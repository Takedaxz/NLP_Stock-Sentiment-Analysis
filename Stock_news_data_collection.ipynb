# %% [markdown]
# # Web scraping stock market news for Sentiment Analysis

# %% [markdown]
# ## 1. Install/import libraries

# %%
# %pip install pandas nltk cloudscraper beautifulsoup4 htmldate newspaper3k lxml_html_clean
# Out:
# Requirement already satisfied: pandas in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (2.2.3)
# Requirement already satisfied: nltk in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (3.9.1)
# Requirement already satisfied: cloudscraper in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (1.2.71)
# Requirement already satisfied: beautifulsoup4 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (4.12.3)
# Requirement already satisfied: htmldate in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (1.9.3)
# Requirement already satisfied: newspaper3k in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (0.2.8)
# Requirement already satisfied: lxml_html_clean in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (0.4.1)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: click in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: pyparsing>=2.4.7 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from cloudscraper) (3.2.1)
# Requirement already satisfied: requests>=2.9.2 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from cloudscraper) (2.32.3)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from cloudscraper) (1.0.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: charset_normalizer>=3.4.0 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from htmldate) (3.4.1)
# Requirement already satisfied: dateparser>=1.1.2 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from htmldate) (1.2.1)
# Requirement already satisfied: lxml<6,>=5.3.0 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from htmldate) (5.3.1)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from htmldate) (2.3.0)
# Requirement already satisfied: Pillow>=3.3.0 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from newspaper3k) (11.1.0)
# Requirement already satisfied: PyYAML>=3.11 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from newspaper3k) (6.0.2)
# Requirement already satisfied: cssselect>=0.9.2 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from newspaper3k) (1.3.0)
# Requirement already satisfied: feedparser>=5.2.1 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from newspaper3k) (6.0.11)
# Requirement already satisfied: tldextract>=2.0.1 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from newspaper3k) (5.1.3)
# Requirement already satisfied: feedfinder2>=0.0.4 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: jieba3k>=0.35.1 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: tinysegmenter==0.3 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from newspaper3k) (0.3)
# Requirement already satisfied: tzlocal>=0.2 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from dateparser>=1.1.2->htmldate) (5.3.1)
# Requirement already satisfied: six in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Requirement already satisfied: sgmllib3k in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from requests>=2.9.2->cloudscraper) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from requests>=2.9.2->cloudscraper) (2025.1.31)
# Requirement already satisfied: requests-file>=1.4 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (3.17.0)
# Requirement already satisfied: colorama in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Standard library
import os
import re
import time
import random
import asyncio
import warnings
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor,  as_completed

# Third-party libraries
import pandas as pd
import nltk
import nest_asyncio
import cloudscraper
from htmldate import find_date
from bs4 import BeautifulSoup
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from newspaper import Article

warnings.filterwarnings('ignore')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# ## 2. Data collection

# %%
# ——— CONFIG ———
# Company ticker identifier for investing.com
COMPANY     = "tesla-motors"   
# Maximum number of pages to scrape (pagination)
MAX_PAGE    = 1000             
# Number of concurrent workers for ThreadPoolExecutor
MAX_WORKERS = 50              
# Maximum number of retry attempts for failed requests
MAX_RETRIES = 5              

# HTTP headers to mimic a legitimate web browser request
# This helps avoid detection as a bot/scraper
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/115.0.0.0 Safari/537.36"
    ),
    "Accept": (
        "text/html,application/xhtml+xml,application/xml;"
        "q=0.9,image/avif,image/webp,*/*;q=0.8"
    ),
    # Referrer to appear as if coming from the main site
    "Referer": "https://www.investing.com/",
}

# Create a cloudscraper instance to bypass Cloudflare protections
scraper = cloudscraper.create_scraper(
    browser={'browser': 'chrome', 'platform': 'windows'}
)

def fetch_page(page: int):
    """ดึงลิงก์ข่าวจากหน้า {page} แล้วคืน list ของ href"""
    # Construct URL for the specific page number
    url = f"https://www.investing.com/equities/{COMPANY}-news/{page}"
    # Implement retry logic for resilience
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            # Make HTTP request with timeout
            r = scraper.get(url, headers=HEADERS, timeout=30)
            r.raise_for_status()  # Raise exception for 4XX/5XX responses
            # Parse HTML with BeautifulSoup
            soup = BeautifulSoup(r.text, "lxml")
            # CSS selector to find news article links
            anchors = soup.select(
                'ul[data-test="news-list"] '
                'li article a[data-test="article-title-link"]'
            )
            # Extract href attributes from anchor tags
            return [a["href"] for a in anchors if a.has_attr("href")]
        except Exception as e:
            # Exponential backoff with jitter for retries
            if attempt < MAX_RETRIES:
                backoff = 2 ** (attempt - 1) + random.random()
                time.sleep(backoff)
            else:
                # Log failure after exhausting retries
                print(f"Page {page} failed after {MAX_RETRIES}: {e}")
    # Return empty list if all attempts fail
    return []

def robust_scrape():
    # First, fetch page 1 to determine how many links per page
    first = fetch_page(1)
    PER_PAGE = len(first)
    # Validate we got results from first page
    if PER_PAGE == 0:
        raise RuntimeError("Failed to fetch the first page. Please check headers or cookies and try again.")
    print(f"Detected {PER_PAGE} links per page, expecting {PER_PAGE * MAX_PAGE} total")

    # Initialize results dictionary with first page
    results = {1: first}
    # Create list of remaining pages to fetch
    pages = list(range(2, MAX_PAGE + 1))

    # Use thread pool for parallel execution
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as pool:
        # Submit fetch jobs for all pages
        futures = {pool.submit(fetch_page, p): p for p in pages}
        # Process completed futures as they finish
        for fut in as_completed(futures):
            p = futures[fut]
            results[p] = fut.result()

        # Retry logic for pages with incomplete results
        for round in range(1, MAX_RETRIES + 1):
            # Identify pages with fewer links than expected
            bad = [p for p, links in results.items() if len(links) != PER_PAGE]
            if not bad:
                print(f"All pages OK after {round-1} retries")
                break

            # Retry only the problematic pages
            print(f"Retry round {round} for pages: {bad}")
            futures = {pool.submit(fetch_page, p): p for p in bad}
            for fut in as_completed(futures):
                p = futures[fut]
                results[p] = fut.result()
        else:
            # This executes if the for loop completes without breaking
            print("Retry limit reached; some pages may still be incomplete.")

    # Calculate statistics on results
    total_fetched = sum(len(links) for links in results.values())
    expected = PER_PAGE * MAX_PAGE
    print(f"Total links fetched (including duplicates): {total_fetched} (expected {expected})")

    # Deduplicate links using set conversion
    all_links = set(link for links in results.values() for link in links)
    print(f"Final: got {len(all_links)} unique URLs (expected {expected})")
    return list(all_links)

# Entry point guard - only executes when run directly
if __name__ == "__main__":
    links = robust_scrape()
# Out:
# Detected 10 links per page, expecting 10000 total
# All pages OK after 0 retries
# Total links fetched (including duplicates): 10000 (expected 10000)
# Final: got 9999 unique URLs (expected 10000)

# %%
links
# Out:
# ['https://www.investing.com/news/stock-market-news/musk-says-hes-raising-pay-for-tesla-ai-engineers-amid-a-talent-war-432SI-3365051',
#  'https://www.investing.com/news/stock-market-news/tesla-slips-as-nhtsa-probes-fsd-collisions-in-reduced-visibility-conditions-3670572',
#  'https://www.investing.com/news/company-news/josh-gottheimers-active-trading-in-july-buys-and-sells-in-tesla-3m-and-more-93CH-3576509',
#  'https://www.investing.com/news/stock-market-news/elon-musk-must-face-fraud-lawsuit-for-disclosing-twitter-stake-late-3189411',
#  'https://www.investing.com/news/stock-market-news/pullback-in-consumer-discretionary-stocks-is-a-buying-opportunity--fairlead-strategies-432SI-3485394',
#  'https://www.investing.com/news/stock-market-news/ford-cuts-prices-for-f150-lightning-xlt-flash-and-lariat-variants-3375567',
#  'https://www.investing.com/news/stock-market-news/ford-gm-bumped-to-buy-boeing-gets-2-upgrades-4-big-analyst-picks-3216549',
#  'https://www.investing.com/news/stock-market-news/rbc-capital-cuts-price-target-on-tesla-as-price-war-weighs-432SI-3059235',
#  'https://www.investing.com/news/pro/tesla-motors-receives-investment-bank-analyst-rating-update-
#  'https://www.investing.com/news/pro/piper-sandler-maintains-tesla-at-overweight-with-a-price-target-of-40000-3997432',
#  'https://www.investing.com/news/stock-market-news/waymo-says-it-plans-to-roll-out-robotaxi-service-in-washington-dc-in-2026-3947152',
#  'https://www.investing.com/news/stock-market-news/investors-bought-magnificent-7-etf-amid-downturn-data-shows-3925347',
#  'https://www.investing.com/news/world-news/chinas-xi-visits-financial-hub-shanghai-in-first-trip-in-three-years-3245872',
#  'https://www.investing.com/news/stock-market-news/wedbush-reiterates-outperform-ahead-of-teslas-4q-delivery-report-432SI-3264027',
#  'https://www.investing.com/news/stock-market-news/elon-musks-doge-team-granted-readonly-access-to-us-treasury-payment-data--report-93CH-3854295',
#  'https://www.investing.com/news/stock-market-news/chinas-nio-cuts-prices-for-all-models-ends-free-battery-swapping-services-3102739',
#  'https://www.investing.com/news/pro/td-cowen-maintains-tesla-at-buy-with-a-price-target-of-33000-3997428',
#  'https://www.investing.com/news/stock-market-news/tesla-recalls-380000-vehicles-in-us-over-power-steering-issue-3882817',
#  'https://www.investing.com/news/economy-news/morning-bid-us-exceptionalism-has-a-flipside-3833407',
#  'https://www.investing.com/news/stock-market-news/hyundai-and-sk-on-finalize-5b-ev-battery-venture-in-us-432SI-3064069',
#  'https://www.investing.com/news/stock-market-news/northvolts-north-american-division-ceo-to-step-down-3841235',
#  'https://www.investing.com/news/stock-market-news/honda-ceo-touts-evs-but-combustion-engines-could-last-until-2040-3021737',
#  'https://www.investing.com/news/pro/active-options-tsla-aapl-amzn-bbby-nvda-amd-mmm-meta-baba-msft-f-432SI-2883195',
#  'https://www.investing.com/news/stock-market-news/hyundai-offers-higher-wage-structure-for-some-us-employees-3232754',
#  'https://www.investing.com/news/analyst-ratings/truist-cuts-tesla-stock-price-target-to-280-maintains-hold-93CH-3963568',
#  ...]

# %%
with open('TSLA_urls.txt', 'w') as f:
    for link in links:
        f.write("%s\n" % link)

# %%
# Apply nest_asyncio to allow running asyncio within Jupyter notebook
# This is necessary because Jupyter already uses an event loop
nest_asyncio.apply()

# Configuration parameters for parallel processing and network requests
# Calculate optimal number of workers for fetching HTML (limited to 32)
FETCH_WORKERS = min(32, os.cpu_count() * 4)  
# Use available CPU cores for processing articles 
PROCESS_WORKERS = os.cpu_count() or 4       
# Maximum retry attempts for failed network requests
MAX_FETCH_RETRIES = 3                      
# Delay between retry attempts (seconds)
RETRY_DELAY = 1                             
# Stock ticker symbol used for labeling data
TICKER = 'TSLA'
# Create cloudscraper instance to bypass anti-bot measures
scraper = cloudscraper.create_scraper()

def is_placeholder(html: str) -> bool:
    """
    Check if the HTML content is a placeholder/error page instead of actual content.
    
    These placeholders are common when websites detect scraping or have technical issues.
    """
    lower = html.lower() if html else ""
    return (
        'temporarily down for maintenance' in lower
        or 'just a moment' in lower
        or "we're temporarily down" in lower
    )

def safe_find_datetime(url, html_content=None):
    """
    Extract publication date and time from the URL or HTML content.
    
    Uses multiple strategies with fallbacks:
    1. Try htmldate library on URL
    2. Look for American format dates (MM/DD/YYYY, HH:MM AM/PM) in content
    3. Try both European and American formats (DD/MM/YYYY or MM/DD/YYYY)
    4. Fallback to current date and time if all else fails
    
    Returns: tuple of (date_string, time_string)
    """
    try:
        # Strategy 1: Use htmldate library to extract date from URL
        dt = find_date(url)
        if dt:
            return dt, "00:00"  # Return with default time if date found
    except:
        pass
    
    if html_content:
        # Strategy 2: Look for American format with AM/PM
        m = re.search(r"(\d{1,2}/\d{1,2}/\d{4}),\s*(\d{1,2}:\d{2}\s*(?:AM|PM))", html_content)
        if m:
            ds, ts = m.groups()
            try:
                dt = datetime.strptime(f"{ds}, {ts}", "%m/%d/%Y, %I:%M %p")
                return dt.strftime("%Y-%m-%d"), dt.strftime("%H:%M")
            except:
                pass
        
        # Strategy 3: Look for numeric dates with 24-hour time format
        m = re.search(r"(\d{2}/\d{2}/\d{4}),\s*(\d{2}:\d{2})", html_content)
        if m:
            ds, ts = m.groups()
            # Try both European and American date formats
            for fmt in ("%d/%m/%Y, %H:%M", "%m/%d/%Y, %H:%M"):
                try:
                    dt = datetime.strptime(f"{ds}, {ts}", fmt)
                    return dt.strftime("%Y-%m-%d"), dt.strftime("%H:%M")
                except:
                    continue
    
    # Fallback: Use current date and time
    now = datetime.now()
    return now.strftime("%Y-%m-%d"), now.strftime("%H:%M")

# ——— Fetch HTML with minimal retry mechanism ———
def fetch_html(url, idx, total):
    """
    Fetch the HTML content for a given URL with retry logic.
    
    Args:
        url: The URL to fetch
        idx: Current index (for progress reporting)
        total: Total number of URLs (for progress reporting)
        
    Returns:
        tuple of (url, html_content) or (url, None) if failed
    """
    for attempt in range(1, MAX_FETCH_RETRIES + 1):
        try:
            # Make HTTP request with timeout
            resp = scraper.get(url, timeout=30)
            html = resp.text
            
            # Check if we got a placeholder page instead of content
            if is_placeholder(html):
                raise RuntimeError('Placeholder')
                
            # Report success
            print(f"[Fetch][{idx}/{total}][ok]")
            return url, html
            
        except Exception:
            # Report retry attempt
            print(f"[Fetch][{idx}/{total}][retry {attempt}]")
            if attempt < MAX_FETCH_RETRIES:
                # Wait before retrying
                time.sleep(RETRY_DELAY)
                
    # Report complete failure after all retries
    print(f"[Fetch error] {idx}/{total}: failed after {MAX_FETCH_RETRIES} retries")
    return url, None

# ——— Initialize sentiment analyzer from NLTK ———
SID = SentimentIntensityAnalyzer()

def process_article(arg):
    """
    Process an article's HTML to extract content and analyze sentiment.
    
    Uses newspaper3k library to parse article content and NLTK's VADER
    for sentiment analysis.
    
    Args:
        arg: tuple of (url, html_content)
        
    Returns:
        dictionary with extracted data and sentiment scores, or None if processing failed
    """
    url, html = arg
    if not html:
        return None
        
    # Initialize newspaper Article object
    art = Article(url)
    art.set_html(html)
    
    try:
        # Parse article content
        art.parse()
    except:
        return None
        
    # Extract text and title
    text = art.text or ""
    title = (art.title or "").strip() or "No title"
    
    # Calculate sentiment scores using VADER
    pol = SID.polarity_scores(text)
    
    # Extract publication date and time
    date, tm = safe_find_datetime(url, html)
    
    # Return combined data using dictionary unpacking
    return {**{'ticker': TICKER, 'publish_date': date, 'publish_time': tm,
             'title': title, 'body_text': text, 'url': url}, **pol}

async def scrape_all(urls):
    """
    Asynchronous pipeline to fetch and process multiple URLs in parallel.
    
    Implements a two-phase approach:
    1. Fetch all URLs concurrently using threads
    2. Process all fetched content concurrently using threads
    
    Args:
        urls: List of URLs to process
        
    Returns:
        pandas DataFrame containing all processed articles
    """
    total = len(urls)
    loop = asyncio.get_event_loop()
    
    # Phase 1: Fetch HTML content from all URLs in parallel
    with ThreadPoolExecutor(max_workers=FETCH_WORKERS) as fetch_pool:
        # Create fetch tasks and run them through the thread pool
        fetch_tasks = [loop.run_in_executor(fetch_pool, fetch_html, u, i+1, total)
                       for i, u in enumerate(urls)]
        # Wait for all fetch tasks to complete
        fetched = await asyncio.gather(*fetch_tasks)

    # Phase 2: Process all fetched HTML content in parallel
    records = []
    with ThreadPoolExecutor(max_workers=PROCESS_WORKERS) as proc_pool:
        # Submit processing tasks only for URLs with successful fetches
        futures = {
            proc_pool.submit(process_article, fr): fr[0]
            for fr in fetched if fr[1]  # Skip URLs where HTML is None
        }
        
        # Process results as they complete
        for i, fut in enumerate(as_completed(futures), 1):
            res = fut.result()
            print(f"[Process][{i}/{total}] {futures[fut]}")
            if res:
                records.append(res)
                
    # Convert results to DataFrame
    return pd.DataFrame(records)

# ——— Main entry point function ———
def main(links):
    """
    Main function that runs the entire scraping pipeline.
    
    Args:
        links: List of URLs to process
        
    Returns:
        pandas DataFrame with processed articles
    """
    df = asyncio.get_event_loop().run_until_complete(scrape_all(links))
    return df

# Execute the main function if this script is run directly
if __name__ == '__main__':
    df = main(links)
    print(df.shape)
    print(df.head())
# Out:
# [Fetch][32/9999][retry 1]
# [Fetch][6/9999][ok]
# [Fetch][1/9999][ok]
# [Fetch][11/9999][ok]
# [Fetch][10/9999][ok]
# [Fetch][9/9999][ok]
# [Fetch][12/9999][ok]
# [Fetch][21/9999][ok]
# [Fetch][14/9999][ok]
# [Fetch][2/9999][ok]
# [Fetch][4/9999][ok]
# [Fetch][18/9999][ok]
# [Fetch][17/9999][ok]
# [Fetch][24/9999][ok]
# [Fetch][26/9999][ok]
# [Fetch][13/9999][ok]
# [Fetch][23/9999][ok]
# [Fetch][8/9999][ok]
# [Fetch][5/9999][ok]
# [Fetch][20/9999][ok]
# [Fetch][25/9999][ok]
# [Fetch][28/9999][ok]
# [Fetch][29/9999][ok]
# [Fetch][22/9999][ok]
# [Fetch][31/9999][ok]
# [Fetch][30/9999][ok]
# [Fetch][19/9999][ok]
# [Fetch][15/9999][ok]
# [Fetch][7/9999][ok]
# [Fetch][27/9999][ok]
# [Fetch][33/9999][ok]
# [Fetch][42/9999][ok]
# [Fetch][38/9999][ok]
# [Fetch][43/9999][ok]
# [Fetch][45/9999][ok]
# [Fetch][39/9999][ok]
# [Fetch][52/9999][ok]
# [Fetch][47/9999][ok]
# [Fetch][54/9999][ok]
# [Fetch][50/9999][ok]
# [Fetch][3/9999][ok][Fetch][41/9999][ok]
# [Fetch][58/9999][ok]
#
# [Fetch][53/9999][ok]
# [Fetch][34/9999][ok]
# [Fetch][49/9999][ok]
# [Fetch][35/9999][ok]
# [Fetch][40/9999][ok]
# [Fetch][36/9999][ok]
# [Fetch][57/9999][ok]
# [Fetch][44/9999][ok]
# [Fetch][60/9999][ok]
# [Fetch][55/9999][ok]
# [Fetch][51/9999][ok]
# [Fetch][59/9999][ok]
# [Fetch][56/9999][ok]
# [Fetch][37/9999][ok]
# [Fetch][46/9999][ok]
# [Fetch][48/9999][ok]
# [Fetch][61/9999][ok]
# [Fetch][63/9999][ok]
# [Fetch][66/9999][ok]
# [Fetch][65/9999][ok]
# [Fetch][64/9999][ok]
# [Fetch][75/9999][ok]
# [Fetch][71/9999][ok]
# [Fetch][76/9999][ok]
# [Fetch][84/9999][ok]
# [Fetch][73/9999][ok]
# [Fetch][81/9999][ok]
# [Fetch][67/9999][ok]
# [Fetch][72/9999][ok]
# [Fetch][83/9999][ok]
# [Fetch][74/9999][ok]
# [Fetch][87/9999][ok]
# [Fetch][89/9999][ok]
# [Fetch][85/9999][ok]
# [Fetch][68/9999][ok]
# [Fetch][91/9999][ok]
# [Fetch][88/9999][ok]
# [Fetch][79/9999][ok]
# [Fetch][78/9999][ok]
# [Fetch][86/9999][ok]
# [Fetch][95/9999][ok]
# [Fetch][98/9999][ok]
# [Fetch][97/9999][ok]
# [Fetch][77/9999][ok]
# [Fetch][62/9999][ok]
# [Fetch][100/9999][ok]
# [Fetch][82/9999][ok]
# [Fetch][90/9999][ok]
# [Fetch][102/9999][ok]
# [Fetch][103/9999][ok]
# [Fetch][105/9999][ok]
# [Fetch][16/9999][ok]
# [Fetch][107/9999][ok]
# [Fetch][109/9999][ok]
# [Fetch][96/9999][ok]
# [Fetch][69/9999][ok]
# [Fetch][99/9999][ok]
# [Fetch][112/9999][ok]
# [Fetch][101/9999][ok]
# [Fetch][111/9999][ok]
# [Fetch][93/9999][ok]
# [Fetch][113/9999][ok]
# [Fetch][115/9999][ok]
# [Fetch][114/9999][ok]
# [Fetch][94/9999][ok]
# [Fetch][108/9999][ok]
# [Fetch][32/9999][ok]
# [Fetch][70/9999][ok]
# [Fetch][119/9999][ok]
# [Fetch][127/9999][ok]
# [Fetch][118/9999][ok]
# [Fetch][130/9999][ok]
# [Fetch][123/9999][ok]
# [Fetch][131/9999][ok]
# [Fetch][126/9999][ok]
# [Fetch][128/9999][ok]
# [Fetch][132/9999][ok]
# [Fetch][133/9999][ok]
# [Fetch][120/9999][ok]
# [Fetch][121/9999][ok]
# [Fetch][134/9999][ok][Fetch][125/9999][ok]
#
# [Fetch][138/9999][ok]
# [Fetch][117/9999][ok]
# [Fetch][141/9999][ok]
# [Fetch][110/9999][ok]
# [Fetch][140/9999][ok]
# [Fetch][129/9999][ok]
# [Fetch][142/9999][ok]
# [Fetch][92/9999][ok]
# [Fetch][116/9999][ok]
# [Fetch][149/9999][ok]
# [Fetch][144/9999][ok]
# [Fetch][145/9999][ok]
# [Fetch][146/9999][ok]
# [Fetch][148/9999][ok]
# [Fetch][151/9999][ok]
# [Fetch][153/9999][ok]
# [Fetch][150/9999][ok]
# [Fetch][80/9999][ok]
# [Fetch][147/9999][ok]
# [Fetch][104/9999][ok]
# [Fetch][157/9999][ok]
# [Fetch][152/9999][ok]
# [Fetch][136/9999][ok]
# [Fetch][156/9999][ok]
# [Fetch][135/9999][ok]
# [Fetch][155/9999][ok]
# [Fetch][154/9999][ok]
# [Fetch][122/9999][ok]
# [Fetch][139/9999][ok]
# [Fetch][159/9999][ok]
# [Fetch][143/9999][ok]
# [Fetch][163/9999][ok]
# [Fetch][158/9999][ok]
# [Fetch][162/9999][ok]
# [Fetch][160/9999][ok]
# [Fetch][166/9999][ok]
# [Fetch][167/9999][ok]
# [Fetch][169/9999][ok]
# [Fetch][174/9999][ok]
# [Fetch][179/9999][ok]
# [Fetch][168/9999][ok]
# [Fetch][170/9999][ok]
# [Fetch][178/9999][ok]
# [Fetch][161/9999][ok]
# [Fetch][172/9999][ok]
# [Fetch][175/9999][ok]
# [Fetch][181/9999][ok]
# [Fetch][176/9999][ok]
# [Fetch][180/9999][ok]
# [Fetch][177/9999][ok]
# [Fetch][183/9999][ok]
# [Fetch][189/9999][ok]
# [Fetch][192/9999][ok]
# [Fetch][188/9999][ok]
# [Fetch][171/9999][ok]
# [Fetch][185/9999][ok]
# [Fetch][182/9999][ok]
# [Fetch][193/9999][ok]
# [Fetch][195/9999][ok]
# [Fetch][165/9999][ok]
# [Fetch][197/9999][ok]
# [Fetch][204/9999][ok]
# [Fetch][198/9999][ok]
# [Fetch][200/9999][ok]
# [Fetch][190/9999][ok]
# [Fetch][205/9999][ok]
# [Fetch][199/9999][ok]
# [Fetch][194/9999][ok]
# [Fetch][202/9999][ok]
# [Fetch][173/9999][ok]
# [Fetch][207/9999][ok]
# [Fetch][212/9999][ok]
# [Fetch][217/9999][ok]
# [Fetch][184/9999][ok]
# [Fetch][211/9999][ok][Fetch][214/9999][ok]
#
# [Fetch][216/9999][ok]
# [Fetch][215/9999][ok]
# [Fetch][221/9999][ok]
# [Fetch][220/9999][ok]
# [Fetch][213/9999][ok]
# [Fetch][219/9999][ok]
# [Fetch][196/9999][ok]
# [Fetch][209/9999][ok]
# [Fetch][201/9999][ok]
# [Fetch][224/9999][ok]
# [Fetch][218/9999][ok]
# [Fetch][227/9999][ok][Fetch][226/9999][ok]
#
# [Fetch][223/9999][ok]
# [Fetch][187/9999][ok]
# [Fetch][124/9999][ok]
# [Fetch][203/9999][ok]
# [Fetch][208/9999][ok]
# [Fetch][206/9999][ok]
# [Fetch][186/9999][ok]
# [Fetch][137/9999][ok]
# [Fetch][164/9999][ok]
# [Fetch][191/9999][ok]
# [Fetch][222/9999][ok]
# [Fetch][229/9999][ok]
# [Fetch][210/9999][ok]
# [Fetch][234/9999][ok]
# [Fetch][231/9999][ok]
# [Fetch][233/9999][ok]
# [Fetch][232/9999][ok]
# [Fetch][230/9999][ok]
# [Fetch][235/9999][ok]
# [Fetch][240/9999][ok]
# [Fetch][243/9999][ok]
# [Fetch][228/9999][ok]
# [Fetch][241/9999][ok]
# [Fetch][239/9999][ok]
# [Fetch][238/9999][ok]
# [Fetch][237/9999][ok]
# [Fetch][253/9999][ok]
# [Fetch][246/9999][ok]
# [Fetch][247/9999][ok]
# [Fetch][244/9999][ok]
# [Fetch][252/9999][ok]
# [Fetch][249/9999][ok]
# [Fetch][248/9999][ok]
# [Fetch][245/9999][ok]
# [Fetch][255/9999][ok]
# [Fetch][250/9999][ok][Fetch][256/9999][ok]
#
# [Fetch][254/9999][ok]
# [Fetch][262/9999][ok]
# [Fetch][267/9999][ok]
# [Fetch][264/9999][ok]
# [Fetch][236/9999][ok]
# [Fetch][261/9999][ok]
# [Fetch][270/9999][ok]
# [Fetch][272/9999][ok]
# [Fetch][258/9999][ok]
# [Fetch][269/9999][ok]
# [Fetch][268/9999][ok]
# [Fetch][225/9999][ok]
# [Fetch][273/9999][ok]
# [Fetch][274/9999][ok]
# [Fetch][265/9999][ok]
# [Fetch][259/9999][ok]
# [Fetch][251/9999][ok]
# [Fetch][271/9999][ok]
# [Fetch][279/9999][ok]
# [Fetch][276/9999][ok]
# [Fetch][266/9999][ok]
# [Fetch][280/9999][ok]
# [Fetch][260/9999][ok]
# [Fetch][282/9999][ok][Fetch][278/9999][ok]
#
# [Fetch][263/9999][ok]
# [Fetch][285/9999][ok]
# [Fetch][283/9999][ok]
# [Fetch][242/9999][ok]
# [Fetch][286/9999][ok]
# [Fetch][277/9999][ok]
# [Fetch][284/9999][ok]
# [Fetch][294/9999][ok]
# [Fetch][293/9999][ok]
# [Fetch][292/9999][ok]
# [Fetch][291/9999][ok]
# [Fetch][281/9999][ok]
# [Fetch][290/9999][ok]
# [Fetch][296/9999][ok]
# [Fetch][288/9999][ok]
# [Fetch][287/9999][ok]
# [Fetch][257/9999][ok]
# [Fetch][300/9999][ok]
# [Fetch][275/9999][ok]
# [Fetch][297/9999][ok]
# [Fetch][311/9999][ok]
# [Fetch][313/9999][ok]
# [Fetch][305/9999][ok]
# [Fetch][307/9999][ok]
# [Fetch][309/9999][ok]
# [Fetch][303/9999][ok]
# [Fetch][319/9999][ok]
# [Fetch][306/9999][ok]
# [Fetch][308/9999][ok]
# [Fetch][299/9999][ok]
# [Fetch][322/9999][ok]
# [Fetch][289/9999][ok]
# [Fetch][318/9999][ok]
# [Fetch][310/9999][ok]
# [Fetch][321/9999][ok]
# [Fetch][317/9999][ok]
# [Fetch][316/9999][ok]
# [Fetch][320/9999][ok]
# [Fetch][324/9999][ok]
# [Fetch][312/9999][ok]
# [Fetch][323/9999][ok]
# [Fetch][304/9999][ok]
# [Fetch][328/9999][ok]
# [Fetch][331/9999][ok]
# [Fetch][325/9999][ok]
# [Fetch][333/9999][ok]
# [Fetch][338/9999][ok]
# [Fetch][336/9999][ok]
# [Fetch][334/9999][ok]
# [Fetch][329/9999][ok]
# [Fetch][326/9999][ok]
# [Fetch][342/9999][ok]
# [Fetch][332/9999][ok]
# [Fetch][340/9999][ok]
# [Fetch][327/9999][ok]
# [Fetch][339/9999][ok]
# [Fetch][330/9999][ok]
# [Fetch][335/9999][ok]
# [Fetch][337/9999][ok]
# [Fetch][341/9999][ok]
# [Fetch][344/9999][ok]
# [Fetch][295/9999][ok]
# [Fetch][346/9999][ok]
# [Fetch][347/9999][ok]
# [Fetch][343/9999][ok][Fetch][350/9999][ok]
#
# [Fetch][351/9999][ok]
# [Fetch][353/9999][ok]
# [Fetch][348/9999][ok]
# [Fetch][352/9999][ok]
# [Fetch][355/9999][ok]
# [Fetch][357/9999][ok]
# [Fetch][359/9999][ok]
# [Fetch][354/9999][ok]
# [Fetch][302/9999][ok]
# [Fetch][360/9999][ok]
# [Fetch][361/9999][ok]
# [Fetch][314/9999][ok]
# [Fetch][358/9999][ok]
# [Fetch][369/9999][ok]
# [Fetch][362/9999][ok]
# [Fetch][364/9999][ok]
# [Fetch][368/9999][ok]
# [Fetch][366/9999][ok]
# [Fetch][367/9999][ok]
# [Fetch][370/9999][ok]
# [Fetch][363/9999][ok]
# [Fetch][298/9999][ok]
# [Fetch][345/9999][ok]
# [Fetch][301/9999][ok]
# [Fetch][371/9999][ok]
# [Fetch][349/9999][ok]
# [Fetch][375/9999][ok]
# [Fetch][376/9999][ok]
# [Fetch][365/9999][ok]
# [Fetch][372/9999][ok]
# [Fetch][377/9999][ok]
# [Fetch][380/9999][ok]
# [Fetch][381/9999][ok]
# [Fetch][378/9999][ok]
# [Fetch][387/9999][ok]
# [Fetch][382/9999][ok]
# [Fetch][388/9999][ok]
# [Fetch][389/9999][ok]
# [Fetch][400/9999][ok]
# [Fetch][394/9999][ok]
# [Fetch][397/9999][ok]
# [Fetch][384/9999][ok]
# [Fetch][390/9999][ok]
# [Fetch][386/9999][ok]
# [Fetch][385/9999][ok]
# [Fetch][383/9999][ok]
# [Fetch][391/9999][ok][Fetch][379/9999][ok]
#
# [Fetch][399/9999][ok]
# [Fetch][402/9999][ok]
# [Fetch][398/9999][ok]
# [Fetch][374/9999][ok]
# [Fetch][395/9999][ok]
# [Fetch][393/9999][ok]
# [Fetch][407/9999][ok]
# [Fetch][392/9999][ok]
# [Fetch][408/9999][ok]
# [Fetch][403/9999][ok]
# [Fetch][406/9999][ok]
# [Fetch][405/9999][ok]
# [Fetch][420/9999][ok]
# [Fetch][417/9999][ok]
# [Fetch][425/9999][ok]
# [Fetch][423/9999][ok]
# [Fetch][373/9999][ok]
# [Fetch][421/9999][ok]
# [Fetch][413/9999][ok]
# [Fetch][424/9999][ok]
# [Fetch][419/9999][ok]
# [Fetch][414/9999][ok]
# [Fetch][411/9999][ok]
# [Fetch][429/9999][ok]
# [Fetch][415/9999][ok]
# [Fetch][422/9999][ok]
# [Fetch][404/9999][ok]
# [Fetch][426/9999][ok]
# [Fetch][416/9999][ok]
# [Fetch][427/9999][ok]
# [Fetch][418/9999][ok]
# [Fetch][432/9999][ok]
# [Fetch][431/9999][ok]
# [Fetch][433/9999][ok]
# [Fetch][430/9999][ok]
# [Fetch][412/9999][ok]
# [Fetch][428/9999][ok]
# [Fetch][410/9999][ok][Fetch][437/9999][ok]
#
# [Fetch][435/9999][ok]
# [Fetch][434/9999][ok]
# [Fetch][440/9999][ok]
# [Fetch][409/9999][ok]
# [Fetch][436/9999][ok]
# [Fetch][439/9999][ok]
# [Fetch][441/9999][ok]
# [Fetch][445/9999][ok]
# [Fetch][396/9999][ok]
# [Fetch][443/9999][ok]
# [Fetch][438/9999][ok]
# [Fetch][446/9999][ok]
# [Fetch][450/9999][ok]
# [Fetch][448/9999][ok]
# [Fetch][456/9999][ok]
# [Fetch][452/9999][ok]
# [Fetch][453/9999][ok]
# [Fetch][449/9999][ok]
# [Fetch][455/9999][ok]
# [Fetch][442/9999][ok]
# [Fetch][444/9999][ok]
# [Fetch][454/9999][ok]
# [Fetch][461/9999][ok]
# [Fetch][458/9999][ok]
# [Fetch][451/9999][ok]
# [Fetch][459/9999][ok]
# [Fetch][467/9999][ok]
# [Fetch][447/9999][ok]
# [Fetch][462/9999][ok]
# [Fetch][468/9999][ok]
# [Fetch][470/9999][ok]
# [Fetch][401/9999][ok]
# [Fetch][463/9999][ok]
# [Fetch][471/9999][ok]
# [Fetch][460/9999][ok]
# [Fetch][466/9999][ok]
# [Fetch][475/9999][ok]
# [Fetch][476/9999][ok]
# [Fetch][480/9999][ok]
# [Fetch][478/9999][ok]
# [Fetch][473/9999][ok]
# [Fetch][485/9999][ok]
# [Fetch][486/9999][ok]
# [Fetch][481/9999][ok]
# [Fetch][479/9999][ok]
# [Fetch][464/9999][ok]
# [Fetch][487/9999][ok]
# [Fetch][482/9999][ok]
# [Fetch][477/9999][ok]
# [Fetch][465/9999][ok]
# [Fetch][457/9999][ok]
# [Fetch][469/9999][ok]
# [Fetch][483/9999][ok]
# [Fetch][474/9999][ok]
# [Fetch][489/9999][ok]
# [Fetch][488/9999][ok][Fetch][494/9999][ok]
#
# [Fetch][495/9999][ok]
# [Fetch][492/9999][ok]
# [Fetch][496/9999][ok]
# [Fetch][502/9999][ok]
# [Fetch][493/9999][ok]
# [Fetch][491/9999][ok]
# [Fetch][500/9999][ok]
# [Fetch][490/9999][ok]
# [Fetch][510/9999][ok]
# [Fetch][508/9999][ok]
# [Fetch][503/9999][ok]
# [Fetch][513/9999][ok]
# [Fetch][511/9999][ok][Fetch][504/9999][ok]
#
# [Fetch][501/9999][ok]
# [Fetch][507/9999][ok]
# [Fetch][514/9999][ok]
# [Fetch][509/9999][ok]
# [Fetch][497/9999][ok]
# [Fetch][499/9999][ok]
# [Fetch][505/9999][ok]
# [Fetch][515/9999][ok]
# [Fetch][498/9999][ok]
# [Fetch][506/9999][ok]
# [Fetch][484/9999][ok]
# [Fetch][520/9999][ok]
# [Fetch][512/9999][ok]
# [Fetch][517/9999][ok]
# [Fetch][521/9999][ok]
# [Fetch][518/9999][ok]
# [Fetch][529/9999][ok]
# [Fetch][524/9999][ok]
# [Fetch][315/9999][ok]
# [Fetch][526/9999][ok]
# [Fetch][527/9999][ok]
# [Fetch][528/9999][ok]
# [Fetch][522/9999][ok]
# [Fetch][525/9999][ok]
# [Fetch][530/9999][ok]
# [Fetch][535/9999][ok]
# [Fetch][534/9999][ok]
# [Fetch][536/9999][ok]
# [Fetch][540/9999][ok]
# [Fetch][519/9999][ok]
# [Fetch][544/9999][ok]
# [Fetch][531/9999][ok]
# [Fetch][543/9999][ok]
# [Fetch][538/9999][ok]
# [Fetch][545/9999][ok]
# [Fetch][472/9999][ok]
# [Fetch][533/9999][ok]
# [Fetch][532/9999][ok]
# [Fetch][548/9999][ok]
# [Fetch][542/9999][ok]
# [Fetch][537/9999][ok][Fetch][541/9999][ok]
#
# [Fetch][550/9999][ok]
# [Fetch][549/9999][ok]
# [Fetch][523/9999][ok]
# [Fetch][546/9999][ok]
# [Fetch][547/9999][ok]
# [Fetch][539/9999][ok]
# [Fetch][555/9999][ok]
# [Fetch][556/9999][ok]
# [Fetch][557/9999][ok]
# [Fetch][561/9999][ok]
# [Fetch][558/9999][ok]
# [Fetch][552/9999][ok]
# [Fetch][553/9999][ok]
# [Fetch][566/9999][ok]
# [Fetch][562/9999][ok]
# [Fetch][570/9999][ok]
# [Fetch][554/9999][ok]
# [Fetch][516/9999][ok]
# [Fetch][551/9999][ok]
# [Fetch][568/9999][ok][Fetch][567/9999][ok]
#
# [Fetch][579/9999][ok]
# [Fetch][578/9999][ok]
# [Fetch][580/9999][ok]
# [Fetch][574/9999][ok]
# [Fetch][569/9999][ok]
# [Fetch][572/9999][ok]
# [Fetch][582/9999][ok]
# [Fetch][581/9999][ok]
# [Fetch][564/9999][ok]
# [Fetch][356/9999][ok]
# [Fetch][575/9999][ok]
# [Fetch][585/9999][ok]
# [Fetch][587/9999][ok]
# [Fetch][589/9999][ok]
# [Fetch][563/9999][ok]
# [Fetch][565/9999][ok]
# [Fetch][559/9999][ok]
# [Fetch][588/9999][ok]
# [Fetch][586/9999][ok]
# [Fetch][591/9999][ok]
# [Fetch][583/9999][ok]
# [Fetch][593/9999][ok]
# [Fetch][590/9999][ok]
# [Fetch][573/9999][ok]
# [Fetch][596/9999][ok]
# [Fetch][571/9999][ok]
# [Fetch][577/9999][ok]
# [Fetch][560/9999][ok]
# [Fetch][592/9999][ok]
# [Fetch][576/9999][ok]
# [Fetch][595/9999][ok]
# [Fetch][600/9999][ok]
# [Fetch][594/9999][ok]
# [Fetch][603/9999][ok]
# [Fetch][599/9999][ok]
# [Fetch][605/9999][ok]
# [Fetch][584/9999][ok]
# [Fetch][598/9999][ok]
# [Fetch][612/9999][ok]
# [Fetch][618/9999][ok]
# [Fetch][607/9999][ok]
# [Fetch][602/9999][ok]
# [Fetch][614/9999][ok]
# [Fetch][608/9999][ok]
# [Fetch][617/9999][ok]
# [Fetch][615/9999][ok]
# [Fetch][616/9999][ok]
# [Fetch][604/9999][ok]
# [Fetch][597/9999][ok]
# [Fetch][619/9999][ok]
# [Fetch][613/9999][ok]
# [Fetch][606/9999][ok]
# [Fetch][624/9999][ok]
# [Fetch][620/9999][ok]
# [Fetch][630/9999][ok]
# [Fetch][625/9999][ok]
# [Fetch][611/9999][ok]
# [Fetch][627/9999][ok]
# [Fetch][610/9999][ok]
# [Fetch][621/9999][ok]
# [Fetch][632/9999][ok]
# [Fetch][633/9999][ok]
# [Fetch][628/9999][ok]
# [Fetch][631/9999][ok]
# [Fetch][637/9999][ok]
# [Fetch][638/9999][ok]
# [Fetch][622/9999][ok]
# [Fetch][626/9999][ok]
# [Fetch][634/9999][ok]
# [Fetch][635/9999][ok]
# [Fetch][623/9999][ok]
# [Fetch][640/9999][ok]
# [Fetch][629/9999][ok]
# [Fetch][647/9999][ok][Fetch][636/9999][ok]
#
# [Fetch][609/9999][ok]
# [Fetch][645/9999][ok]
# [Fetch][642/9999][ok]
# [Fetch][649/9999][ok]
# [Fetch][643/9999][ok]
# [Fetch][648/9999][ok]
# [Fetch][639/9999][ok]
# [Fetch][656/9999][ok]
# [Fetch][644/9999][ok]
# [Fetch][655/9999][ok]
# [Fetch][646/9999][ok]
# [Fetch][652/9999][ok]
# [Fetch][653/9999][ok]
# [Fetch][660/9999][ok]
# [Fetch][658/9999][ok]
# [Fetch][657/9999][ok]
# [Fetch][663/9999][ok][Fetch][665/9999][ok]
# [Fetch][661/9999][ok]
#
# [Fetch][650/9999][ok]
# [Fetch][666/9999][ok]
# [Fetch][667/9999][ok]
# [Fetch][662/9999][ok]
# [Fetch][641/9999][ok]
# [Fetch][654/9999][ok]
# [Fetch][601/9999][ok]
# [Fetch][670/9999][ok][Fetch][659/9999][ok]
#
# [Fetch][651/9999][ok]
# [Fetch][664/9999][ok]
# [Fetch][673/9999][ok]
# [Fetch][669/9999][ok]
# [Fetch][671/9999][ok]
# [Fetch][668/9999][ok]
# [Fetch][672/9999][ok]
# [Fetch][676/9999][ok]
# [Fetch][675/9999][ok]
# [Fetch][684/9999][ok]
# [Fetch][682/9999][ok]
# [Fetch][687/9999][ok]
# [Fetch][683/9999][ok]
# [Fetch][678/9999][ok]
# [Fetch][699/9999][ok]
# [Fetch][693/9999][ok]
# [Fetch][679/9999][ok]
# [Fetch][695/9999][ok]
# [Fetch][106/9999][ok]
# [Fetch][690/9999][ok]
# [Fetch][696/9999][ok]
# [Fetch][704/9999][ok]
# [Fetch][688/9999][ok]
# [Fetch][706/9999][ok]
# [Fetch][689/9999][ok]
# [Fetch][692/9999][ok]
# [Fetch][702/9999][ok]
# [Fetch][685/9999][ok]
# [Fetch][705/9999][ok]
# [Fetch][677/9999][ok]
# [Fetch][707/9999][ok]
# [Fetch][698/9999][ok]
# [Fetch][680/9999][ok]
# [Fetch][691/9999][ok]
# [Fetch][714/9999][ok]
# [Fetch][709/9999][ok]
# [Fetch][701/9999][ok]
# [Fetch][703/9999][ok][Fetch][713/9999][ok]
#
# [Fetch][711/9999][ok]
# [Fetch][710/9999][ok]
# [Fetch][716/9999][ok]
# [Fetch][718/9999][ok]
# [Fetch][719/9999][ok]
# [Fetch][717/9999][ok]
# [Fetch][712/9999][ok]
# [Fetch][720/9999][ok]
# [Fetch][721/9999][ok]
# [Fetch][694/9999][ok]
# [Fetch][723/9999][ok]
# [Fetch][724/9999][ok]
# [Fetch][722/9999][ok]
# [Fetch][731/9999][ok]
# [Fetch][732/9999][ok]
# [Fetch][700/9999][ok]
# [Fetch][681/9999][ok]
# [Fetch][735/9999][ok]
# [Fetch][738/9999][ok]
# [Fetch][697/9999][ok]
# [Fetch][742/9999][ok]
# [Fetch][740/9999][ok]
# [Fetch][730/9999][ok]
# [Fetch][728/9999][ok]
# [Fetch][733/9999][ok]
# [Fetch][725/9999][ok]
# [Fetch][726/9999][ok]
# [Fetch][734/9999][ok]
# [Fetch][729/9999][ok]
# [Fetch][727/9999][ok]
# [Fetch][743/9999][ok]
# [Fetch][745/9999][ok]
# [Fetch][747/9999][ok]
# [Fetch][744/9999][ok]
# [Fetch][746/9999][ok]
# [Fetch][739/9999][ok]
# [Fetch][736/9999][ok]
# [Fetch][708/9999][ok]
# [Fetch][751/9999][ok]
# [Fetch][750/9999][ok]
# [Fetch][753/9999][ok]
# [Fetch][756/9999][ok]
# [Fetch][752/9999][ok]
# [Fetch][758/9999][ok]
# [Fetch][764/9999][ok]
# [Fetch][754/9999][ok]
# [Fetch][737/9999][ok]
# [Fetch][748/9999][ok]
# [Fetch][763/9999][ok]
# [Fetch][759/9999][ok]
# [Fetch][762/9999][ok]
# [Fetch][755/9999][ok]
# [Fetch][768/9999][ok]
# [Fetch][769/9999][ok]
# [Fetch][760/9999][ok]
# [Fetch][767/9999][ok]
# [Fetch][775/9999][ok]
# [Fetch][765/9999][ok]
# [Fetch][771/9999][ok]
# [Fetch][772/9999][ok]
# [Fetch][674/9999][ok]
# [Fetch][773/9999][ok]
# [Fetch][776/9999][ok]
# [Fetch][770/9999][ok]
# [Fetch][757/9999][ok]
# [Fetch][778/9999][ok]
# [Fetch][780/9999][ok]
# [Fetch][777/9999][ok]
# [Fetch][781/9999][ok]
# [Fetch][785/9999][ok][Fetch][784/9999][ok]
#
# [Fetch][774/9999][ok]
# [Fetch][779/9999][ok]
# [Fetch][761/9999][ok]
# [Fetch][786/9999][ok]
# [Fetch][749/9999][ok]
# [Fetch][788/9999][ok]
# [Fetch][741/9999][ok]
# [Fetch][783/9999][ok]
# [Fetch][791/9999][ok]
# [Fetch][797/9999][ok]
# [Fetch][782/9999][ok]
# [Fetch][793/9999][ok]
# [Fetch][790/9999][ok]
# [Fetch][789/9999][ok]
# [Fetch][787/9999][ok]
# [Fetch][795/9999][ok]
# [Fetch][792/9999][ok]
# [Fetch][798/9999][ok]
# [Fetch][802/9999][ok]
# [Fetch][799/9999][ok]
# [Fetch][801/9999][ok]
# [Fetch][803/9999][ok]
# [Fetch][794/9999][ok]
# [Fetch][796/9999][ok]
# [Fetch][804/9999][ok]
# [Fetch][800/9999][ok]
# [Fetch][806/9999][ok]
# [Fetch][813/9999][ok]
# [Fetch][807/9999][ok]
# [Fetch][809/9999][ok]
# [Fetch][812/9999][ok]
# [Fetch][814/9999][ok]
# [Fetch][811/9999][ok]
# [Fetch][816/9999][ok]
# [Fetch][818/9999][ok]
# [Fetch][819/9999][ok]
# [Fetch][815/9999][ok]
# [Fetch][823/9999][ok]
# [Fetch][808/9999][ok]
# [Fetch][686/9999][ok]
# [Fetch][821/9999][ok]
# [Fetch][766/9999][ok]
# [Fetch][805/9999][ok]
# [Fetch][827/9999][ok]
# [Fetch][825/9999][ok]
# [Fetch][832/9999][ok]
# [Fetch][828/9999][ok]
# [Fetch][834/9999][ok]
# [Fetch][810/9999][ok]
# [Fetch][817/9999][ok]
# [Fetch][833/9999][ok][Fetch][830/9999][ok]
# [Fetch][835/9999][ok]
#
# [Fetch][820/9999][ok]
# [Fetch][839/9999][ok]
# [Fetch][829/9999][ok]
# [Fetch][844/9999][ok]
# [Fetch][837/9999][ok]
# [Fetch][841/9999][ok]
# [Fetch][836/9999][ok]
# [Fetch][845/9999][ok]
# [Fetch][843/9999][ok]
# [Fetch][850/9999][ok]
# [Fetch][848/9999][ok]
# [Fetch][849/9999][ok]
# [Fetch][851/9999][ok]
# [Fetch][847/9999][ok]
# [Fetch][842/9999][ok]
# [Fetch][855/9999][ok]
# [Fetch][826/9999][ok]
# [Fetch][853/9999][ok]
# [Fetch][852/9999][ok]
# [Fetch][856/9999][ok]
# [Fetch][854/9999][ok]
# [Fetch][822/9999][ok]
# [Fetch][846/9999][ok]
# [Fetch][840/9999][ok]
# [Fetch][857/9999][ok]
# [Fetch][831/9999][ok]
# [Fetch][838/9999][ok]
# [Fetch][861/9999][ok][Fetch][859/9999][ok]
#
# [Fetch][858/9999][ok]
# [Fetch][863/9999][ok]
# [Fetch][867/9999][ok]
# [Fetch][868/9999][ok]
# [Fetch][862/9999][ok]
# [Fetch][865/9999][ok]
# [Fetch][872/9999][ok]
# [Fetch][869/9999][ok]
# [Fetch][860/9999][ok]
# [Fetch][875/9999][ok]
# [Fetch][864/9999][ok]
# [Fetch][879/9999][ok]
# [Fetch][866/9999][ok]
# [Fetch][870/9999][ok]
# [Fetch][873/9999][ok]
# [Fetch][874/9999][ok]
# [Fetch][876/9999][ok][Fetch][871/9999][ok]
#
# [Fetch][878/9999][ok]
# [Fetch][887/9999][ok]
# [Fetch][881/9999][ok]
# [Fetch][880/9999][ok]
# [Fetch][884/9999][ok]
# [Fetch][883/9999][ok]
# [Fetch][877/9999][ok]
# [Fetch][890/9999][ok]
# [Fetch][888/9999][ok]
# [Fetch][889/9999][ok]
# [Fetch][882/9999][ok]
# [Fetch][895/9999][ok]
# [Fetch][891/9999][ok]
# [Fetch][901/9999][ok]
# [Fetch][897/9999][ok][Fetch][899/9999][ok]
#
# [Fetch][894/9999][ok]
# [Fetch][886/9999][ok]
# [Fetch][898/9999][ok]
# [Fetch][885/9999][ok]
# [Fetch][905/9999][ok]
# [Fetch][904/9999][ok]
# [Fetch][893/9999][ok]
# [Fetch][900/9999][ok]
# [Fetch][892/9999][ok]
# [Fetch][903/9999][ok]
# [Fetch][896/9999][ok]
# [Fetch][906/9999][ok]
# [Fetch][907/9999][ok]
# [Fetch][909/9999][ok]
# [Fetch][908/9999][ok]
# [Fetch][913/9999][ok]
# [Fetch][911/9999][ok]
# [Fetch][912/9999][ok]
# [Fetch][902/9999][ok]
# [Fetch][914/9999][ok]
# [Fetch][920/9999][ok]
# [Fetch][921/9999][ok]
# [Fetch][917/9999][ok]
# [Fetch][918/9999][ok]
# [Fetch][915/9999][ok]
# [Fetch][923/9999][ok]
# [Fetch][927/9999][ok]
# [Fetch][929/9999][ok]
# [Fetch][910/9999][ok]
# [Fetch][919/9999][ok]
# [Fetch][931/9999][ok]
# [Fetch][922/9999][ok]
# [Fetch][937/9999][ok]
# [Fetch][926/9999][ok]
# [Fetch][924/9999][ok]
# [Fetch][933/9999][ok]
# [Fetch][925/9999][ok]
# [Fetch][935/9999][ok]
# [Fetch][928/9999][ok]
# [Fetch][934/9999][ok]
# [Fetch][938/9999][ok]
# [Fetch][944/9999][ok][Fetch][936/9999][ok]
#
# [Fetch][941/9999][ok]
# [Fetch][943/9999][ok]
# [Fetch][932/9999][ok]
# [Fetch][916/9999][ok]
# [Fetch][946/9999][ok]
# [Fetch][945/9999][ok]
# [Fetch][942/9999][ok]
# [Fetch][940/9999][ok]
# [Fetch][939/9999][ok]
# [Fetch][948/9999][ok]
# [Fetch][949/9999][ok][Fetch][947/9999][ok]
#
# [Fetch][954/9999][ok]
# [Fetch][953/9999][ok]
# [Fetch][951/9999][ok]
# [Fetch][952/9999][ok]
# [Fetch][959/9999][ok]
# [Fetch][958/9999][ok]
# [Fetch][962/9999][ok]
# [Fetch][967/9999][ok]
# [Fetch][972/9999][ok]
# [Fetch][966/9999][ok]
# [Fetch][960/9999][ok]
# [Fetch][970/9999][ok][Fetch][950/9999][ok]
# [Fetch][973/9999][ok]
# [Fetch][955/9999][ok]
#
# [Fetch][957/9999][ok]
# [Fetch][975/9999][ok]
# [Fetch][956/9999][ok]
# [Fetch][930/9999][ok]
# [Fetch][961/9999][ok]
# [Fetch][969/9999][ok]
# [Fetch][976/9999][ok]
# [Fetch][977/9999][ok]
# [Fetch][965/9999][ok]
# [Fetch][968/9999][ok]
# [Fetch][978/9999][ok]
# [Fetch][971/9999][ok]
# [Fetch][974/9999][ok]
# [Fetch][980/9999][ok]
# [Fetch][982/9999][ok]
# [Fetch][981/9999][ok]
# [Fetch][983/9999][ok]
# [Fetch][824/9999][ok]
# [Fetch][964/9999][ok]
# [Fetch][985/9999][ok]
# [Fetch][987/9999][ok]
# [Fetch][986/9999][ok]
# [Fetch][988/9999][ok]
# [Fetch][963/9999][ok]
# [Fetch][984/9999][ok]
# [Fetch][992/9999][ok]
# [Fetch][989/9999][ok]
# [Fetch][979/9999][ok]
# [Fetch][994/9999][ok]
# [Fetch][996/9999][ok]
# [Fetch][990/9999][ok]
# [Fetch][998/9999][ok]
# [Fetch][993/9999][ok]
# [Fetch][997/9999][ok]
# [Fetch][995/9999][ok]
# [Fetch][1004/9999][ok]
# [Fetch][999/9999][ok]
# [Fetch][991/9999][ok]
# [Fetch][1000/9999][ok]
# [Fetch][1005/9999][ok]
# [Fetch][1002/9999][ok]
# [Fetch][1003/9999][ok]
# [Fetch][1007/9999][ok]
# [Fetch][1008/9999][ok]
# [Fetch][1014/9999][ok]
# [Fetch][1001/9999][ok]
# [Fetch][1013/9999][ok]
# [Fetch][1011/9999][ok]
# [Fetch][1012/9999][ok]
# [Fetch][1006/9999][ok]
# [Fetch][1018/9999][ok]
# [Fetch][1020/9999][ok]
# [Fetch][1024/9999][ok]
# [Fetch][1017/9999][ok]
# [Fetch][1019/9999][ok]
# [Fetch][1023/9999][ok]
# [Fetch][1022/9999][ok]
# [Fetch][1010/9999][ok]
# [Fetch][1026/9999][ok]
# [Fetch][1015/9999][ok]
# [Fetch][1027/9999][ok]
# [Fetch][1030/9999][ok]
# [Fetch][1034/9999][ok]
# [Fetch][1028/9999][ok]
# [Fetch][1035/9999][ok]
# [Fetch][1021/9999][ok]
# [Fetch][1037/9999][ok]
# [Fetch][1009/9999][ok]
# [Fetch][1025/9999][ok]
# [Fetch][1039/9999][ok]
# [Fetch][1038/9999][ok]
# [Fetch][1029/9999][ok]
# [Fetch][1032/9999][ok]
# [Fetch][1042/9999][ok]
# [Fetch][1031/9999][ok]
# [Fetch][1043/9999][ok]
# [Fetch][1041/9999][ok]
# [Fetch][1044/9999][ok]
# [Fetch][1040/9999][ok]
# [Fetch][1045/9999][ok]
# [Fetch][1050/9999][ok]
# [Fetch][1048/9999][ok]
# [Fetch][1053/9999][ok]
# [Fetch][1047/9999][ok]
# [Fetch][1051/9999][ok]
# [Fetch][1054/9999][ok]
# [Fetch][1056/9999][ok]
# [Fetch][1058/9999][ok]
# [Fetch][1046/9999][ok]
# [Fetch][1055/9999][ok]
# [Fetch][1057/9999][ok]
# [Fetch][1049/9999][ok]
# [Fetch][1059/9999][ok]
# [Fetch][1066/9999][ok]
# [Fetch][1052/9999][ok]
# [Fetch][1062/9999][ok]
# [Fetch][1070/9999][ok]
# [Fetch][1071/9999][ok]
# [Fetch][1060/9999][ok]
# [Fetch][1064/9999][ok]
# [Fetch][1016/9999][ok]
# [Fetch][1077/9999][ok]
# [Fetch][1078/9999][ok]
# [Fetch][1076/9999][ok]
# [Fetch][1079/9999][ok]
# [Fetch][1074/9999][ok]
# [Fetch][1082/9999][ok]
# [Fetch][1063/9999][ok]
# [Fetch][1072/9999][ok]
# [Fetch][1083/9999][ok]
# [Fetch][1065/9999][ok]
# [Fetch][1080/9999][ok]
# [Fetch][1086/9999][ok]
# [Fetch][1085/9999][ok]
# [Fetch][1033/9999][ok]
# [Fetch][1089/9999][ok]
# [Fetch][1084/9999][ok]
# [Fetch][1088/9999][ok]
# [Fetch][1068/9999][ok]
# [Fetch][1067/9999][ok]
# [Fetch][1061/9999][ok]
# [Fetch][1087/9999][ok]
# [Fetch][1073/9999][ok]
# [Fetch][1091/9999][ok]
# [Fetch][1090/9999][ok]
# [Fetch][1093/9999][ok]
# [Fetch][1094/9999][ok]
# [Fetch][1096/9999][ok]
# [Fetch][1036/9999][ok]
# [Fetch][1075/9999][ok]
# [Fetch][1092/9999][ok]
# [Fetch][1097/9999][ok]
# [Fetch][1098/9999][ok]
# [Fetch][1095/9999][ok]
# [Fetch][1102/9999][ok]
# [Fetch][1105/9999][ok]
# [Fetch][1099/9999][ok]
# [Fetch][1109/9999][ok]
# [Fetch][1104/9999][ok]
# [Fetch][1100/9999][ok]
# [Fetch][1112/9999][ok]
# [Fetch][1106/9999][ok]
# [Fetch][1107/9999][ok]
# [Fetch][1113/9999][ok]
# [Fetch][1069/9999][ok]
# [Fetch][1116/9999][ok]
# [Fetch][1115/9999][ok]
# [Fetch][1119/9999][ok]
# [Fetch][1108/9999][ok]
# [Fetch][1121/9999][ok]
# [Fetch][1114/9999][ok]
# [Fetch][1118/9999][ok]
# [Fetch][1103/9999][ok][Fetch][1111/9999][ok]
#
# [Fetch][1110/9999][ok]
# [Fetch][1124/9999][ok]
# [Fetch][1120/9999][ok]
# [Fetch][1125/9999][ok]
# [Fetch][1127/9999][ok]
# [Fetch][1123/9999][ok]
# [Fetch][1128/9999][ok]
# [Fetch][1130/9999][ok]
# [Fetch][1081/9999][ok]
# [Fetch][1133/9999][ok]
# [Fetch][1129/9999][ok]
# [Fetch][1135/9999][ok]
# [Fetch][1122/9999][ok]
# [Fetch][1132/9999][ok]
# [Fetch][1131/9999][ok]
# [Fetch][1126/9999][ok]
# [Fetch][1136/9999][ok]
# [Fetch][1117/9999][ok]
# [Fetch][1139/9999][ok]
# [Fetch][1137/9999][ok]
# [Fetch][1144/9999][ok]
# [Fetch][1101/9999][ok]
# [Fetch][1141/9999][ok]
# [Fetch][1142/9999][ok]
# [Fetch][1138/9999][ok]
# [Fetch][1155/9999][ok]
# [Fetch][1156/9999][ok]
# [Fetch][1152/9999][ok]
# [Fetch][1148/9999][ok]
# [Fetch][1160/9999][ok]
# [Fetch][1154/9999][ok]
# [Fetch][1153/9999][ok]
# [Fetch][1143/9999][ok]
# [Fetch][1157/9999][ok]
# [Fetch][1140/9999][ok]
# [Fetch][1147/9999][ok]
# [Fetch][1164/9999][ok]
# [Fetch][1146/9999][ok]
# [Fetch][1151/9999][ok]
# [Fetch][1134/9999][ok]
# [Fetch][1158/9999][ok]
# [Fetch][1159/9999][ok]
# [Fetch][1149/9999][ok]
# [Fetch][1150/9999][ok]
# [Fetch][1162/9999][ok]
# [Fetch][1171/9999][ok]
# [Fetch][1161/9999][ok]
# [Fetch][1163/9999][ok]
# [Fetch][1165/9999][ok]
# [Fetch][1145/9999][ok]
# [Fetch][1168/9999][ok]
# [Fetch][1173/9999][ok]
# [Fetch][1174/9999][ok]
# [Fetch][1175/9999][ok]
# [Fetch][1170/9999][ok]
# [Fetch][1172/9999][ok][Fetch][1169/9999][ok]
#
# [Fetch][1177/9999][ok]
# [Fetch][1179/9999][ok]
# [Fetch][1166/9999][ok]
# [Fetch][1176/9999][ok]
# [Fetch][1167/9999][ok]
# [Fetch][1182/9999][ok]
# [Fetch][1180/9999][ok]
# [Fetch][1183/9999][ok]
# [Fetch][1185/9999][ok]
# [Fetch][1189/9999][ok]
# [Fetch][1181/9999][ok]
# [Fetch][1178/9999][ok]
# [Fetch][1192/9999][ok]
# [Fetch][1186/9999][ok]
# [Fetch][1195/9999][ok]
# [Fetch][1191/9999][ok]
# [Fetch][1193/9999][ok][Fetch][1190/9999][ok]
# [Fetch][1184/9999][ok]
#
# [Fetch][1199/9999][ok]
# [Fetch][1187/9999][ok]
# [Fetch][1196/9999][ok]
# [Fetch][1188/9999][ok]
# [Fetch][1197/9999][ok]
# [Fetch][1200/9999][ok]
# [Fetch][1204/9999][ok]
# [Fetch][1202/9999][ok]
# [Fetch][1194/9999][ok][Fetch][1209/9999][ok]
#
# [Fetch][1203/9999][ok]
# [Fetch][1198/9999][ok]
# [Fetch][1206/9999][ok]
# [Fetch][1208/9999][ok]
# [Fetch][715/9999][ok]
# [Fetch][1211/9999][ok]
# [Fetch][1212/9999][ok]
# [Fetch][1205/9999][ok]
# [Fetch][1207/9999][ok]
# [Fetch][1218/9999][ok]
# [Fetch][1217/9999][ok]
# [Fetch][1210/9999][ok]
# [Fetch][1220/9999][ok]
# [Fetch][1215/9999][ok]
# [Fetch][1219/9999][ok]
# [Fetch][1216/9999][ok]
# [Fetch][1229/9999][ok]
# [Fetch][1225/9999][ok]
# [Fetch][1222/9999][ok]
# [Fetch][1228/9999][ok]
# [Fetch][1230/9999][ok]
# [Fetch][1221/9999][ok]
# [Fetch][1226/9999][ok]
# [Fetch][1224/9999][ok]
# [Fetch][1235/9999][ok]
# [Fetch][1236/9999][ok]
# [Fetch][1232/9999][ok]
# [Fetch][1231/9999][ok]
# [Fetch][1237/9999][ok]
# [Fetch][1223/9999][ok]
# [Fetch][1239/9999][ok]
# [Fetch][1240/9999][ok]
# [Fetch][1241/9999][ok]
# [Fetch][1213/9999][ok]
# [Fetch][1201/9999][ok]
# [Fetch][1234/9999][ok]
# [Fetch][1214/9999][ok]
# [Fetch][1249/9999][ok]
# [Fetch][1243/9999][ok]
# [Fetch][1247/9999][ok][Fetch][1242/9999][ok]
# [Fetch][1251/9999][ok]
#
# [Fetch][1246/9999][ok]
# [Fetch][1245/9999][ok]
# [Fetch][1248/9999][ok]
# [Fetch][1250/9999][ok]
# [Fetch][1252/9999][ok]
# [Fetch][1244/9999][ok]
# [Fetch][1254/9999][ok]
# [Fetch][1260/9999][ok]
# [Fetch][1258/9999][ok]
# [Fetch][1261/9999][ok]
# [Fetch][1256/9999][ok]
# [Fetch][1257/9999][ok]
# [Fetch][1259/9999][ok]
# [Fetch][1270/9999][ok]
# [Fetch][1265/9999][ok]
# [Fetch][1268/9999][ok]
# [Fetch][1253/9999][ok]
# [Fetch][1278/9999][ok]
# [Fetch][1255/9999][ok][Fetch][1262/9999][ok]
# [Fetch][1271/9999][ok]
# [Fetch][1266/9999][ok]
#
# [Fetch][1272/9999][ok]
# [Fetch][1281/9999][ok]
# [Fetch][1267/9999][ok]
# [Fetch][1269/9999][ok]
# [Fetch][1276/9999][ok]
# [Fetch][1277/9999][ok]
# [Fetch][1263/9999][ok]
# [Fetch][1233/9999][ok]
# [Fetch][1280/9999][ok][Fetch][1274/9999][ok]
#
# [Fetch][1288/9999][ok]
# [Fetch][1264/9999][ok]
# [Fetch][1282/9999][ok]
# [Fetch][1273/9999][ok]
# [Fetch][1275/9999][ok]
# [Fetch][1286/9999][ok]
# [Fetch][1284/9999][ok]
# [Fetch][1287/9999][ok]
# [Fetch][1283/9999][ok]
# [Fetch][1227/9999][ok]
# [Fetch][1279/9999][ok]
# [Fetch][1289/9999][ok]
# [Fetch][1290/9999][ok]
# [Fetch][1285/9999][ok]
# [Fetch][1292/9999][ok]
# [Fetch][1296/9999][ok]
# [Fetch][1293/9999][ok]
# [Fetch][1294/9999][ok]
# [Fetch][1300/9999][ok]
# [Fetch][1299/9999][ok]
# [Fetch][1291/9999][ok]
# [Fetch][1297/9999][ok]
# [Fetch][1298/9999][ok]
# [Fetch][1303/9999][ok]
# [Fetch][1295/9999][ok]
# [Fetch][1311/9999][ok]
# [Fetch][1302/9999][ok]
# [Fetch][1312/9999][ok]
# [Fetch][1310/9999][ok]
# [Fetch][1309/9999][ok]
# [Fetch][1305/9999][ok]
# [Fetch][1317/9999][ok]
# [Fetch][1319/9999][ok]
# [Fetch][1316/9999][ok]
# [Fetch][1321/9999][ok]
# [Fetch][1313/9999][ok]
# [Fetch][1325/9999][ok]
# [Fetch][1320/9999][ok]
# [Fetch][1323/9999][ok]
# [Fetch][1324/9999][ok]
# [Fetch][1304/9999][ok]
# [Fetch][1327/9999][ok]
# [Fetch][1307/9999][ok]
# [Fetch][1331/9999][ok]
# [Fetch][1326/9999][ok]
# [Fetch][1333/9999][ok]
# [Fetch][1332/9999][ok]
# [Fetch][1335/9999][ok]
# [Fetch][1238/9999][ok]
# [Fetch][1329/9999][ok]
# [Fetch][1334/9999][ok]
# [Fetch][1328/9999][ok]
# [Fetch][1336/9999][ok]
# [Fetch][1314/9999][ok]
# [Fetch][1337/9999][ok]
# [Fetch][1308/9999][ok]
# [Fetch][1315/9999][ok]
# [Fetch][1330/9999][ok]
# [Fetch][1340/9999][ok]
# [Fetch][1301/9999][ok]
# [Fetch][1342/9999][ok]
# [Fetch][1338/9999][ok]
# [Fetch][1339/9999][ok]
# [Fetch][1344/9999][ok]
# [Fetch][1343/9999][ok]
# [Fetch][1341/9999][ok]
# [Fetch][1347/9999][ok]
# [Fetch][1345/9999][ok]
# [Fetch][1356/9999][ok]
# [Fetch][1348/9999][ok]
# [Fetch][1354/9999][ok]
# [Fetch][1350/9999][ok]
# [Fetch][1346/9999][ok]
# [Fetch][1352/9999][ok]
# [Fetch][1306/9999][ok]
# [Fetch][1360/9999][ok]
# [Fetch][1365/9999][ok]
# [Fetch][1358/9999][ok]
# [Fetch][1357/9999][ok]
# [Fetch][1359/9999][ok]
# [Fetch][1371/9999][ok]
# [Fetch][1318/9999][ok]
# [Fetch][1366/9999][ok]
# [Fetch][1363/9999][ok]
# [Fetch][1367/9999][ok]
# [Fetch][1351/9999][ok]
# [Fetch][1353/9999][ok]
# [Fetch][1322/9999][ok]
# [Fetch][1370/9999][ok]
# [Fetch][1364/9999][ok]
# [Fetch][1361/9999][ok]
# [Fetch][1362/9999][ok]
# [Fetch][1349/9999][ok]
# [Fetch][1369/9999][ok]
# [Fetch][1376/9999][ok]
# [Fetch][1374/9999][ok]
# [Fetch][1372/9999][ok]
# [Fetch][1373/9999][ok]
# [Fetch][1368/9999][ok]
# [Fetch][1378/9999][ok]
# [Fetch][1377/9999][ok]
# [Fetch][1375/9999][ok]
# [Fetch][1384/9999][ok]
# [Fetch][1383/9999][ok]
# [Fetch][1380/9999][ok]
# [Fetch][1382/9999][ok]
# [Fetch][1386/9999][ok]
# [Fetch][1388/9999][ok]
# [Fetch][1387/9999][ok]
# [Fetch][1389/9999][ok][Fetch][1379/9999][ok]
#
# [Fetch][1381/9999][ok]
# [Fetch][1391/9999][ok]
# [Fetch][1397/9999][ok]
# [Fetch][1394/9999][ok]
# [Fetch][1400/9999][ok]
# [Fetch][1393/9999][ok]
# [Fetch][1406/9999][ok]
# [Fetch][1395/9999][ok]
# [Fetch][1403/9999][ok]
# [Fetch][1405/9999][ok]
# [Fetch][1390/9999][ok]
# [Fetch][1399/9999][ok]
# [Fetch][1398/9999][ok]
# [Fetch][1385/9999][ok]
# [Fetch][1408/9999][ok]
# [Fetch][1410/9999][ok]
# [Fetch][1404/9999][ok]
# [Fetch][1401/9999][ok]
# [Fetch][1396/9999][ok]
# [Fetch][1416/9999][ok]
# [Fetch][1407/9999][ok]
# [Fetch][1414/9999][ok]
# [Fetch][1415/9999][ok]
# [Fetch][1409/9999][ok]
# [Fetch][1418/9999][ok]
# [Fetch][1420/9999][ok]
# [Fetch][1412/9999][ok]
# [Fetch][1392/9999][ok]
# [Fetch][1421/9999][ok]
# [Fetch][1419/9999][ok]
# [Fetch][1402/9999][ok]
# [Fetch][1413/9999][ok]
# [Fetch][1417/9999][ok]
# [Fetch][1411/9999][ok]
# [Fetch][1423/9999][ok]
# [Fetch][1422/9999][ok]
# [Fetch][1428/9999][ok]
# [Fetch][1425/9999][ok]
# [Fetch][1426/9999][ok]
# [Fetch][1433/9999][ok]
# [Fetch][1355/9999][ok]
# [Fetch][1424/9999][ok]
# [Fetch][1431/9999][ok]
# [Fetch][1430/9999][ok]
# [Fetch][1440/9999][ok]
# [Fetch][1435/9999][ok]
# [Fetch][1437/9999][ok]
# [Fetch][1429/9999][ok]
# [Fetch][1442/9999][ok]
# [Fetch][1432/9999][ok]
# [Fetch][1439/9999][ok]
# [Fetch][1446/9999][ok]
# [Fetch][1450/9999][ok]
# [Fetch][1427/9999][ok]
# [Fetch][1447/9999][ok]
# [Fetch][1444/9999][ok]
# [Fetch][1445/9999][ok]
# [Fetch][1452/9999][ok]
# [Fetch][1448/9999][ok]
# [Fetch][1454/9999][ok][Fetch][1438/9999][ok]
#
# [Fetch][1434/9999][ok]
# [Fetch][1455/9999][ok]
# [Fetch][1459/9999][ok]
# [Fetch][1436/9999][ok]
# [Fetch][1463/9999][ok]
# [Fetch][1443/9999][ok]
# [Fetch][1449/9999][ok]
# [Fetch][1467/9999][ok]
# [Fetch][1464/9999][ok]
# [Fetch][1461/9999][ok]
# [Fetch][1458/9999][ok]
# [Fetch][1466/9999][ok]
# [Fetch][1469/9999][ok]
# [Fetch][1451/9999][ok]
# [Fetch][1468/9999][ok]
# [Fetch][1456/9999][ok]
# [Fetch][1472/9999][ok]
# [Fetch][1462/9999][ok]
# [Fetch][1470/9999][ok]
# [Fetch][1453/9999][ok]
# [Fetch][1471/9999][ok]
# [Fetch][1457/9999][ok]
# [Fetch][1475/9999][ok]
# [Fetch][1481/9999][ok]
# [Fetch][1465/9999][ok]
# [Fetch][1476/9999][ok]
# [Fetch][1479/9999][ok]
# [Fetch][1460/9999][ok]
# [Fetch][1483/9999][ok]
# [Fetch][1478/9999][ok]
# [Fetch][1477/9999][ok]
# [Fetch][1480/9999][ok]
# [Fetch][1473/9999][ok]
# [Fetch][1484/9999][ok]
# [Fetch][1482/9999][ok]
# [Fetch][1485/9999][ok]
# [Fetch][1489/9999][ok]
# [Fetch][1474/9999][ok]
# [Fetch][1488/9999][ok]
# [Fetch][1490/9999][ok]
# [Fetch][1487/9999][ok]
# [Fetch][1496/9999][ok]
# [Fetch][1494/9999][ok]
# [Fetch][1486/9999][ok]
# [Fetch][1441/9999][ok]
# [Fetch][1492/9999][ok]
# [Fetch][1493/9999][ok]
# [Fetch][1491/9999][ok]
# [Fetch][1495/9999][ok]
# [Fetch][1497/9999][ok]
# [Fetch][1502/9999][ok]
# [Fetch][1501/9999][ok]
# [Fetch][1503/9999][ok]
# [Fetch][1512/9999][ok]
# [Fetch][1498/9999][ok]
# [Fetch][1516/9999][ok]
# [Fetch][1506/9999][ok]
# [Fetch][1509/9999][ok]
# [Fetch][1518/9999][ok]
# [Fetch][1515/9999][ok]
# [Fetch][1508/9999][ok]
# [Fetch][1519/9999][ok]
# [Fetch][1523/9999][ok]
# [Fetch][1510/9999][ok]
# [Fetch][1505/9999][ok]
# [Fetch][1504/9999][ok]
# [Fetch][1520/9999][ok]
# [Fetch][1517/9999][ok]
# [Fetch][1514/9999][ok]
# [Fetch][1513/9999][ok]
# [Fetch][1522/9999][ok]
# [Fetch][1521/9999][ok]
# [Fetch][1528/9999][ok]
# [Fetch][1527/9999][ok]
# [Fetch][1530/9999][ok]
# [Fetch][1511/9999][ok]
# [Fetch][1529/9999][ok]
# [Fetch][1500/9999][ok]
# [Fetch][1534/9999][ok]
# [Fetch][1532/9999][ok]
# [Fetch][1531/9999][ok]
# [Fetch][1545/9999][ok]
# [Fetch][1542/9999][ok]
# [Fetch][1539/9999][ok][Fetch][1537/9999][ok]
#
# [Fetch][1550/9999][ok]
# [Fetch][1541/9999][ok]
# [Fetch][1499/9999][ok]
# [Fetch][1540/9999][ok]
# [Fetch][1547/9999][ok]
# [Fetch][1544/9999][ok]
# [Fetch][1543/9999][ok]
# [Fetch][1535/9999][ok]
# [Fetch][1546/9999][ok]
# [Fetch][1533/9999][ok]
# [Fetch][1525/9999][ok]
# [Fetch][1551/9999][ok]
# [Fetch][1552/9999][ok]
# [Fetch][1549/9999][ok]
# [Fetch][1553/9999][ok]
# [Fetch][1507/9999][ok]
# [Fetch][1555/9999][ok]
# [Fetch][1554/9999][ok]
# [Fetch][1556/9999][ok]
# [Fetch][1559/9999][ok]
# [Fetch][1560/9999][ok]
# [Fetch][1562/9999][ok]
# [Fetch][1536/9999][ok]
# [Fetch][1564/9999][ok]
# [Fetch][1565/9999][ok]
# [Fetch][1561/9999][ok]
# [Fetch][1563/9999][ok]
# [Fetch][1569/9999][ok]
# [Fetch][1526/9999][ok]
# [Fetch][1558/9999][ok]
# [Fetch][1571/9999][ok]
# [Fetch][1573/9999][ok]
# [Fetch][1538/9999][ok]
# [Fetch][1548/9999][ok]
# [Fetch][1568/9999][ok]
# [Fetch][1570/9999][ok]
# [Fetch][1572/9999][ok]
# [Fetch][1579/9999][ok]
# [Fetch][1580/9999][ok]
# [Fetch][1575/9999][ok]
# [Fetch][1576/9999][ok]
# [Fetch][1581/9999][ok]
# [Fetch][1566/9999][ok]
# [Fetch][1582/9999][ok]
# [Fetch][1577/9999][ok]
# [Fetch][1585/9999][ok]
# [Fetch][1574/9999][ok]
# [Fetch][1557/9999][ok]
# [Fetch][1584/9999][ok]
# [Fetch][1586/9999][ok]
# [Fetch][1567/9999][ok]
# [Fetch][1590/9999][ok]
# [Fetch][1591/9999][ok]
# [Fetch][1583/9999][ok]
# [Fetch][1593/9999][ok]
# [Fetch][1592/9999][ok]
# [Fetch][1595/9999][ok]
# [Fetch][1596/9999][ok]
# [Fetch][1597/9999][ok]
# [Fetch][1598/9999][ok]
# [Fetch][1601/9999][ok]
# [Fetch][1602/9999][ok]
# [Fetch][1587/9999][ok]
# [Fetch][1604/9999][ok]
# [Fetch][1599/9999][ok]
# [Fetch][1594/9999][ok]
# [Fetch][1603/9999][ok]
# [Fetch][1609/9999][ok]
# [Fetch][1588/9999][ok]
# [Fetch][1589/9999][ok]
# [Fetch][1610/9999][ok]
# [Fetch][1620/9999][ok]
# [Fetch][1618/9999][ok]
# [Fetch][1616/9999][ok]
# [Fetch][1623/9999][ok]
# [Fetch][1605/9999][ok]
# [Fetch][1622/9999][ok]
# [Fetch][1612/9999][ok]
# [Fetch][1606/9999][ok]
# [Fetch][1629/9999][ok][Fetch][1625/9999][ok]
#
# [Fetch][1607/9999][ok]
# [Fetch][1630/9999][ok]
# [Fetch][1619/9999][ok]
# [Fetch][1600/9999][ok]
# [Fetch][1614/9999][ok]
# [Fetch][1617/9999][ok]
# [Fetch][1624/9999][ok]
# [Fetch][1631/9999][ok]
# [Fetch][1626/9999][ok]
# [Fetch][1636/9999][ok]
# [Fetch][1632/9999][ok]
# [Fetch][1634/9999][ok]
# [Fetch][1615/9999][ok]
# [Fetch][1635/9999][ok]
# [Fetch][1627/9999][ok]
# [Fetch][1628/9999][ok]
# [Fetch][1633/9999][ok]
# [Fetch][1613/9999][ok]
# [Fetch][1637/9999][ok]
# [Fetch][1643/9999][ok]
# [Fetch][1640/9999][ok]
# [Fetch][1638/9999][ok]
# [Fetch][1641/9999][ok]
# [Fetch][1639/9999][ok]
# [Fetch][1646/9999][ok]
# [Fetch][1621/9999][ok]
# [Fetch][1652/9999][ok]
# [Fetch][1611/9999][ok]
# [Fetch][1644/9999][ok]
# [Fetch][1645/9999][ok]
# [Fetch][1647/9999][ok]
# [Fetch][1651/9999][ok]
# [Fetch][1642/9999][ok]
# [Fetch][1649/9999][ok]
# [Fetch][1648/9999][ok]
# [Fetch][1654/9999][ok]
# [Fetch][1650/9999][ok]
# [Fetch][1653/9999][ok]
# [Fetch][1655/9999][ok]
# [Fetch][1663/9999][ok]
# [Fetch][1658/9999][ok]
# [Fetch][1660/9999][ok]
# [Fetch][1656/9999][ok]
# [Fetch][1661/9999][ok]
# [Fetch][1657/9999][ok]
# [Fetch][1659/9999][ok]
# [Fetch][1666/9999][ok]
# [Fetch][1662/9999][ok]
# [Fetch][1608/9999][ok]
# [Fetch][1664/9999][ok]
# [Fetch][1668/9999][ok]
# [Fetch][1667/9999][ok]
# [Fetch][1669/9999][ok]
# [Fetch][1671/9999][ok]
# [Fetch][1673/9999][ok]
# [Fetch][1674/9999][ok]
# [Fetch][1665/9999][ok]
# [Fetch][1672/9999][ok]
# [Fetch][1677/9999][ok]
# [Fetch][1675/9999][ok]
# [Fetch][1684/9999][ok]
# [Fetch][1682/9999][ok]
# [Fetch][1688/9999][ok]
# [Fetch][1679/9999][ok]
# [Fetch][1691/9999][ok]
# [Fetch][1676/9999][ok]
# [Fetch][1683/9999][ok]
# [Fetch][1686/9999][ok]
# [Fetch][1687/9999][ok]
# [Fetch][1693/9999][ok]
# [Fetch][1680/9999][ok]
# [Fetch][1689/9999][ok]
# [Fetch][1681/9999][ok]
# [Fetch][1685/9999][ok]
# [Fetch][1690/9999][ok]
# [Fetch][1670/9999][ok]
# [Fetch][1696/9999][ok]
# [Fetch][1692/9999][ok]
# [Fetch][1697/9999][ok]
# [Fetch][1700/9999][ok]
# [Fetch][1699/9999][ok]
# [Fetch][1701/9999][ok]
# [Fetch][1695/9999][ok]
# [Fetch][1703/9999][ok]
# [Fetch][1704/9999][ok]
# [Fetch][1694/9999][ok]
# [Fetch][1702/9999][ok]
# [Fetch][1705/9999][ok]
# [Fetch][1706/9999][ok]
# [Fetch][1678/9999][ok]
# [Fetch][1707/9999][ok]
# [Fetch][1698/9999][ok]
# [Fetch][1709/9999][ok]
# [Fetch][1708/9999][ok]
# [Fetch][1712/9999][ok]
# [Fetch][1720/9999][ok]
# [Fetch][1713/9999][ok]
# [Fetch][1717/9999][ok]
# [Fetch][1715/9999][ok]
# [Fetch][1719/9999][ok]
# [Fetch][1718/9999][ok]
# [Fetch][1722/9999][ok]
# [Fetch][1714/9999][ok]
# [Fetch][1727/9999][ok]
# [Fetch][1723/9999][ok]
# [Fetch][1730/9999][ok]
# [Fetch][1710/9999][ok]
# [Fetch][1724/9999][ok]
# [Fetch][1733/9999][ok]
# [Fetch][1725/9999][ok]
# [Fetch][1728/9999][ok]
# [Fetch][1731/9999][ok]
# [Fetch][1729/9999][ok]
# [Fetch][1737/9999][ok]
# [Fetch][1732/9999][ok]
# [Fetch][1736/9999][ok]
# [Fetch][1734/9999][ok]
# [Fetch][1721/9999][ok]
# [Fetch][1739/9999][ok]
# [Fetch][1726/9999][ok]
# [Fetch][1711/9999][ok]
# [Fetch][1738/9999][ok]
# [Fetch][1735/9999][ok]
# [Fetch][1744/9999][ok]
# [Fetch][1524/9999][ok]
# [Fetch][1716/9999][ok]
# [Fetch][1747/9999][ok]
# [Fetch][1740/9999][ok]
# [Fetch][1743/9999][ok]
# [Fetch][1753/9999][ok]
# [Fetch][1741/9999][ok]
# [Fetch][1748/9999][ok]
# [Fetch][1752/9999][ok]
# [Fetch][1749/9999][ok]
# [Fetch][1751/9999][ok]
# [Fetch][1756/9999][ok]
# [Fetch][1750/9999][ok]
# [Fetch][1742/9999][ok]
# [Fetch][1761/9999][ok]
# [Fetch][1759/9999][ok]
# [Fetch][1768/9999][ok]
# [Fetch][1754/9999][ok]
# [Fetch][1746/9999][ok]
# [Fetch][1745/9999][ok]
# [Fetch][1763/9999][ok]
# [Fetch][1755/9999][ok]
# [Fetch][1758/9999][ok]
# [Fetch][1757/9999][ok]
# [Fetch][1764/9999][ok]
# [Fetch][1760/9999][ok]
# [Fetch][1766/9999][ok]
# [Fetch][1767/9999][ok]
# [Fetch][1775/9999][ok]
# [Fetch][1765/9999][ok]
# [Fetch][1770/9999][ok]
# [Fetch][1771/9999][ok]
# [Fetch][1762/9999][ok]
# [Fetch][1774/9999][ok]
# [Fetch][1777/9999][ok]
# [Fetch][1778/9999][ok]
# [Fetch][1773/9999][ok]
# [Fetch][1776/9999][ok]
# [Fetch][1782/9999][ok]
# [Fetch][1772/9999][ok][Fetch][1781/9999][ok]
#
# [Fetch][1779/9999][ok]
# [Fetch][1783/9999][ok]
# [Fetch][1780/9999][ok]
# [Fetch][1785/9999][ok]
# [Fetch][1784/9999][ok]
# [Fetch][1786/9999][ok]
# [Fetch][1789/9999][ok]
# [Fetch][1796/9999][ok]
# [Fetch][1787/9999][ok]
# [Fetch][1790/9999][ok]
# [Fetch][1788/9999][ok]
# [Fetch][1795/9999][ok]
# [Fetch][1797/9999][ok]
# [Fetch][1792/9999][ok]
# [Fetch][1769/9999][ok]
# [Fetch][1793/9999][ok]
# [Fetch][1803/9999][ok]
# [Fetch][1802/9999][ok]
# [Fetch][1815/9999][ok]
# [Fetch][1812/9999][ok]
# [Fetch][1814/9999][ok]
# [Fetch][1806/9999][ok]
# [Fetch][1805/9999][ok]
# [Fetch][1810/9999][ok]
# [Fetch][1791/9999][ok]
# [Fetch][1807/9999][ok]
# [Fetch][1799/9999][ok]
# [Fetch][1808/9999][ok]
# [Fetch][1804/9999][ok]
# [Fetch][1816/9999][ok]
# [Fetch][1817/9999][ok]
# [Fetch][1825/9999][ok]
# [Fetch][1794/9999][ok]
# [Fetch][1801/9999][ok]
# [Fetch][1809/9999][ok]
# [Fetch][1823/9999][ok]
# [Fetch][1818/9999][ok]
# [Fetch][1822/9999][ok]
# [Fetch][1800/9999][ok]
# [Fetch][1828/9999][ok]
# [Fetch][1833/9999][ok]
# [Fetch][1827/9999][ok]
# [Fetch][1829/9999][ok]
# [Fetch][1835/9999][ok]
# [Fetch][1826/9999][ok]
# [Fetch][1838/9999][ok]
# [Fetch][1821/9999][ok]
# [Fetch][1839/9999][ok][Fetch][1842/9999][ok]
# [Fetch][1834/9999][ok]
# [Fetch][1830/9999][ok]
#
# [Fetch][1811/9999][ok]
# [Fetch][1819/9999][ok]
# [Fetch][1837/9999][ok]
# [Fetch][1820/9999][ok]
# [Fetch][1824/9999][ok]
# [Fetch][1844/9999][ok]
# [Fetch][1798/9999][ok]
# [Fetch][1836/9999][ok]
# [Fetch][1831/9999][ok]
# [Fetch][1843/9999][ok]
# [Fetch][1846/9999][ok]
# [Fetch][1845/9999][ok]
# [Fetch][1847/9999][ok]
# [Fetch][1852/9999][ok]
# [Fetch][1848/9999][ok]
# [Fetch][1840/9999][ok]
# [Fetch][1851/9999][ok]
# [Fetch][1854/9999][ok]
# [Fetch][1853/9999][ok]
# [Fetch][1850/9999][ok]
# [Fetch][1849/9999][ok]
# [Fetch][1856/9999][ok]
# [Fetch][1858/9999][ok]
# [Fetch][1864/9999][ok]
# [Fetch][1862/9999][ok]
# [Fetch][1841/9999][ok]
# [Fetch][1857/9999][ok]
# [Fetch][1861/9999][ok]
# [Fetch][1865/9999][ok]
# [Fetch][1860/9999][ok]
# [Fetch][1859/9999][ok]
# [Fetch][1866/9999][ok]
# [Fetch][1863/9999][ok]
# [Fetch][1868/9999][ok]
# [Fetch][1871/9999][ok]
# [Fetch][1875/9999][ok]
# [Fetch][1872/9999][ok]
# [Fetch][1874/9999][ok]
# [Fetch][1876/9999][ok]
# [Fetch][1870/9999][ok]
# [Fetch][1869/9999][ok]
# [Fetch][1873/9999][ok]
# [Fetch][1867/9999][ok]
# [Fetch][1881/9999][ok]
# [Fetch][1880/9999][ok]
# [Fetch][1885/9999][ok]
# [Fetch][1882/9999][ok]
# [Fetch][1878/9999][ok]
# [Fetch][1883/9999][ok]
# [Fetch][1889/9999][ok]
# [Fetch][1832/9999][ok]
# [Fetch][1887/9999][ok]
# [Fetch][1884/9999][ok]
# [Fetch][1894/9999][ok]
# [Fetch][1879/9999][ok]
# [Fetch][1891/9999][ok]
# [Fetch][1578/9999][ok]
# [Fetch][1890/9999][ok]
# [Fetch][1888/9999][ok]
# [Fetch][1893/9999][ok]
# [Fetch][1886/9999][ok]
# [Fetch][1892/9999][ok]
# [Fetch][1877/9999][ok]
# [Fetch][1855/9999][ok]
# [Fetch][1895/9999][ok]
# [Fetch][1896/9999][ok]
# [Fetch][1899/9999][ok]
# [Fetch][1900/9999][ok]
# [Fetch][1897/9999][ok]
# [Fetch][1903/9999][ok]
# [Fetch][1901/9999][ok]
# [Fetch][1905/9999][ok]
# [Fetch][1902/9999][ok]
# [Fetch][1898/9999][ok]
# [Fetch][1907/9999][ok]
# [Fetch][1904/9999][ok]
# [Fetch][1908/9999][ok]
# [Fetch][1910/9999][ok]
# [Fetch][1909/9999][ok]
# [Fetch][1919/9999][ok]
# [Fetch][1906/9999][ok]
# [Fetch][1917/9999][ok]
# [Fetch][1914/9999][ok]
# [Fetch][1915/9999][ok]
# [Fetch][1911/9999][ok]
# [Fetch][1924/9999][ok]
# [Fetch][1922/9999][ok]
# [Fetch][1918/9999][ok]
# [Fetch][1920/9999][ok]
# [Fetch][1930/9999][ok]
# [Fetch][1923/9999][ok]
# [Fetch][1916/9999][ok]
# [Fetch][1928/9999][ok]
# [Fetch][1927/9999][ok]
# [Fetch][1938/9999][ok]
# [Fetch][1929/9999][ok]
# [Fetch][1912/9999][ok]
# [Fetch][1921/9999][ok]
# [Fetch][1936/9999][ok]
# [Fetch][1933/9999][ok]
# [Fetch][1937/9999][ok]
# [Fetch][1932/9999][ok]
# [Fetch][1931/9999][ok]
# [Fetch][1925/9999][ok]
# [Fetch][1926/9999][ok]
# [Fetch][1935/9999][ok]
# [Fetch][1813/9999][ok]
# [Fetch][1913/9999][ok]
# [Fetch][1939/9999][ok]
# [Fetch][1934/9999][ok]
# [Fetch][1941/9999][ok]
# [Fetch][1947/9999][ok]
# [Fetch][1940/9999][ok]
# [Fetch][1944/9999][ok]
# [Fetch][1945/9999][ok]
# [Fetch][1951/9999][ok]
# [Fetch][1949/9999][ok]
# [Fetch][1948/9999][ok]
# [Fetch][1950/9999][ok]
# [Fetch][1946/9999][ok]
# [Fetch][1952/9999][ok]
# [Fetch][1954/9999][ok]
# [Fetch][1957/9999][ok]
# [Fetch][1942/9999][ok]
# [Fetch][1953/9999][ok]
# [Fetch][1959/9999][ok]
# [Fetch][1943/9999][ok]
# [Fetch][1967/9999][ok]
# [Fetch][1962/9999][ok]
# [Fetch][1961/9999][ok]
# [Fetch][1955/9999][ok]
# [Fetch][1960/9999][ok]
# [Fetch][1966/9999][ok]
# [Fetch][1965/9999][ok]
# [Fetch][1956/9999][ok]
# [Fetch][1963/9999][ok]
# [Fetch][1972/9999][ok]
# [Fetch][1969/9999][ok]
# [Fetch][1970/9999][ok]
# [Fetch][1968/9999][ok]
# [Fetch][1958/9999][ok]
# [Fetch][1973/9999][ok]
# [Fetch][1971/9999][ok]
# [Fetch][1978/9999][ok]
# [Fetch][1974/9999][ok]
# [Fetch][1976/9999][ok]
# [Fetch][1980/9999][ok]
# [Fetch][1985/9999][ok]
# [Fetch][1975/9999][ok]
# [Fetch][1983/9999][ok]
# [Fetch][1982/9999][ok]
# [Fetch][1979/9999][ok]
# [Fetch][1987/9999][ok]
# [Fetch][1984/9999][ok]
# [Fetch][1991/9999][ok]
# [Fetch][1988/9999][ok]
# [Fetch][1993/9999][ok]
# [Fetch][1992/9999][ok]
# [Fetch][1981/9999][ok]
# [Fetch][1996/9999][ok]
# [Fetch][1977/9999][ok]
# [Fetch][1964/9999][ok]
# [Fetch][1995/9999][ok]
# [Fetch][1998/9999][ok]
# [Fetch][1997/9999][ok]
# [Fetch][2000/9999][ok]
# [Fetch][1990/9999][ok]
# [Fetch][1989/9999][ok]
# [Fetch][1986/9999][ok]
# [Fetch][2003/9999][ok]
# [Fetch][2002/9999][ok]
# [Fetch][2001/9999][ok]
# [Fetch][2006/9999][ok]
# [Fetch][2004/9999][ok]
# [Fetch][2009/9999][ok]
# [Fetch][2010/9999][ok]
# [Fetch][2016/9999][ok]
# [Fetch][2011/9999][ok]
# [Fetch][2019/9999][ok]
# [Fetch][2007/9999][ok]
# [Fetch][1994/9999][ok]
# [Fetch][2014/9999][ok]
# [Fetch][2005/9999][ok]
# [Fetch][2020/9999][ok]
# [Fetch][2013/9999][ok]
# [Fetch][2017/9999][ok]
# [Fetch][2021/9999][ok]
# [Fetch][2012/9999][ok]
# [Fetch][2026/9999][ok]
# [Fetch][2018/9999][ok]
# [Fetch][2022/9999][ok]
# [Fetch][2008/9999][ok]
# [Fetch][2023/9999][ok]
# [Fetch][2025/9999][ok]
# [Fetch][2030/9999][ok]
# [Fetch][2028/9999][ok]
# [Fetch][2027/9999][ok]
# [Fetch][2015/9999][ok]
# [Fetch][2029/9999][ok]
# [Fetch][2035/9999][ok]
# [Fetch][2032/9999][ok]
# [Fetch][2037/9999][ok]
# [Fetch][2034/9999][ok]
# [Fetch][2024/9999][ok]
# [Fetch][2033/9999][ok]
# [Fetch][1999/9999][ok]
# [Fetch][2041/9999][ok]
# [Fetch][2038/9999][ok]
# [Fetch][2036/9999][ok]
# [Fetch][2039/9999][ok]
# [Fetch][2043/9999][ok]
# [Fetch][2045/9999][ok]
# [Fetch][2044/9999][ok]
# [Fetch][2031/9999][ok]
# [Fetch][2050/9999][ok]
# [Fetch][2048/9999][ok]
# [Fetch][2047/9999][ok]
# [Fetch][2052/9999][ok]
# [Fetch][2046/9999][ok]
# [Fetch][2054/9999][ok]
# [Fetch][2051/9999][ok]
# [Fetch][2059/9999][ok]
# [Fetch][2061/9999][ok]
# [Fetch][2042/9999][ok]
# [Fetch][2040/9999][ok]
# [Fetch][2053/9999][ok]
# [Fetch][2049/9999][ok]
# [Fetch][2057/9999][ok]
# [Fetch][2064/9999][ok]
# [Fetch][2062/9999][ok]
# [Fetch][2066/9999][ok]
# [Fetch][2067/9999][ok]
# [Fetch][2058/9999][ok]
# [Fetch][2063/9999][ok]
# [Fetch][2069/9999][ok]
# [Fetch][2068/9999][ok]
# [Fetch][2070/9999][ok]
# [Fetch][2065/9999][ok]
# [Fetch][2072/9999][ok]
# [Fetch][2060/9999][ok]
# [Fetch][2073/9999][ok]
# [Fetch][2079/9999][ok]
# [Fetch][2075/9999][ok]
# [Fetch][2082/9999][ok]
# [Fetch][2071/9999][ok]
# [Fetch][2087/9999][ok]
# [Fetch][2077/9999][ok]
# [Fetch][2081/9999][ok]
# [Fetch][2089/9999][ok]
# [Fetch][2093/9999][ok]
# [Fetch][2056/9999][ok]
# [Fetch][2084/9999][ok]
# [Fetch][2074/9999][ok]
# [Fetch][2078/9999][ok]
# [Fetch][2076/9999][ok]
# [Fetch][2090/9999][ok]
# [Fetch][2091/9999][ok]
# [Fetch][2086/9999][ok]
# [Fetch][2085/9999][ok]
# 9998  https://www.investing.com/news/economy/musk-sa...  0.095  0.816  0.089
#
#       compound
# 0       0.7906
# 1       0.8316
# 2       0.8235
# 3       0.7650
# 4       0.7654
# ...        ...
# 9994   -0.3973
# 9995    0.9884
# 9996   -0.9371
# 9997   -0.8437
# 9998   -0.4215
#
# [9999 rows x 10 columns]

# %%
#sort by publish_date and publish_time
df = df.sort_values(by=['publish_date', 'publish_time'], ascending=[False,False]).reset_index(drop=True)

# %%
pd.set_option('display.max_columns', None)

# %%
# Count empty body_text entries
empty_body_count = df[df['body_text'] == ''].shape[0]
print(f"Number of articles with empty body_text: {empty_body_count}")
# Out:
# Number of articles with empty body_text: 0

# %%
df
# Out:
#      ticker publish_date publish_time  \
# 0      TSLA   2025-05-05        17:59
# 1      TSLA   2025-05-05        04:49
# 2      TSLA   2025-05-05        01:20
# 3      TSLA   2025-05-03        08:27
# 4      TSLA   2025-05-03        06:10
# ...     ...          ...          ...
# 9994   TSLA   2022-07-13        03:59
# 9995   TSLA   2022-07-12        19:12
# 9996   TSLA   2022-07-12        17:04
# 9997   TSLA   2022-07-12        02:34
# 9998   TSLA   2018-04-03        16:00
#
#                                                   title  \
# 0                             Error 404: Page Not Found
# 1     Wall Street analyst says Tesla and its mission...
# 2         Musk says AI should replace some govt workers
# 3     Can Tesla help the U.S. catch up to China in t...
# 4     Factbox-Warren Buffett and Berkshire Hathaway ...
# ...                                                 ...
# 9994  Exclusive: Tesla supplier Panasonic eyes 20% j...
# 9995  Dow Futures Tick Higher Ahead of Key Inflation...
# 9996  Twitter sues Elon Musk to hold him to $44 bill...
# 9997  Trump steps up attacks on Musk, who said Trump...
# 9998  Insmed PT Raised to $70 at H.C. Wainwright By ...
#
#                                               body_text  \
# 0     404\n\nPage Not Found\n\nSeems like the page y...
# 1     Investing.com -- Tesla’s near $1 trillion valu...
# 2     Investing.com-- Elon Musk advocated for levera...
# 3     Investing.com -- Tesla (NASDAQ: ) could play a...
# 4     By Jonathan Stempel\n\nOMAHA, Nebraska (Reuter...
# ...                                                 ...
# 9994  By Norihiko Shirouzu\n\n(Reuters) - Panasonic ...
# 9995  By Oliver Gray\n\nInvesting.com - U.S. stock f...
# 9996  By Tom Hals\n\nWILMINGTON, Del. (Reuters) - Tw...
# 9997  (Reuters) - Donald Trump on Tuesday ratcheted ...
# 9998  (Updated - May 29, 2024 6:04 AM EDT)\n\nH.C. W...
#
#                                                     url    neg    neu    pos  \
# 0     https://www.investing.com/news/stock-market-ne...  0.140  0.860  0.000
# 1     https://www.investing.com/news/stock-market-ne...  0.046  0.847  0.107
# 2     https://www.investing.com/news/economy-news/mu...  0.023  0.888  0.089
# 3     https://www.investing.com/news/stock-market-ne...  0.004  0.887  0.109
# 4     https://www.investing.com/news/stock-market-ne...  0.038  0.889  0.073
# ...                                                 ...    ...    ...    ...
# 9994  https://www.investing.com/news/stock-market-ne...  0.042  0.817  0.141
# 9995  https://www.investing.com/news/stock-market-ne...  0.046  0.895  0.059
# 9996  https://www.investing.com/news/economy/twitter...  0.101  0.822  0.077
# 9997  https://www.investing.com/news/stock-market-ne...  0.055  0.888  0.057
# 9998    0.9882
#
# [9999 rows x 10 columns]

# %%
# 1. แปลงคอลัมน์ publish_date เป็น datetime
article_sentiments['publish_date'] = pd.to_datetime(article_sentiments['publish_date'], errors='coerce')

# 2. แปลงคอลัมน์ publish_time เป็นเวลา (datetime.time)
article_sentiments['publish_time'] = pd.to_datetime(article_sentiments['publish_time'], format='%H:%M', errors='coerce').dt.time

article_sentiments['publish_datetime'] = pd.to_datetime(
    article_sentiments['publish_date'].astype(str) + ' ' + article_sentiments['publish_time'].astype(str),
    errors='coerce'
)

# %%
# สมมติว่า df คือ DataFrame ที่ได้จากการ scrape
# ตัวอย่างการโหลดไฟล์ pickle (ปรับ path ให้ตรงกับไฟล์ของคุณ)
# df = pd.read_pickle('/mnt/data/your_file.pkl')


def remove_html(text):
    if isinstance(text, str):
        return BeautifulSoup(text, "html.parser").get_text()
    return text

def remove_ads(text):
    if isinstance(text, str):
        # ลบข้อความที่มีรูปแบบโฆษณาที่พบได้บ่อย (สามารถปรับ regex ได้ตามความเหมาะสม)
        text = re.sub(r"here or remove ads.*?disclosureor", "", text, flags=re.IGNORECASE|re.DOTALL)
    return text

def clean_text(text):
    text = remove_html(text)      # ลบ HTML tags
    text = remove_ads(text)       # ลบข้อความโฆษณา
    text = text.strip()           # ตัดช่องว่างหัวและท้าย
    text = re.sub(r'[\r\n]+', ' ', text)
    text = re.sub(r'\s+', ' ', text)  # แทนที่ช่องว่างหลายตัวด้วยช่องว่างเดียว
    return text

for col in ['title', 'body_text']:
    article_sentiments[col] = article_sentiments[col].apply(clean_text)

article_sentiments = article_sentiments.drop_duplicates()

article_sentiments = article_sentiments.drop(columns=['publish_date', 'publish_time'])

# %%
article_sentiments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ticker            9999 non-null   object
#  1   title             9999 non-null   object
#  2   body_text         9999 non-null   object
#  3   url               9999 non-null   object
#  4   neg               9999 non-null   float64
#  5   neu               9999 non-null   float64
#  6   pos               9999 non-null   float64
#  7   compound          9999 non-null   float64
#  8   publish_datetime  9999 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 703.2+ KB

# %%
article_sentiments
# Out:
#      ticker                                              title  \
# 0      TSLA                          Error 404: Page Not Found
# 1      TSLA  Wall Street analyst says Tesla and its mission...
# 2      TSLA      Musk says AI should replace some govt workers
# 3      TSLA  Can Tesla help the U.S. catch up to China in t...
# 4      TSLA  Factbox-Warren Buffett and Berkshire Hathaway ...
# ...     ...                                                ...
# 9994   TSLA  Exclusive: Tesla supplier Panasonic eyes 20% j...
# 9995   TSLA  Dow Futures Tick Higher Ahead of Key Inflation...
# 9996   TSLA  Twitter sues Elon Musk to hold him to $44 bill...
# 9997   TSLA  Trump steps up attacks on Musk, who said Trump...
# 9998   TSLA  Insmed PT Raised to $70 at H.C. Wainwright By ...
#
#                                               body_text  \
# 0     404 Page Not Found Seems like the page you wer...
# 1     Investing.com -- Tesla’s near $1 trillion valu...
# 2     Investing.com-- Elon Musk advocated for levera...
# 3     Investing.com -- Tesla (NASDAQ: ) could play a...
# 4     By Jonathan Stempel OMAHA, Nebraska (Reuters) ...
# ...                                                 ...
# 9994  By Norihiko Shirouzu (Reuters) - Panasonic (OT...
# 9995  By Oliver Gray Investing.com - U.S. stock futu...
# 9996  By Tom Hals WILMINGTON, Del. (Reuters) - Twitt...
# 9997  (Reuters) - Donald Trump on Tuesday ratcheted ...
# 9998  (Updated - May 29, 2024 6:04 AM EDT) H.C. Wain...
#
#                                                     url    neg    neu    pos  \
# 0     https://www.investing.com/news

#
#                                                     url    neg    neu    pos  \
# 0     https://www.investing.com/news/stock-market-ne...  0.046  0.847  0.107
# 1     https://www.investing.com/news/economy-news/mu...  0.023  0.888  0.089
# 2     https://www.investing.com/news/stock-market-ne...  0.004  0.887  0.109
# 3     https://www.investing.com/news/stock-market-ne...  0.038  0.889  0.073
# 4     https://www.investing.com/news/cryptocurrency-...  0.000  0.911  0.089
# ...                                                 ...    ...    ...    ...
# 9993  https://www.investing.com/news/stock-market-ne...  0.042  0.817  0.141
# 9994  https://www.investing.com/news/stock-market-ne...  0.046  0.895  0.059
# 9995  https://www.investing.com/news/economy/twitter...  0.101  0.822  0.077
# 9996  https://www.investing.com/news/stock-market-ne...  0.055  0.888  0.057
# 9997  https://www.investing.com/news/technology-news...  0.008  0.864  0.128
#
#       compound    publish_datetime
# 0       0.9664 2025-05-05 04:49:00
# 1       0.8750 2025-05-05 01:20:00
# 2       0.9865 2025-05-03 08:27:00
# 3       0.9829 2025-05-03 06:10:00
# 4       0.9806 2025-05-03 03:02:00
# ...        ...                 ...
# 9993    0.9957 2022-07-13 03:59:00
# 9994    0.5423 2022-07-12 19:12:00
# 9995   -0.9636 2022-07-12 17:04:00
# 9996    0.1403 2022-07-12 02:34:00
# 9997    0.9882 2018-04-03 16:00:00
#
# [9998 rows x 9 columns]

# %%
article_sentiments.to_pickle("TSLA_article_sentiments.pkl")

article_sentiments.to_csv("TSLA_article_sentiments.csv", index=False)

# %%
TICKERS        = ['NVDA','AAPL','AMZN','GOOGL','MSFT','META','TSLA']
START_DATE     = '2009-07-01'
END_DATE       = '2025-05-03'
TH_UP, TH_DOWN = 0.005, -0.005

df_nvda  = pd.read_pickle('data/NVDA_article_sentiments.pkl')
df_appl  = pd.read_pickle('data/AAPL_article_sentiments.pkl')
df_amzn  = pd.read_pickle('data/AMZN_article_sentiments.pkl')
df_googl = pd.read_pickle('data/GOOGL_article_sentiments.pkl')
df_msft = pd.read_pickle('data/MSFT_article_sentiments.pkl')
df_meta = pd.read_pickle('data/META_article_sentiments.pkl')
df_tsla = pd.read_pickle('data/TSLA_article_sentiments.pkl')
df_news  = pd.concat([df_nvda, df_appl, df_amzn, df_googl,df_msft,df_meta,df_tsla], axis=0, ignore_index=True)

df_news['date'] = pd.to_datetime(df_news['publish_datetime']).dt.date

# %%
import yfinance as yf

price_dfs = []
for tk in TICKERS:
    p = yf.download(tk, start=START_DATE, end=END_DATE, auto_adjust=False)
    # Flatten columns if MultiIndex
    if isinstance(p.columns, pd.MultiIndex):
        p.columns = p.columns.get_level_values(0)
    p = p.rename(columns={
        'Open':'open_t','High':'high_t','Low':'low_t',
        'Close':'close_t','Volume':'volume_t'
    })
    # MA, Momentum, ATR, RSI, MACD_hist
    p['MA5_t']       = p['close_t'].rolling(5).mean()
    p['MA10_t']      = p['close_t'].rolling(10).mean()
    p['momentum5_t'] = p['close_t'] - p['close_t'].shift(5)
    hl = p['high_t'] - p['low_t']
    hc = (p['high_t'] - p['close_t'].shift(1)).abs()
    lc = (p['low_t']  - p['close_t'].shift(1)).abs()
    tr = pd.concat([hl,hc,lc],axis=1).max(axis=1)
    p['ATR14_t']     = tr.rolling(14).mean()
    delta = p['close_t'].diff()
    gain  = delta.clip(lower=0); loss = -delta.clip(upper=0)
    avg_g = gain.rolling(14).mean(); avg_l = loss.rolling(14).mean()
    rs    = avg_g/avg_l
    p['RSI14_t']     = 100 - (100/(1+rs))
    ema12 = p['close_t'].ewm(span=12,adjust=False).mean()
    ema26 = p['close_t'].ewm(span=26,adjust=False).mean()
    macd  = ema12 - ema26
    signal= macd.ewm(span=9,adjust=False).mean()
    p['MACD_hist_t'] = macd - signal
    # target label
    p['close_t+1']        = p['close_t'].shift(-1)
    p['future_return_1d'] = (p['close_t+1'] - p['close_t'])/p['close_t']
    p['label'] = p['future_return_1d'].apply(
        lambda r: 2 if r>TH_UP else 0 if r<TH_DOWN else 1
    )
    req = ['open_t','high_t','low_t','close_t','volume_t',
           'MA5_t','MA10_t','momentum5_t','ATR14_t','RSI14_t','MACD_hist_t',
           'future_return_1d','label']
    p = p.dropna(subset=req)
    p = p.reset_index().rename(columns={'Date':'date'})
    p['date']   = p['date'].dt.date
    p['ticker'] = tk
    price_dfs.append(p)


df_price = pd.concat(price_dfs, ignore_index=True)

# %%
df = pd.merge(df_news, df_price, on=['ticker','date'], how='inner')

# %%
df.to_pickle("data/Stock_article_sentiments.pkl")
df.to_csv("data/Stock_article_sentiments.csv", index=False)

# %%
df = pd.read_pickle("data/Stock_article_sentiments.pkl")

# %%
df
# Out:
#       ticker                                              title  \
# 0       NVDA                Deepseek Releases New Math AI Model
# 1       NVDA  Adv Micro Device receives Investment Bank Anal...
# 2       NVDA  Nvidia Corp receives Investment Bank Analyst R...
# 3       NVDA  Taiwan’s ASE: evaluating how it will support N...
# 4       NVDA  Super Micro slumps on forecast cut, analysts d...
# ...      ...                                                ...
# 64647   TSLA  Exclusive: Tesla supplier Panasonic eyes 20% j...
# 64648   TSLA  Dow Futures Tick Higher Ahead of Key Inflation...
# 64649   TSLA  Twitter sues Elon Musk to hold him to $44 bill...
# 64650   TSLA  Trump steps up attacks on Musk, who said Trump...
# 64651   TSLA  Insmed PT Raised to $70 at H.C. Wainwright By ...
#
#                                                body_text  \
# 0      Risk Disclosure: Trading in financial instrume...
# 1      Risk Disclosure: Trading in financial instrume...
# 2      Risk Disclosure: Trading in financial instrume...
# 3      By Wen-Yee Lee and Ben Blanchard TAIPEI (Reute...
# 4      By Aditya Soni (Reuters) -Super Micro Computer...
# ...                                                  ...
# 64647  By Norihiko Shirouzu (Reuters) - Panasonic (OT...
# 64648  By Oliver Gray Investing.com - U.S. stock futu...
# 64649  By Tom Hals WILMINGTON, Del. (Reuters) - Twitt...
# 64650  (Reuters) - Donald Trump on Tuesday ratcheted ...
# 64651  (Updated - May 29, 2024 6:04 AM EDT) H.C. Wain...
#
#                                                      url    neg    neu    pos  \
# 0      https://www.investing.com/news/pro/deepseek-re...  0.076  0.893  0.032
# 1      https://www.investing.com/news/pro/seaport-glo...  0.076  0.893  0.032
# 2      https://www.investing.com/news/pro/seaport-glo...  0.076  0.893  0.032
# 3      https://www.investing.com/news/stock-market-ne...  0.032  0.883  0.084
# 4      https://www.investing.com/news/stock-market-ne...  0.099  0.779  0.122
# ...                                                  ...    ...    ...    ...
