# %% [markdown]
# # Web scraping stock market news for Sentiment Analysis

# %% [markdown]
# ## 1. Install/import libraries

# %%
# %pip install pandas nltk cloudscraper beautifulsoup4 htmldate newspaper3k lxml_html_clean
# Out:
# Requirement already satisfied: pandas in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (2.2.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: nltk in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (3.9.1)
# Requirement already satisfied: cloudscraper in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (1.2.71)
# Requirement already satisfied: beautifulsoup4 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (4.12.3)
# Requirement already satisfied: htmldate in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (1.9.3)
# Requirement already satisfied: newspaper3k in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (0.2.8)
# Requirement already satisfied: lxml_html_clean in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (0.4.1)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: click in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: pyparsing>=2.4.7 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from cloudscraper) (3.2.1)
# Requirement already satisfied: requests>=2.9.2 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from cloudscraper) (2.32.3)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from cloudscraper) (1.0.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: charset_normalizer>=3.4.0 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from htmldate) (3.4.1)
# Requirement already satisfied: dateparser>=1.1.2 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from htmldate) (1.2.1)
# Requirement already satisfied: lxml<6,>=5.3.0 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from htmldate) (5.3.1)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from htmldate) (2.3.0)
# Requirement already satisfied: Pillow>=3.3.0 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from newspaper3k) (11.1.0)
# Requirement already satisfied: PyYAML>=3.11 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from newspaper3k) (6.0.2)
# Requirement already satisfied: cssselect>=0.9.2 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from newspaper3k) (1.3.0)
# Requirement already satisfied: feedparser>=5.2.1 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from newspaper3k) (6.0.11)
# Requirement already satisfied: tldextract>=2.0.1 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from newspaper3k) (5.1.3)
# Requirement already satisfied: feedfinder2>=0.0.4 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: jieba3k>=0.35.1 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: tinysegmenter==0.3 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from newspaper3k) (0.3)
# Requirement already satisfied: tzlocal>=0.2 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from dateparser>=1.1.2->htmldate) (5.3.1)
# Requirement already satisfied: six in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Requirement already satisfied: sgmllib3k in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from requests>=2.9.2->cloudscraper) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from requests>=2.9.2->cloudscraper) (2025.1.31)
# Requirement already satisfied: requests-file>=1.4 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from tldextract>=2.0.1->newspaper3k) (3.17.0)
# Requirement already satisfied: colorama in c:\users\acer\anaconda3\envs\nlp2\lib\site-packages (from click->nltk) (0.4.6)

# %%
# Standard library
import os
import re
import time
import random
import asyncio
import warnings
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor,  as_completed

# Third-party libraries
import pandas as pd
import nltk
import nest_asyncio
import cloudscraper
from htmldate import find_date
from bs4 import BeautifulSoup
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from newspaper import Article

warnings.filterwarnings('ignore')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# ## 2. Data collection

# %%
# ——— CONFIG ———
# Company ticker identifier for investing.com
COMPANY     = "facebook-inc"   
# Maximum number of pages to scrape (pagination)
MAX_PAGE    = 1000             
# Number of concurrent workers for ThreadPoolExecutor
MAX_WORKERS = 50              
# Maximum number of retry attempts for failed requests
MAX_RETRIES = 5              

# HTTP headers to mimic a legitimate web browser request
# This helps avoid detection as a bot/scraper
HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/115.0.0.0 Safari/537.36"
    ),
    "Accept": (
        "text/html,application/xhtml+xml,application/xml;"
        "q=0.9,image/avif,image/webp,*/*;q=0.8"
    ),
    # Referrer to appear as if coming from the main site
    "Referer": "https://www.investing.com/",
}

# Create a cloudscraper instance to bypass Cloudflare protections
scraper = cloudscraper.create_scraper(
    browser={'browser': 'chrome', 'platform': 'windows'}
)

def fetch_page(page: int):
    """ดึงลิงก์ข่าวจากหน้า {page} แล้วคืน list ของ href"""
    # Construct URL for the specific page number
    url = f"https://www.investing.com/equities/{COMPANY}-news/{page}"
    # Implement retry logic for resilience
    for attempt in range(1, MAX_RETRIES + 1):
        try:
            # Make HTTP request with timeout
            r = scraper.get(url, headers=HEADERS, timeout=30)
            r.raise_for_status()  # Raise exception for 4XX/5XX responses
            # Parse HTML with BeautifulSoup
            soup = BeautifulSoup(r.text, "lxml")
            # CSS selector to find news article links
            anchors = soup.select(
                'ul[data-test="news-list"] '
                'li article a[data-test="article-title-link"]'
            )
            # Extract href attributes from anchor tags
            return [a["href"] for a in anchors if a.has_attr("href")]
        except Exception as e:
            # Exponential backoff with jitter for retries
            if attempt < MAX_RETRIES:
                backoff = 2 ** (attempt - 1) + random.random()
                time.sleep(backoff)
            else:
                # Log failure after exhausting retries
                print(f"Page {page} failed after {MAX_RETRIES}: {e}")
    # Return empty list if all attempts fail
    return []

def robust_scrape():
    # First, fetch page 1 to determine how many links per page
    first = fetch_page(1)
    PER_PAGE = len(first)
    # Validate we got results from first page
    if PER_PAGE == 0:
        raise RuntimeError("Failed to fetch the first page. Please check headers or cookies and try again.")
    print(f"Detected {PER_PAGE} links per page, expecting {PER_PAGE * MAX_PAGE} total")

    # Initialize results dictionary with first page
    results = {1: first}
    # Create list of remaining pages to fetch
    pages = list(range(2, MAX_PAGE + 1))

    # Use thread pool for parallel execution
    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as pool:
        # Submit fetch jobs for all pages
        futures = {pool.submit(fetch_page, p): p for p in pages}
        # Process completed futures as they finish
        for fut in as_completed(futures):
            p = futures[fut]
            results[p] = fut.result()

        # Retry logic for pages with incomplete results
        for round in range(1, MAX_RETRIES + 1):
            # Identify pages with fewer links than expected
            bad = [p for p, links in results.items() if len(links) != PER_PAGE]
            if not bad:
                print(f"All pages OK after {round-1} retries")
                break

            # Retry only the problematic pages
            print(f"Retry round {round} for pages: {bad}")
            futures = {pool.submit(fetch_page, p): p for p in bad}
            for fut in as_completed(futures):
                p = futures[fut]
                results[p] = fut.result()
        else:
            # This executes if the for loop completes without breaking
            print("Retry limit reached; some pages may still be incomplete.")

    # Calculate statistics on results
    total_fetched = sum(len(links) for links in results.values())
    expected = PER_PAGE * MAX_PAGE
    print(f"Total links fetched (including duplicates): {total_fetched} (expected {expected})")

    # Deduplicate links using set conversion
    all_links = set(link for links in results.values() for link in links)
    print(f"Final: got {len(all_links)} unique URLs (expected {expected})")
    return list(all_links)

# Entry point guard - only executes when run directly
if __name__ == "__main__":
    links = robust_scrape()
# Out:
# Detected 10 links per page, expecting 10000 total
# All pages OK after 0 retries
# Total links fetched (including duplicates): 10000 (expected 10000)
# Final: got 9999 unique URLs (expected 10000)

# %%
links
# Out:
# ['https://www.investing.com/news/stock-market-news/eu-fines-meta-797-million-over-abusive-practices-benefiting-facebook-marketplace-3723142',
#  'https://www.investing.com/news/cryptocurrency-news/the-metaverse-mark-zuckerbergs-brave-new-world-2587228',
#  'https://www.investing.com/news/stock-market-news/ubs-downgrades-alphabet-stock-sees-better-riskreward-in-meta-and-amazon-432SI-3112943',
#  'https://www.investing.com/news/cryptocurrency-news/bitcoiner-claims-to-have-found-long-lost-satoshi-bitcoin-code-with-personal-notations-2907648',
#  'https://www.investing.com/news/stock-market-news/google-discussed-dropping-broadcom-as-ai-chips-supplier-the-information-3179195',
#  'https://www.investing.com/news/cryptocurrency-news/house-in-portugal-sold-for-3-bitcoins-without-euro-conversion-2819603',
#  'https://www.investing.com/news/world-news/soccerrepeat-racism-offenders-should-be-kicked-out-of-international-football-says-bale-2608074',
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3396922',
#  'https://www.investing.com/news/stock-market-news/rohingya-refugees-sue-facebook-for-150-billion-over-myanmar-violence-2702013',
#  'https://www.investing.com/news/stock-market-news/google-to-block-news-links-in-canada-over-law-on-paying-publishers--statement-3116890',
#  'https://www.investing.com/news/politics/analysis-white-house-us-companies-could-agree-on-25-tax-rate-officials-business-groups-say-2468672',
#  'https://www.investing.com/news/pro/tiktok-ban-5-reasons-why-analysts-think-nothing-will-happen-before-elections-432SI-3334359',
#  'https://www.investing.com/news/world-news/us-senate-set-to-pass-major-online-child-safety-reforms-3543116',
#  'https://www.investing.com/news/cryptocurrency-news/will-polkadot-save-decentralized-finance-from-ethereums-scaling-problems-2600593',
#  'https://www.investing.com/news/stock-market-news/beefed-up-eu-tech-rules-could-be-global-standard-says-facebook-whistleblower-2672030',
#  'https://www.investing.com/news/cryptocurrency-news/bybit-card-marks-2nd-anniversary-with-15-million-cards-issued-enhancing-user-experience-and-accelerating-global-footprint-3927686',
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3693567',
#  'https://www.investing.com/news/stock-market-news/bofa-lifts-meta-price-target-to-710-on-ai-growth-cost-discipline-3827956',
#  'https://www.investing.com/news/world-news/meta-says-iranian-group-tried-to-target-trump-biden-officials-whatsapp-accounts-3587287',
#  'https://www.investing.com/news/pro/meta-platforms-inc-pt-raised-to-230-at-stifel-on-latest-cuts-432SI-3030586',
#  'https://www.investing.com/news/company-news/meta-platforms-ceo-sells-over-84-million-in-company-stock-93CH-3498579',
#  'https://www.investing.com/news/cryptocurrency-news/instagram-is-adding-nfts-soon-says-mark-zuckerberg-2785439',
#  'https://www.investing.com/news/stock-market-news/amazon-misses-wall-street-estimates-for-quarterly-sales-2573210',
#  'https://www.investing.com/news/stock-market-news/dow-closes-up-to-make-it-seven-in-a-row-as-jobs-data-boosts-ratecut-hopes-3430805',
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3049212',
#  'https://www.investing.com/news/world-news/syrias-president-bashar-alassad-wins-fourth-term-in-office-with-951-of-votes-live-conference-2517698',
#  'https://www.investing.com/news/stock-market-news/sp-500-cuts-losses-but-signs-of-further-cracks-in-banks-weigh-3039548',
#  'https://www.investing.com/news/stock-market-news/sp-500-flat-as-treasury-yields-jump-after-hotter-inflation-report-3152816',
#  'https://www.investing.com/news/cryptocurrency-news/liquidity-mining-scam-fbi-warns-users-to-stay-cautious-2854705',
#  'https://www.investing.com/news/stock-market-news/meta-bringing-together-ai-research-and-product-teams-3277633',
#  'https://www.investing.com/news/stock-market-news/google-approves-trumps-truth-social-for-play-store--axios-2910950',
#  'https://www.investing.com/news/stock-market-news/dozens-of-us-states-sue-meta-platforms-for-harming-mental-health-of-young-people-3207211',
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3379712',
#  'https://www.investing.com/news/company-news/meta-platforms-chief-legal-officer-sells-shares-worth-over-290k-93CH-3385725',
#  'https://www.investing.com/news/cryptocurrency-news/metaverse-platforms-are-working-on-interoperability-why-does-it-matter-2953052',
#  'https://www.investing.com/news/stock-market-news/us-stock-buyback-plans-picking-up-in-earnings-season-epfr-says-3294288',
#  'https://www.investing.com/news/stock-market-news/tesla-falls-after-report-of-sap-snub-piper-sandler-price-target-cut-3293016',
#  'https://www.investing.com/news/economy-news/vietnam-govt-says-spacex-plans-15-billion-investment-in-country-3633173',
#  'https://www.investing.com/news/world-news/defeated-candidates-in-russian-election-try-to-annul-crooked-online-results-2624921',
#  'https://www.investing.com/news/stock-market-news/wall-street-opens-lower-consolidating-after-monday-surge-dow-down--50-pts-2466919',
#  'https://www.investing.com/news/stock-market-news/us-sets-stage-for-antitrust-probes-into-microsoft-openai-and-nvidia-3472907',
#  'https://www.investing.com/news/stock-market-news/metas-frankfurtlisted-shares-rise-79-after-q2-beat-3547733',
#  'https://www.investing.com/news/stock-market-news/sp-500-struggles-for-direction-amc-puts-squeeze-on-shortsellers-again-2525410',
#  'https://www.investing.com/news/stock-market-news/meta-platforms-icahn-enterprises-fisker-rise-premarket-fmc-falls-3122549',
#  'https://www.investing.com/news/stock-market-news/stock-market-today-dow-stumbles-as-strong-jobs-data-strike-down-fed-pivot-hopes-2907612',
#  'https://www.investing.com/news/cryptocurrency-news/bitcci-plans-to-revolutionize-the-adult-entertainment-industry-through-blockchain-and-nfts-2767730',
#  'https://www.investing.com/news/stock-market-news/pwc-australia-flags-revenue-hole-partner-profit-cut-due-to-tax-scandal-legacy-3165702',
#  'https://www.investing.com/news/economy-news/risk-spotlight-swings-to-earnings-avalanche-3687240',
#  'https://www.investing.com/news/cryptocurrency-news/flipster-announces-collaboration-with-tether-3579396',
#  'https://www.investing.com/news/stock-market-news/us-appeals-court-rejects-bid-by-states-to-revive-antitrust-lawsuit-against-facebook-3066486',
#  'https://www.investing.com/news/cryptocurrency-news/coin-healthcheck-ethereum-meta-ethm-2691736',
#  'https://www.investing.com/news/pro/pure-storage-inc-receives-investment-bank-analyst-rating-update-3721105',
#  'https://www.investing.com/news/stock-market-news/italian-lawmakers-urge-government-to-scale-back-crypto-web-tax-plans-3730276',
#  'https://www.investing.com/news/commodities-news/markets-in-q3-gains-pains-and-oil-reigns-3186357',
#  'https://www.investing.com/news/technology-news/facebook-disables-13-billion-fake-accounts-in-octoberdecember-last-year-2453076',
#  'https://www.investing.com/news/stock-market-news/sp-500-falls-as-china-credit-contagion-fears-deepen-september-slide-2621333',
#  'https://www.investing.com/news/cryptocurrency-news/magnificent-seven-tech-stocks-tumble-a-whopping-280b-as-crypto-surges-3209381',
#  'https://www.investing.com/news/cryptocurrency-news/twix-brings-iconic-rivalry-to-the-nft-space-2644783',
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3547681',
#  'https://www.investing.com/news/commodities-news/hungary-says-its-backing-of-eus-russia-oil-ban-hinges-on-hundreds-of-millions-of-dollars-2822720',
#  'https://www.investing.com/news/stock-market-news/wall-street-jumps-at-open-on-omicron-optimism-dow-up-240-pts-2695952',
#  'https://www.investing.com/news/stock-market-news/startup-rivos-raises-250-million-to-develop-riscv-ai-chips-3380157',
#  'https://www.investing.com/news/stock-market-news/sp-500-nasdaq-at-record-highs-house-makes-progress-on-35t-budget-2598568',
#  'https://www.investing.com/news/stock-market-news/sp-500-nasdaq-keep-record-run-going-as-tech-rides-falling-yields-2549180',
#  'https://www.investing.com/news/stock-market-news/eu-to-test-facebook-x-and-others-on-disinformation-ahead-of-german-election-3829931',
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3291047',
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3776407',
#  'https://www.investing.com/news/commodities-news/russia-rains-missiles-on-kyiv-other-cities-after-pulling-out-of-grain-deal-2926375',
#  'https://www.investing.com/news/stock-market-news/german-cartel-office-examining-google-considering-cases-involving-amazon-apple-meta-2730795',
#  'https://www.investing.com/news/loop-industries-reports-q4-net-loss-of-143m-provides-update-on-continuing-business-developments-432SI-2830785',
#  'https://www.investing.com/news/stock-market-news/factboxwhy-are-tech-firms-leading-job-cuts-in-corporate-america-2974045',
#  'https://www.investing.com/news/stock-market-news/meta-unfriends-fb-ticker-in-final-farewell-to-facebook-era-2835286',
#  'https://www.investing.com/news/cryptocurrency-news/zambesi-gold-brings-financial-players-a-digital-token-backed-by-real-gold-2777294',
#  'https://www.investing.com/news/stock-market-news/sp-500-ends-lower-as-chinaled-global-growth-worries-persist-fed-eyed-2622600',
#  'https://www.investing.com/news/cryptocurrency-news/margex-announces-integration-of-ton-toncoin-for-deposits-and-withdrawals-3552986',
#  'https://www.investing.com/news/world-news/russia-says-it-destroys-five-ukraines-su27-jet-fighters-at-myrhorod-airfield-3504791',
#  'https://www.investing.com/news/cryptocurrency-news/shareholders-urge-mark-zuckerberg-to-buy-bitcoin-for-meta-3808005',
#  'https://www.investing.com/news/stock-market-news/futures-tread-water-after-sp-500-hits-record-high-2578960',
#  'https://www.investing.com/news/economy-news/alleged-child-abuse-case-puts-banned-malaysian-sect-back-in-spotlight-3616451',
#  'https://www.investing.com/news/cryptocurrency-news/readygg-launches-rdyx-token-on-coinlist-to-democratize-web3-game-development-3517343',
#  'https://www.investing.com/news/pro/meta-platforms-inc-pt-lowered-to-175-at-keybanc-432SI-2920412',
#  'https://www.investing.com/news/stock-market-news/sp-500-skids-as-geopolitical-tensions-flare-fed-minutes-eyed-2765624',
#  'https://www.investing.com/news/cryptocurrency-news/jack-dorsey-steps-down-from-twitter-microstrategy-snaps-up-7k-btc-and-square-rebrands-to-block-hodlers-digest-nov-28dec-4-2700535',
#  'https://www.investing.com/news/stock-market-news/meta-platforms-shares-surge-as-zuckerberg-promises-sharper-focus-on-returns-2993627',
#  'https://www.investing.com/news/company-news/meta-platforms-coo-sells-over-245k-in-company-stock-93CH-3392152',
#  'https://www.investing.com/news/cryptocurrency-news/meta-scraps-nfts-on-instagram-and-facebook-nifty-newsletter-march-814-3031671',
#  'https://www.investing.com/news/stock-market-news/tech-giants-q3-earnings-sway-market-microsoft-excels-as-alphabet-disappoints-93CH-3208726',
#  'https://www.investing.com/news/stock-market-news/3-media-stocks-to-consider-adding-to-your-portfolio-2600611',
#  'https://www.investing.com/news/stock-market-news/exgoogle-exec-said-goal-was-to-crush-competition-trial-evidence-shows-3612003',
#  'https://www.investing.com/news/general/us-supreme-court-rebuffs-lawyers-punished-after-woeful-suit-backing-trump-3188159',
#  'https://www.investing.com/news/analyst-ratings/rbc-lifts-meta-platforms-stock-target-to-800-on-ai-prospects-93CH-3838839',
#  'https://www.investing.com/news/stock-market-news/european-stock-futures-slip-credit-suisse-posts-huge-loss-ahead-of-ecb-meeting-2923071',
#  'https://www.investing.com/news/stock-market-news/dow-turns-negative-as-energy-slumps-rate-scare-puts-tech-in-crosshairs-2451090',
#  'https://www.investing.com/news/economy/facebook-plans-to-remove-sensitive-ad-targeting-options-2673930',
#  'https://www.investing.com/news/stock-market-news/russia-tightens-grip-on-media-landscape-as-yandex-sells-homepage-news-to-rival-vk-2877917',
#  'https://www.investing.com/news/stock-market-news/microsofts-brad-smith-says-company-respects-european-laws-amid-us-criticism-4012163',
#  'https://www.investing.com/news/stock-market-news/ubs-shifts-tech-weightings-boosts-microsoft-and-meta-on-ai-optimism-4016906',
#  'https://www.investing.com/news/stock-market-news/court-eases-curbs-on-washingtons-contacts-with-social-media-companies-3170984',
#  'https://www.investing.com/news/stock-market-news/intels-move-into-ohio-brings-new-tech-kudos-competitionfor-talent-2745355',
#  'https://www.investing.com/news/stock-market-news/sp-500-dow-open-at-record-peak-as-investors-eye-tech-earnings-2655340',
#  'https://www.investing.com/news/world-news/iran-executes-four-accused-of-sabotage-links-to-israels-mossad-3264581',
#  'https://www.investing.com/news/stock-market-news/stock-market-growth-set-to-broaden-in-medium-term--citi-3312610',
#  'https://www.investing.com/news/stock-market-news/meta-platforms-has-the-most-meaningful-companyspecific-drivers--jpmorgan-432SI-3130067',
#  'https://www.investing.com/news/stock-market-news/stock-market-today-dow-in-worst-quarterly-loss-since-2020-on-recession-fears-2842878',
#  'https://www.investing.com/news/world-news/slovakia-bans-georgian-volunteer-9-others-from-entry-as-fico-ramps-up-coup-plot-accusations-3842998',
#  'https://www.investing.com/news/stock-market-news/sp-500-falls-into-correction-as-russiaukraine-tensions-escalate-2769505',
#  'https://www.investing.com/news/economy/us-futures-steady-micron-forecasts-wider-loss--whats-moving-markets-3184996',
#  'https://www.investing.com/news/stock-market-news/youtube-to-stop-removing-content-making-false-claims-on-past-elections-3097374',
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3191133',
#  'https://www.investing.com/news/stock-market-news/sp-500-climbs-as-financials-energy-rack-up-gains-ahead-of-fed-decision-2816295',
#  'https://www.investing.com/news/insider-trading-news/meta-platforms-chief-product-officer-sells-shares-worth-133-million-93CH-3901080',
#  'https://www.investing.com/news/world-news/hungarian-pm-orbans-aide-sparks-outrage-with-soviet-invasion-comment-3635478',
#  'https://www.investing.com/news/stock-market-news/wall-street-analyst-explains-why-big-tech-selloff-could-be-just-about-done-3936230',
#  'https://www.investing.com/news/world-news/british-virgin-islands-activists-protest-plan-for-direct-uk-rule-2815204',
#  'https://www.investing.com/news/economy/tech-earnings-ahead-fed-decision-asml-reports--whats-moving-markets-3836150',
#  'https://www.investing.com/news/stock-market-news/wall-sts-ai-bubble-resembles-runup-to-dotcom-crash-ray-dalio-tells-ft-3833409',
#  'https://www.investing.com/news/cryptocurrency-news/haven1-and-stader-labs-partner-to-bring-liquid-staking-to-the-safe-haven-ecosystem-3469489',
#  'https://www.investing.com/news/commodities-news/russia-and-ukraine-accuse-each-other-of-shelling-around-zaporizhzhia-nuclear-plant-2881237',
#  'https://www.investing.com/news/world-news/lawyer-for-myanmars-suu-kyi-says-he-has-been-issued-a-gag-order-2644698',
#  'https://www.investing.com/news/world-news/exclusivebiden-planning-inperson-campaign-fundraisers-as-soon-as-next-week-3070478',
#  'https://www.investing.com/news/world-news/new-cuban-decree-tightens-controls-on-social-media-sparking-outrage-2593747',
#  'https://www.investing.com/news/world-news/analysisonce-an-interloper-trump-returns-to-white-house-more-powerful-than-before-3818543',
#  'https://www.investing.com/news/stock-market-news/snowflake-snow-shares-skyrocket-what-you-need-to-know-3299852',
#  'https://www.investing.com/news/stock-market-news/big-techs-job-cuts-spur-rallies-even-as-an-economic-slowdown-looms-2987937',
#  'https://www.investing.com/news/stock-market-news/meta-platforms-sheryl-sandberg-to-step-down-as-coo-shares-fall-2832553',
#  'https://www.investing.com/news/stock-market-news/qualcomm-falls-on-revenue-miss-in-some-key-segments-tech-headwinds-2756360',
#  'https://www.investing.com/news/world-news/inquiry-into-new-zealands-deadliest-shooting-to-start-on-tuesday-3203649',
#  'https://www.investing.com/news/stock-market-news/us-consumer-watchdog-lays-out-ambitious-agenda-to-eye-big-tech-lending-competition-2657462',
#  'https://www.investing.com/news/stock-market-news/meta-platforms-earnings-beat-by-129-revenue-topped-estimates-3838202',
#  'https://www.investing.com/news/cryptocurrency-news/arabia-saudita-e-cina-collaborano-alla-realizzazione-di-un-sistema-di-intelligenza-artificiale-in-lingua-araba-3195162',
#  'https://www.investing.com/news/pro/meta-platforms-inc-pt-lowered-to-255-at-goldman-sachs-432SI-2856121',
#  'https://www.investing.com/news/stock-market-news/european-stocks-edge-higher-volkswagen-slips-on-chip-worries-2484760',
#  'https://www.investing.com/news/cryptocurrency-news/xiaomi-retailer-in-portugal-now-accepts-bitcoin-payments-2582262',
#  'https://www.investing.com/news/stock-market-news/dow-futures-gain-meta-surges-18-after-earnings-2812305',
#  'https://www.investing.com/news/stock-market-news/meta-platforms-to-use-reuters-news-content-in-ai-chatbot-3683994',
#  'https://www.investing.com/news/pro/tiktok-faces-us-ban-after-appeals-court-refuses-to-block-law--bloomberg-432SI-3759493',
#  'https://www.investing.com/news/world-news/suspect-in-killing-of-maryland-judge-found-dead-3210678',
#  'https://www.investing.com/news/stock-market-news/futures-gain-as-markets-cheer-alphabet-results-economic-data-awaited-3690294',
#  'https://www.investing.com/news/pro/pinterest-inc-receives-investment-bank-analyst-rating-update-3654814',
#  'https://www.investing.com/news/stock-market-news/stock-market-today-sp-500-rallies-on-tech-strength-ahead-of-big-tech-earnings-3387721',
#  'https://www.investing.com/news/world-news/denmark-prime-minister-praises-people-of-greenland-amid-pressure-from-trump-3951063',
#  'https://www.investing.com/news/world-news/georgia-accuses-exofficial-of-plotting-from-ukraine-to-oust-tbilisi-government-3176756',
#  'https://www.investing.com/news/stock-market-news/russian-court-rejects-googles-appeal-against-50million-fine-over-ukraine-content-3372610',
#  'https://www.investing.com/news/economy/amazon-blowout-china-crackdown-palladium-3k--whats-moving-markets-2491114',
#  'https://www.investing.com/news/stock-market-news/sp-500-slips-on-energy-but-still-trades-near-record-high-2584558',
#  'https://www.investing.com/news/stock-market-news/eu-lawmaker-gets-backing-for-tougher-eu-tech-rules-2558233',
#  'https://www.investing.com/news/coronavirus/native-americans-fight-to-keep-traditions-alive-after-covid-2818026',
#  'https://www.investing.com/news/stock-market-news/stifel-jefferies-launch-coreweave-coverage-at-buy-3994711',
#  'https://www.investing.com/news/stock-market-news/exclusivefacebook-to-change-rules-on-attacking-public-figures-on-its-platforms-2642814',
#  'https://www.investing.com/news/stock-market-news/twitter-stock-incredible-ad-growth-enough-for-analysts-2639181',
#  'https://www.investing.com/news/stock-market-news/meta-lowers-quest-vr-headsets-prices-to-lure-customers-3021923',
#  'https://www.investing.com/news/stock-market-news/wall-street-analysts-react-to-deepseeks-ai-push-as-markets-sell-off-3831327',
#  'https://www.investing.com/news/stock-market-news/stock-market-today-dow-closes-above-41000-for-first-time-as-rotation-gains-steam-3522009',
#  'https://www.investing.com/news/economy/futures-higher-after-wall-st-slumps-lyfts-guidance-error--whats-moving-markets-3303013',
#  'https://www.investing.com/news/cryptocurrency-news/thailand-threatens-facebook-over-crypto-scams-and-other-fraudulent-ads-3158603',
#  'https://www.investing.com/news/stock-market-news/bills-targeting-big-tech-to-go-before-us-senate-panel-2743440',
#  'https://www.investing.com/news/pro/google-inc-receives-investment-bank-analyst-rating-update-3809993',
#  'https://www.investing.com/news/stock-market-news/nasdaq-100-enters-correction-territory-as-ai-tailwind-fades-3552512',
#  'https://www.investing.com/news/stock-market-news/immersion-licenses-haptics-patents-to-meta-platforms-93CH-3303553',
#  'https://www.investing.com/news/world-news/multiple-victims-after-shooting-in-canadas-vaughan-2966885',
#  'https://www.investing.com/news/commodities-news/analysispower-thirst-complicates-esg-investors-love-affair-with-tech-stocks-3633495',
#  'https://www.investing.com/news/assorted/former-meta-platforms-engineer-sues-co-alleging-he-was-fired-over-handling-of-gaza-content--reuters-432SI-3470907',
#  'https://www.investing.com/news/stock-market-news/meta-platforms-delivers-upbeat-guidance-as-q2-results-beat-estimates-shares-jump-3547035',
#  'https://www.investing.com/news/stock-market-news/white-house-says-reforms-should-happen-given-concerns-about-facebook-2636848',
#  'https://www.investing.com/news/world-news/taiwan-president-restraint-does-not-mean-it-wont-counter-china-2882380',
#  'https://www.investing.com/news/stock-market-news/meta-platforms-shares-rise-as-facebook-rebrands-to-focus-on-metaverse-2660456',
#  'https://www.investing.com/news/stock-market-news/fomo-may-lift-megacap-stocks-when-the-market-turns-2770113',
#  'https://www.investing.com/news/stock-market-news/caterpillar-workers-reach-deal-with-union-averting-possible-strike-3018053',
#  'https://www.investing.com/news/company-news/bmo-capital-raises-meta-stock-target-rates-market-perform-on-aidriven-ad-improvements-93CH-3548438',
#  'https://www.investing.com/news/commodities-news/morning-bid-dollar-surges-after-central-bank-barrage-apple-bruised-3349403',
#  'https://www.investing.com/news/stock-market-news/10-policies-if-trump-wins-and-stock-implications-jefferies-3527995',
#  'https://www.investing.com/news/cryptocurrency-news/what-is-a-smart-contract-and-why-is-it-important-in-web-30-2858710',
#  'https://www.investing.com/news/stock-market-news/meta-platforms-to-test-community-notes-feature-across-its-platforms-93CH-3926741',
#  'https://www.investing.com/news/economy/futures-inch-higher-in-runup-to-corporate-earnings-3390242',
#  'https://www.investing.com/news/cryptocurrency-news/will-eu-lawmakers-be-able-to-enforce-tech-rules-2844460',
#  'https://www.investing.com/news/stock-market-news/meta-platforms-seeing-largest-yoy-growth-acceleration-in-q2--jefferies-432SI-3096334',
#  'https://www.investing.com/news/world-news/south-korea-authorities-at-president-yoons-residence-to-execute-arrest-warrant-yonhap-says-3812605',
#  'https://www.investing.com/news/stock-market-news/why-etsy-etsy-shares-are-falling-today-3302472',
#  'https://www.investing.com/news/world-news/hungary-foreign-minister-says-he-was-in-touch-with-turkey-on-swedens-nato-bid-3119266',
#  'https://www.investing.com/news/economy/broadening-us-market-rally-gets-boost-from-dovish-fed-3350712',
#  'https://www.investing.com/news/stock-market-news/meta-overhauls-rules-on-deepfakes-other-altered-media-3367828',
#  'https://www.investing.com/news/stock-market-news/midday-movers-jetblue-airways-meta-bank-of-america-fall-sweetgreen-rises-3120718',
#  'https://www.investing.com/news/world-news/gaza-health-crisis-deepens-for-the-chronically-ill-as-war-intensifies-3226044',
#  'https://www.investing.com/news/pro/google-inc-receives-investment-bank-analyst-rating-update-3449428',
#  'https://www.investing.com/news/stock-market-news/musks-x-agrees-to-pay-about-10-million-to-settle-trump-lawsuit-wsj-reports-3866121',
#  'https://www.investing.com/news/stock-market-news/meta-platforms-shares-dip-amid-tech-giants-downturn-93CH-3204808',
#  'https://www.investing.com/news/stock-market-news/meta-to-launch-web-version-of-threads-app-early-next-week--wsj-3157770',
#  'https://www.investing.com/news/stock-market-news/facebook-slips-as-eu-uk-open-fresh-probe-2523566',
#  'https://www.investing.com/news/cryptocurrency-news/we-are-building-for-the-metaverse-says-meta-vp-nick-clegg-2666390',
#  'https://www.investing.com/news/stock-market-news/does-coinbase-deserve-a-place-in-your-portfolio-2654244',
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3659635',
#  'https://www.investing.com/news/world-news/gunmen-shoot-and-kill-aid-worker-in-gaza-charity-and-family-say-3635919',
#  'https://www.investing.com/news/general/fiery-illinois-highway-collision-kills-three-children-and-two-adults-3333292',
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3136061',
#  'https://www.investing.com/news/pro/evercore-isi-maintains-arista-networks-at-outperform-with-a-price-target-of-10000-3985124',
#  'https://www.investing.com/news/stock-market-news/tiktok-joins-meta-in-appealing-against-eu-gatekeeper-status-3235852',
#  'https://www.investing.com/news/world-news/judge-to-decide-on-racial-slur-allegedly-uttered-by-murder-suspect-in-arbery-case-2683806',
#  'https://www.investing.com/news/stock-market-news/us-judge-rejects-facebook-request-to-dismiss-ftc-antitrust-lawsuit-2736217',
#  'https://www.investing.com/news/stock-market-news/software-stocks-bid-higher-post-deepseek-rout-3835287',
#  'https://www.investing.com/news/stock-market-news/twitter-becomes-first-social-media-platform-to-allow-cannabis-ads-in-us-3004565',
#  'https://www.investing.com/news/insider-trading-news/meta-platforms-chief-legal-officer-jennifer-newstead-sells-547108-in-stock-93CH-3817880',
#  'https://www.investing.com/news/world-news/ukraine-reports-new-attack-on-grain-silos-but-cargo-ship-sets-sail-3155126',
#  'https://www.investing.com/news/forex-news/myanmars-junta-powerless-as-currency-drops-60-in-four-weeks-economy-tanks-2629335',
#  'https://www.investing.com/news/world-news/explainerwhat-is-an-everything-app-and-why-does-elon-musk-want-to-make-one-2925743',
#  'https://www.investing.com/news/cryptocurrency-news/quest-pro-vr-headset-raises-privacy-concerns-for-metas-future-in-metaverse-2913930',
#  'https://www.investing.com/news/stock-market-news/wall-street-falls-as-investors-prepare-for-onslaught-of-corporate-earnings-2846076',
#  'https://www.investing.com/news/economic-indicators/tiktoks-purveyors-of-creams-and-candies-under-threat-from-us-ban-3819448',
#  'https://www.investing.com/news/stock-market-news/sp-500-dow-keep-record-run-going-on-appleled-gains-in-tech-2588619',
#  'https://www.investing.com/news/stock-market-news/sp-500-dow-hit-records-again-as-cyclicals-shine-2587319',
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3641876',
#  'https://www.investing.com/news/pro/auras-technology-co-ltd-receives-investment-bank-analyst-rating-update-3446123',
#  'https://www.investing.com/news/stock-market-news/investors-eye-big-tech-as-stock-market-wobbles-2634644',
#  'https://www.investing.com/news/stock-market-news/sp-500-struggles-for-direction-ahead-of-inflation-data-3076252',
#  'https://www.investing.com/news/cryptocurrency-news/solving-the-fundamental-problems-with-playtoearn-games-2801104',
#  'https://www.investing.com/news/pro/cautious-midwest-boutique-comments-circulate-on-meta-platforms-432SI-4002120',
#  'https://www.investing.com/news/economy/investors-scour-the-globe-for-shelter-as-wall-street-shakes-3409178',
#  'https://www.investing.com/news/economy/facebook-google-twitter-say-could-quit-hong-kong-over-proposed-data-laws-wsj-2549918',
#  'https://www.investing.com/news/stock-market-news/most-japan-firms-stay-committed-to-diversity-despite-us-moves-reuters-survey-shows-3940922',
#  'https://www.investing.com/news/world-news/top-us-cyber-agency-to-monitor-midterm-election-2935874',
#  'https://www.investing.com/news/stock-market-news/judge-says-social-media-companies-must-face-lawsuits-over-harm-to-children-3234099',
#  'https://www.investing.com/news/technology-news/europe-needs-355-billion-for-5g-rollout-industrial-study-says-2456702',
#  'https://www.investing.com/news/pro/benchmark-maintains-meta-platforms-at-buy-with-a-price-target-of-64000-3998069',
#  'https://www.investing.com/news/stock-market-news/futures-muted-ahead-of-fed-meet-this-week-first-republic-bank-shares-tank-3068849',
#  'https://www.investing.com/news/stock-market-news/amazon-declines-to-describe-searchalgorithm-data--australian-regulator-2812640',
#  'https://www.investing.com/news/world-news/death-toll-from-maui-fires-hits-at-least-80-damages-at-billions-of-dollars-3152973',
#  'https://www.investing.com/news/stock-market-news/eu-lawmakers-back-tough-media-law-against-big-techs-content-removal-decisions-3189527',
#  'https://www.investing.com/news/cryptocurrency-news/binance-hires-ex-microsoft-and-agoda-product-and-engineering-execs-to-bring-web3-to-the-masses-2797337',
#  'https://www.investing.com/news/stock-market-news/factboxmajor-us-companies-making-masks-vaccines-mandatory-2582947',
#  'https://www.investing.com/news/world-news/ukraines-top-general-says-no-risk-of-encirclement-for-kyivs-troops-in-kursk-3918385',
#  'https://www.investing.com/news/stock-market-news/trumps-truth-social-app-launches-on-apple-app-store-2768120',
#  'https://www.investing.com/news/stock-market-news/too-soon-for-growth-stocks--ubs-432SI-2864128',
#  'https://www.investing.com/news/economy-news/tech-market-values-jump-in-september-on-fed-rate-cuts-ai-optimism-3644605',
#  'https://www.investing.com/news/stock-market-news/investors-count-on-earning-to-calm-900-billion-us-tech-rout-3528007',
#  'https://www.investing.com/news/stock-market-news/hsbc-launches-metaverse-portfolio-for-wealthy-asian-clients-2798861',
#  'https://www.investing.com/news/stock-market-news/amazon-removes-dei-mentions-in-2025-annual-report-3857186',
#  'https://www.investing.com/news/world-news/us-prosecutors-see-rising-threat-of-aigenerated-child-sex-abuse-imagery-3668239',
#  'https://www.investing.com/news/company-news/mizuho-sees-meta-stock-benefiting-from-ad-growth-and-genai-potential-93CH-3668496',
#  'https://www.investing.com/news/pro/edgewater-research-upgrades-meta-platforms-inc-to-buy-432SI-3021526',
#  'https://www.investing.com/news/stock-market-news/facebook-heads-for-dismal-quarter-as-advertisers-unfriend-2811811',
#  'https://www.investing.com/news/technology-news/fcc-begins-effort-to-revoke-two-chinese-telecoms-us-operating-authority-2449672',
#  'https://www.investing.com/news/stock-market-news/german-authorities-looking-into-possible-data-protection-violations-by-tesla-newspaper-3091278',
#  'https://www.investing.com/news/stock-market-news/these-are-the-current-eps-growth-estimates-for-each-major-sp-500-sector-3806371',
#  'https://www.investing.com/news/stock-market-news/sp-500-cuts-losses-as-dipbuying-helps-tech-move-off-lows-2894963',
#  'https://www.investing.com/news/analyst-ratings/piper-sandler-bullish-on-tech-stocks-post2025-cio-survey-93CH-3756676',
#  'https://www.investing.com/news/world-news/search-continues-for-9-campers-caught-in-malaysia-landslide-2966740',
#  'https://www.investing.com/news/world-news/whisky-and-the-coal-mining-shack-taiwan-election-is-not-only-about-china-3263784',
#  'https://www.investing.com/news/stock-market-news/deepseek-gives-europes-tech-firms-a-chance-to-catch-up-in-global-ai-race-3844302',
#  'https://www.investing.com/news/stock-market-news/meta-platforms-stock-to-surge-on-advertising-resurgence-and-ai-investment-citi-analyst-93CH-3180911',
#  'https://www.investing.com/news/cryptocurrency-news/event-recap-web-summit-2021-crypto-climate-change-and-facebook-2670539',
#  'https://www.investing.com/news/cryptocurrency-news/bybit-x-block-scholes-crypto-derivatives-report-btc-at-alltime-high-eth-options-signal-momentum-3782409',
#  'https://www.investing.com/news/stock-market-news/us-ftc-firings-could-put-consumer-rulings-in-legal-limbo-3940156',
#  'https://www.investing.com/news/stock-market-news/softbank-to-invest-in-search-startup-perplexity-ai-at-3-billion-valuation-bloomberg-reports-3498626',
#  'https://www.investing.com/news/stock-market-news/eu-questions-microsoft-rivals-over-teams-integration-in-office-2638824',
#  'https://www.investing.com/news/world-news/google-agrees-to-change-some-ad-practices-after-french-watchdog-imposes-fine-2524735',
#  'https://www.investing.com/news/pro/bofa-securities-upgrades-meta-platforms-inc-to-buy-432SI-2994020',
#  'https://www.investing.com/news/stock-market-news/asml-to-report-q4-earnings-amid-hopes-and-fears-over-deepseektrump-3833995',
#  'https://www.investing.com/news/stock-market-news/fewer-chickpeas-means-cheap-protein-and-hummus-could-be-harder-to-find-2845051',
#  'https://www.investing.com/news/cryptocurrency-news/health-city--aimedis-publishes-healthmetaverse-and-soon-opens-the-first-clinic-in-it-2708242',
#  'https://www.investing.com/news/stock-market-news/nasdaq-futures-down-70-pts-snap-earnings-weigh-2851791',
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3266341',
#  'https://www.investing.com/news/stock-market-news/sp-500-ends-flat-but-tech-basks-in-postfed-glory-2535513',
#  'https://www.investing.com/news/cryptocurrency-news/from-facebook-to-meta-what-does-the-future-of-social-media-look-like-2705291',
#  'https://www.investing.com/news/pro/meta-plans-to-cut-thousands-of-jobs-after-ceo-predicted-no-more-layoffs--wapo-432SI-3010775',
#  'https://www.investing.com/news/stock-market-news/investors-eye-fed-rate-cut-earnings-as-key-to-sustaining-market-rally-3357977',
#  'https://www.investing.com/news/stock-market-news/apples-iphone-privacy-changes-signal-desire-to-enter-advertising-rbc-2632326',
#  'https://www.investing.com/news/economy/apple-results-soundly-beat-wall-street-targets-90-billion-buyback-announced-2488819',
#  'https://www.investing.com/news/pro/meta-platforms-inc-pt-lowered-to-125-at-guggenheim-432SI-2923604',
#  'https://www.investing.com/news/stock-market-news/rayban-parent-essilorluxottica-shares-rise-on-strong-h1-results-3538324',
#  'https://www.investing.com/news/forex-news/ether-scales-4600-to-record-high-bitcoin-trails-2665429',
#  'https://www.investing.com/news/stock-market-news/eu-court-adviser-backs-whatsapp-in-fight-against-eu-privacy-watchdog-3951208',
#  'https://www.investing.com/news/stock-market-news/russia-reinstates-twitter-traffic-slowdown-on-computers-over-fake-ukraine-posts-ifax-2774897',
#  'https://www.investing.com/news/stock-market-news/big-tech-is-the-new-big-oil-5-magnificent-7-firms-set-to-spend-200b--in-2024-3441371',
#  'https://www.investing.com/news/pro/tripadvisor-receives-investment-bank-analyst-rating-update-3629170',
#  'https://www.investing.com/news/stock-market-news/pinterests-active-users-drop-as-pandemic-boom-wanes-2756621',
#  'https://www.investing.com/news/world-news/alec-baldwin-seen-consoling-family-of-slain-cinematographer-as-set-problems-mount-2653381',
#  'https://www.investing.com/news/politics/facebook-wont-say-if-its-algorithms-boosted-trumps-violent-rhetoric-2496435',
#  'https://www.investing.com/news/stock-market-news/melania-trump-to-make-parler-her-social-media-home-2760440',
#  'https://www.investing.com/news/wells-fargo-stick-to-their-buy-rating-for-zynga-2605998',
#  'https://www.investing.com/news/insider-trading-news/meta-platforms-chief-legal-officer-jennifer-newstead-sells-over-552000-in-stock-93CH-3940883',
#  'https://www.investing.com/news/company-news/meta-platforms-ceo-zuckerberg-sells-over-41-million-in-stock-93CH-3599545',
#  'https://www.investing.com/news/stock-market-news/meta-launches-subscription-service-in-us-3033630',
#  'https://www.investing.com/news/stock-market-news/sp-500-falls-as-bears-strengthen-gripon-tech-after-april-inflation-soars-2504386',
#  'https://www.investing.com/news/stock-market-news/roku-soars-as-improving-ad-revenue-fuels-upbeat-forecast-3218987',
#  'https://www.investing.com/news/stock-market-news/years-after-metoo-first-swept-the-world-taiwan-races-to-respond-3136847',
#  'https://www.investing.com/news/company-news/meta-platforms-coo-sells-shares-worth-over-195000-93CH-3530091',
#  'https://www.investing.com/news/stock-market-news/sp-500-marches-higher-as-cooling-inflation-cements-fed-downshift-bets-2990293',
#  'https://www.investing.com/news/stock-market-news/salesforce-raises-annual-profit-forecast-2954838',
#  'https://www.investing.com/news/world-news/hong-kong-womens-rights-protest-cancelled-after-police-cite-risk-of-violence-3022173',
#  'https://www.investing.com/news/stock-market-news/meta-shares-jump-12-following-q1-earnings-beat-2812134',
#  'https://www.investing.com/news/stock-market-news/after-wallstreetbets-australias-securities-regulator-warns-share-trading-forums-2485989',
#  'https://www.investing.com/news/stock-market-news/big-tech-move-into-finance-to-come-under-closer-eu-scrutiny-3290192',
#  'https://www.investing.com/news/cryptocurrency-news/crypto-regulations-and-market-habits-take-time-2596169',
#  'https://www.investing.com/news/pro/meta-platforms-inc-pt-lowered-to-104-at-rosenblatt-432SI-2939755',
#  'https://www.investing.com/news/stock-market-news/nvidia-forecasts-upbeat-revenue-on-data-center-chip-demand-2683184',
#  'https://www.investing.com/news/stock-market-news/exclusiveeu-antitrust-regulators-rejected-meta-offer-to-curb-use-of-ad-data-sources-say-3133693',
#  'https://www.investing.com/news/stock-market-news/big-tech-layoffs-may-further-disrupt-equity-and-diversity-efforts-2974180',
#  'https://www.investing.com/news/world-news/russian-court-sentences-colombian-man-to-5-years-in-prison-for-fake-news-3083967',
#  'https://www.investing.com/news/stock-market-news/facebook-removes-63000-accounts-in-nigeria-over-sextortion-scams-3533313',
#  'https://www.investing.com/news/pro/meta-executive-leading-ai-chip-efforts-to-leave-position--sources--reuters-432SI-3184504',
#  'https://www.investing.com/news/stock-market-news/tiktok-bytedance-sue-to-block-us-law-seeking-sale-or-ban-of-app-3424948',
#  'https://www.investing.com/news/world-news/two-killed-26-injured-in-russian-attack-on-ukraines-sumy-officials-say-3330713',
#  'https://www.investing.com/news/economic-indicators/irish-domestic-economy-shrank-in-q3-following-q2-investment-boom-2956319',
#  'https://www.investing.com/news/world-news/factboxtop-cases-before-the-us-supreme-court-during-its-new-term-3650725',
#  'https://www.investing.com/news/stock-market-news/stock-market-today-dow-in-nearly-3000point-gain-on-trumps-tariff-uturn-3975625',
#  'https://www.investing.com/news/stock-market-news/facebook-asks-oversight-board-for-guidance-on-crosscheck-system-2628709',
#  'https://www.investing.com/news/stock-market-news/l3harris-in-talks-to-buy-israeli-spyware-firm-nso--reports-2837242',
#  'https://www.investing.com/news/economy/central-banks-on-brink-of-victory-in-inflation-fight--bis-3323099',
#  'https://www.investing.com/news/stock-market-news/salesforce-launches-ai-assistant-across-its-apps-including-slack-and-tableau-3172568',
#  'https://www.investing.com/news/stock-market-news/sp-500-in-red-as-strong-jobs-gains-likely-to-keep-up-fed-rate-hikes-2833425',
#  'https://www.investing.com/news/stock-market-news/dow-futures-rise-180-pts-political-uncertainty-inflation-data-in-focus-2934453',
#  'https://www.investing.com/news/stock-market-news/exclusivetwitter-sees-jump-in-govt-demands-to-remove-content-of-journalists-news-outlets-2557850',
#  'https://www.investing.com/news/economy/factboxtech-firms-leading-job-cuts-in-corporate-america-2977209',
#  'https://www.investing.com/news/cryptocurrency-news/meta-working-on-textbased-decentralized-social-network-codenamed-p92-3027371',
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3676738',
#  'https://www.investing.com/news/stock-market-news/googles-russian-subsidiary-submits-bankruptcy-declaration-ifax-2838149',
#  'https://www.investing.com/news/stock-market-news/spac-cf-acquisition-soars-on-trump-links-of-target-firm-rumble-2701054',
#  'https://www.investing.com/news/stock-market-news/5-big-analyst-ai-moves-intels-new-chips-in-focus-nvidia-now-a-budget-ai-stock-3258340',
#  'https://www.investing.com/news/stock-market-news/sp-500-rides-tech-higher-as-fed-kicks-off-tightening-cycle-2786155',
#  'https://www.investing.com/news/stock-market-news/meta-used-copyrighted-books-for-ai-training-despite-its-own-lawyers-warnings-authors-allege-3255152',
#  'https://www.investing.com/news/stock-market-news/apple-investors-reject-proposal-against-dei-policies-3890150',
#  'https://www.investing.com/news/cryptocurrency-news/top-10-cryptocurrency-trends-to-watch-out-for-in-2022-2801236',
#  'https://www.investing.com/news/world-news/factboxuk-lawmakers-voice-opinion-on-pm-boris-johnson-2844538',
#  'https://www.investing.com/news/insider-trading-news/meta-platforms-ceo-mark-zuckerberg-sells-807m-in-stock-93CH-3762649',
#  'https://www.investing.com/news/stock-market-news/facebook-says-maintenance-error-caused-mondays-6hour-outage-2635441',
#  'https://www.investing.com/news/stock-market-news/facebook-plans-to-change-its-name--the-verge-2648895',
#  'https://www.investing.com/news/cryptocurrency-news/world-mobile-accelerates-us-network-growth-with-second-batch-of-airnode-sales-3569725',
#  'https://www.investing.com/news/commodities-news/palestinian-red-crescent-un-agencies-evacuate-al-shifa-premature-babies-statement-3238909',
#  'https://www.investing.com/news/cryptocurrency-news/miss-universe-denies-link-with-recently-unveiled-coin-project-3181236',
#  'https://www.investing.com/news/stock-market-news/stock-market-today-dow-ekes-out-gain-as-energy-shines-but-tech-takes-breather-3335177',
#  'https://www.investing.com/news/analyst-ratings/meta-stock-price-target-raised-to-800-by-raymond-james-93CH-3839528',
#  'https://www.investing.com/news/stock-market-news/european-stocks-slip-lower-after-strong-week-us-tariffs-ukraine-peace-in-focus-3869765',
#  'https://www.investing.com/news/pro/meta-platforms-to-launch-audio-version-of-its-meta-ai-chatbot-featuring-celebrity-voices--reuters-432SI-3628824',
#  'https://www.investing.com/news/economic-indicators/hungary-plans-talks-with-allies-to-combat-higher-oil-prices-after-new-us-sanctions-on-russia-3808094',
#  'https://www.investing.com/news/pro/rosenblatt-maintains-meta-platforms-at-buy-with-a-price-target-of-91800-4016122',
#  'https://www.investing.com/news/assorted/meta-platforms-partners-with-tencent-for-new-vr-headset-in-china-93CH-3230838',
#  'https://www.investing.com/news/stock-market-news/musk-says-twitter-to-soon-allow-calls-encrypted-messaging-3077940',
#  'https://www.investing.com/news/stock-market-news/us-stocks-are-rising-as-another-week-of-megacap-earnings-kicks-off-3139391',
#  'https://www.investing.com/news/stock-market-news/apple-must-face-narrowed-privacy-lawsuit-over-its-apps-3636892',
#  'https://www.investing.com/news/pro/meta-strikes-deal-to-divest-itself-of-kustomer--wsj-432SI-3074244',
#  'https://www.investing.com/news/cryptocurrency-news/binanceus-is-coming-to-the-metaverse-2735075',
#  'https://www.investing.com/news/economy/factbox-ecb-to-launch-digital-euro-project-2557244',
#  'https://www.investing.com/news/cryptocurrency-news/meta-trademark-filing-hints-at-plans-for-crypto-payments-platform-2827646',
#  'https://www.investing.com/news/stock-market-news/alibabas-cloud-unit-brings-metas-ai-model-llama-to-its-clients-3134011',
#  'https://www.investing.com/news/economy/global-tech-stocks-stage-tentative-recovery-after-meta-rout-2757063',
#  'https://www.investing.com/news/stock-market-news/sp-dow-end-slightly-up-extend-closing-streaks-despite-disney-drag-3423606',
#  'https://www.investing.com/news/stock-market-news/activist-investor-urges-getty-to-partner-with-meta-microsoft-to-grow-revenue-3056932',
#  'https://www.investing.com/news/stock-market-news/roku-is-removing-rt-from-the-roku-channel-store-in-europe--source-2774628',
#  'https://www.investing.com/news/cryptocurrency-news/crypto-flipsider-news---hsbc-partners-with-the-sandbox-consensys-doubles-valuation-and-aptos-raises-250-million-nfts-are-coming-to-instagram-three-defi-protocols-exploited-for-14-million-kazakhstan-mining-crack-down-2785956',
#  'https://www.investing.com/news/pro/meta-platforms-climbs-48-432SI-3021891',
#  'https://www.investing.com/news/economic-indicators/ukraine-bans-all-imports-from-russia-2801150',
#  'https://www.investing.com/news/economy/morning-bid-tech-becalmed-april-pmis-start-rolling-in-3389682',
#  'https://www.investing.com/news/stock-market-news/essilorluxottica-downgraded-at-ubs-on-valuation-nearterm-risks-3751701',
#  'https://www.investing.com/news/coronavirus/doctors-in-hungary-urge-volunteers-to-join-overwhelmed-covid19-wards-2453172',
#  'https://www.investing.com/news/world-news/pray-for-us-theyve-arrived-how-syria-descended-into-revenge-bloodshed-3930887',
#  'https://www.investing.com/news/stock-market-news/us-consumer-watchdog-to-query-tech-giants-over-financial-data-sources-2650337',
#  'https://www.investing.com/news/stock-market-news/uk-launches-investigation-into-tiktok-reddit-over-childrens-personal-data-practices-3901368',
#  'https://www.investing.com/news/company-news/meta-platforms-cfo-susan-li-sells-over-178-million-in-stock-93CH-3447027',
#  'https://www.investing.com/news/pro/mark-zuckerberg-meta-planning-to-invest-60b65b-in-capex-2025--bloomberg-432SI-3829856',
#  'https://www.investing.com/news/stock-market-news/facebook-owner-meta-announces-tests-of-generative-ai-ads-tool-3080626',
#  'https://www.investing.com/news/pro/tiktoks-coo-v-pappas-stepping-down-432SI-3111360',
#  'https://www.investing.com/news/stock-market-news/wall-street-analysts-reflect-positively-on-meta-layoffs-see-attractive-valuation-432SI-2940099',
#  'https://www.investing.com/news/cryptocurrency-news/amid-twitter-chaos-web3-firm-acquires-mastodon-instance-pawoonet-2968680',
#  'https://www.investing.com/news/stock-market-news/us-stocks-are-rising-after-inflation-data-fuels-hopes-on-lower-rate-hikes-3030168',
#  'https://www.investing.com/news/pro/meta-platforms-inc-pt-lowered-to-235-at-deutsche-bank-432SI-2850676',
#  'https://www.investing.com/news/stock-market-news/new-york-mayor-sues-social-media-firms-for-fueling-youth-mental-health-crisis-3304101',
#  'https://www.investing.com/news/stock-market-news/sp-500-rises-to-record-ahead-of-big-tech-earnings-tesla-hits-1t-market-cap-2654514',
#  'https://www.investing.com/news/pro/pinterest-inc-receives-investment-bank-analyst-rating-update-3710928',
#  'https://www.investing.com/news/stock-market-news/midday-movers-wynn-resorts-align-technology-newell-brands-and-more-2927189',
#  'https://www.investing.com/news/stock-market-news/bc-partners-to-acquire-accountbased-marketing-firm-madison-logic-2971055',
#  'https://www.investing.com/news/cryptocurrency-news/zuckerberg-warns-europe-about-new-data-regulations-2759684',
#  'https://www.investing.com/news/stock-market-news/meta-platforms-confirming-cost-cuts-would-be-a-key-catalyst--morgan-stanley-432SI-2897081',
#  'https://www.investing.com/news/stock-market-news/russia-to-go-after-google-this-month-with-fine-of-up-to-20-of-annual-turnover-2647647',
#  'https://www.investing.com/news/stock-market-news/analysishow-the-biden-white-house-is-fighting-russian-disinformation-2778181',
#  'https://www.investing.com/news/cryptocurrency-news/animoca-brands-targets-social-media-giants-in-latest-web3-expansion-plans-2790883',
#  'https://www.investing.com/news/stock-market-news/nvidia-overtakes-apple-as-no-2-most-valuable-company-3472266',
#  'https://www.investing.com/news/cryptocurrency-news/navigating-opportunities-and-risks-in-web3-investment-bybit-at-invest-web3-forum-3831908',
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3291212',
#  'https://www.investing.com/news/stock-market-news/samsung-boss-jay-y-lee-to-build-on-late-fathers-legacy-2923127',
#  'https://www.investing.com/news/economy-news/eus-dombrovskis-says-eu-prefers-negotiated-solution-on-trade-with-us-3999296',
#  'https://www.investing.com/news/stock-market-news/oversight-boards-policy-footprint-increases-in-third-quarter-2964219',
#  'https://www.investing.com/news/world-news/us-security-officials-worry-about-homegrown-election-threats-2914109',
#  'https://www.investing.com/news/economy-news/factboxairlines-suspend-flights-as-middle-east-tensions-rise-3699386',
# ...
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3627073',
#  'https://www.investing.com/news/pro/meta-platforms-inc-pt-raised-to-200-at-fbn-securities-432SI-2996177',
#  'https://www.investing.com/news/cryptocurrency-news/meta-reportedly-plans-to-integrate-nfts-on-facebook-and-instagram-profiles-2743946',
#  'https://www.investing.com/news/stock-market-news/sp-500-stumbles-as-bets-on-diplomatic-path-to-russiaukraine-crisis-fade-2769579',
#  'https://www.investing.com/news/stock-market-news/wall-street-retreats-from-records-as-investors-await-fed-2662997',
#  'https://www.investing.com/news/economy/analysisoverdue-pullback-in-us-stocks-to-test-dipbuyers-resolve-3387796',
#  'https://www.investing.com/news/pro/meta-platforms-developing-ai-search-engine--the-information-432SI-3686122',
#  'https://www.investing.com/news/stock-market-news/buy-the-dip-in-quality-ai-stocks-ubs-tells-its-clients-3839877',
#  'https://www.investing.com/news/stock-market-news/us-stocks-open-higher-after-worst-day-in-2-years-2892098',
#  'https://www.investing.com/news/pro/tripadvisor-receives-investment-bank-analyst-rating-update-3707921',
#  'https://www.investing.com/news/stock-market-news/social-media-platforms-blocked-in-sri-lanka-2796986',
#  'https://www.investing.com/news/world-news/louisiana-super-fog-kills-7-in-massive-car-pileup-3206341',
#  'https://www.investing.com/news/world-news/wedding-certificate-and-cell-phone-how-a-us-veterans-wife-fled-afghanistan-2602327',
#  'https://www.investing.com/news/commodities-news/facebook-signs-first-deal-to-buy-renewable-energy-in-india-2475069',
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3135964',
#  'https://www.investing.com/news/stock-market-news/special-report-the-expfizer-scientist-who-became-an-antivax-hero-2450442',
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3549010',
#  'https://www.investing.com/news/cryptocurrency-news/the-next-web-30-social-media-will-be-built-on-solana-2673241',
#  'https://www.investing.com/news/stock-market-news/analysisrohingya-lawsuit-against-facebook-a-wakeup-call-for-social-media-2707047',
#  'https://www.investing.com/news/cryptocurrency-news/bydfi-launches-innovative-perpetual-contract-copy-trading-feature-welcomes-global-traders-to-join-3809440',
#  'https://www.investing.com/news/coronavirus/seoul-defends-mandatory-coronavirus-testing-of-foreign-workers-2450256',
#  'https://www.investing.com/news/stock-market-news/tesla-and-macys-rise-premarket-coinbase-and-nio-fall-3508970',
#  'https://www.investing.com/news/world-news/most-online-hate-targets-women-says-eu-report-3245933',
#  'https://www.investing.com/news/world-news/european-parliaments-kaili-ousted-from-post-as-she-denies-corruption-charges-2963023',
#  'https://www.investing.com/news/economic-indicators/ukraines-farm-unions-ask-government-to-protect-free-eu-market-access-3292890',
#  'https://www.investing.com/news/pro/signal-is-approved-app--white-house-432SI-3950079',
#  'https://www.investing.com/news/cryptocurrency-news/metaverse-is-the-next-big-thing-square-changes-name-to-block-2698746',
#  'https://www.investing.com/news/pro/meta-platforms-inc-pt-lowered-to-240-at-evercore-isi-432SI-2856184',
#  'https://www.investing.com/news/insider-trading-news/meta-platforms-chief-product-officer-christopher-cox-sells-1355-million-in-stock-93CH-3904380',
#  'https://www.investing.com/news/stock-market-news/nasdaq-futures-lead-as-amd-boosts-chips-before-fed-verdict-microsoft-drops-3545468',
#  'https://www.investing.com/news/cryptocurrency-news/the-opportunities-and-risks-of-metaverse-for-small-businesses-2852144',
#  'https://www.investing.com/news/stock-market-news/pepsico-facebook-and-jj-rise-premarket-lordstown-motors-slumps-2634943',
#  'https://www.investing.com/news/pro/bofa-securities-maintains-meta-platforms-at-buy-with-a-price-target-of-64000-3983090',
#  'https://www.investing.com/news/world-news/donetsk-battles-are-hell-ukraines-zelenskiy-says-as-kherson-mops-up-2942341',
#  'https://www.investing.com/news/stock-market-news/maryland-opens-temporary-channel-at-collapsed-bridge-site--governor-3360273',
#  'https://www.investing.com/news/company-news/metas-chief-legal-officer-sells-shares-worth-over-483k-93CH-3514803',
#  'https://www.investing.com/news/stock-market-news/broadcom-has-recently-won-googles-nextgen-ai-asic-chip-design-jpmorgan-432SI-3473642',
#  'https://www.investing.com/news/stock-market-news/6-big-analyst-calls-today-ubs-gets-mixed-reaction-after-credit-suisse--pro-recap-3034481',
#  'https://www.investing.com/news/cryptocurrency-news/maplestory-universe-unveils-nexpace-protocol-today-3588801',
#  'https://www.investing.com/news/stock-market-news/in-challenge-to-meta-apple-expected-to-unveil-mixedreality-headset-3097270',
#  'https://www.investing.com/news/insider-trading-news/mark-zuckerberg-sells-meta-shares-for-138-million-93CH-3879019',
#  'https://www.investing.com/news/pro/cantor-fitzgerald-maintains-meta-platforms-at-overweight-with-a-price-target-of-62400-3993176',
#  'https://www.investing.com/news/world-news/special-reporttrump-allies-breach-us-voting-systems-in-search-of-2020-fraud-evidence-2813439',
#  'https://www.investing.com/news/stock-market-news/australia-to-introduce-new-laws-to-force-media-platforms-to-unmask-online-trolls-2691783',
#  'https://www.investing.com/news/stock-market-news/facebook-gains-as-insta-brings-ads-to-reels-its-answer-to-tiktok-2535333',
#  'https://www.investing.com/news/stock-market-news/new-nvidia-ai-chips-face-issue-with-overheating-servers-the-information-reports-3726925',
#  'https://www.investing.com/news/cryptocurrency-news/metas-metaverse-fails-to-impress-users-reports-43-billion-in-q4-losses-2994344',
#  'https://www.investing.com/news/cryptocurrency-news/we-need-to-do-our-share-says-cz-as-binance-lags-in-lobbying-2801684',
#  'https://www.investing.com/news/world-news/factboxus-japan-philippines-strike-deals-on-defense-investment-at-leaders-summit-3375995',
#  'https://www.investing.com/news/stock-market-news/amds-ai-bets-face-investor-scrutiny-as-big-tech-switches-to-custom-chips-3845127',
#  'https://www.investing.com/news/stock-market-news/sp-500-steadies-as-rising-materials-tech-offer-respite-after-selloff-2677062',
#  'https://www.investing.com/news/stock-market-news/sp-500-flat-as-reopening-stocks-gain-but-energy-loses-power-2510002',
#  'https://www.investing.com/news/world-news/australia-drops-court-action-against-musks-x-over-church-stabbing-posts-3470938',
#  'https://www.investing.com/news/economy/facebook-twitter-pinterest-drop-ces-plans-over-covid19-concerns-2719922',
#  'https://www.investing.com/news/stock-market-news/afterhours-movers-facebook-qualcomm-fall-following-weak-outlooks-432SI-2855929',
#  'https://www.investing.com/news/stock-market-news/first-republic-meta-platforms-harleydavidson-and-foot-locker-rise-premarket-3035609',
#  'https://www.investing.com/news/stock-market-news/tesla-meta-platforms-alibaba-fall-premarket-walmart-wework-rise-2919684',
#  'https://www.investing.com/news/stock-market-news/falling-magnificent-7-volatility-suggests-us-stock-market-not-in-a-bubble--bofa-3310064',
#  'https://www.investing.com/news/stock-market-news/facebook-says-wsj-allegations-are-mischaracterizations-confer-false-motives-2620008',
#  'https://www.investing.com/news/stock-market-news/3-high-profile-tech-stocks-poised-for-more-growth-2501954',
#  'https://www.investing.com/news/stock-market-news/sp-500-rebound-fades-on-global-growth-concerns-ahead-of-fed-meeting-2622485',
#  'https://www.investing.com/news/stock-market-news/eu-top-court-says-youtube-not-liable-for-user-copyright-breaches-2538453',
#  'https://www.investing.com/news/stock-market-news/us-tiktok-content-creators-warn-followers-to-find-them-on-instagram-youtube-3760739',
#  'https://www.investing.com/news/stock-market-news/sp-500-slips-as-stumbling-banks-offset-dipbuying-in-tech-2832534',
#  'https://www.investing.com/news/stock-market-news/facebookbacked-group-launches-misinformation-adjudication-panel-in-australia-2639691',
#  'https://www.investing.com/news/analyst-ratings/keybanc-maintains-meta-stock-overweight-with-750-target-93CH-3839611',
#  'https://www.investing.com/news/stock-market-news/brazil-seriously-concerned-about-meta-changes-to-hate-speech-policy-3812272',
#  'https://www.investing.com/news/world-news/vanuatu-braces-for-heavy-rains-two-days-after-deadly-quake-3781335',
#  'https://www.investing.com/news/stock-market-news/companies-confront-a-new-climate-challenge-home-offices-2818027',
#  'https://www.investing.com/news/stock-market-news/soccerbattle-of-the-brands-man-utd-and-liverpool-look-for-investors-2950997',
#  'https://www.investing.com/news/economy/futures-edge-lower-after-wall-streets-twoday-rally-2625717',
#  'https://www.investing.com/news/stock-market-news/ai-stocks-weak-on-word-microsoft-drops-data-center-leases-in-us-and-europe-3950192',
#  'https://www.investing.com/news/stock-market-news/us-stocks-open-higher-as-tech-earnings-in-focus-2813048',
#  'https://www.investing.com/news/stock-market-news/meta-platforms-stock-soars-17-on-betterthanfeared-results-analysts-see-attractive-valuation-432SI-2812709',
#  'https://www.investing.com/news/pro/meta-platforms-jumps-nearly-4-on-latest-job-cuts-432SI-3030123',
#  'https://www.investing.com/news/cryptocurrency-news/frances-privacy-watchdog-google-analytics-will-be-made-illegal-2763281',
#  'https://www.investing.com/news/pro/guggenheim-maintains-meta-platforms-at-buy-with-a-price-target-of-72500-4016655',
#  'https://www.investing.com/news/analyst-ratings/da-davidson-maintains-buy-on-meta-stock-target-at-650-93CH-3999355',
#  'https://www.investing.com/news/world-news/noconfidence-vote-looms-for-papua-new-guinea-leader-marape-3457973',
#  'https://www.investing.com/news/stock-market-news/rwe-stock-rises-following-new-ppa-with-meta-93CH-3934407',
#  'https://www.investing.com/news/stock-market-news/metas-oversight-board-to-investigate-posts-about-australian-indigenous-vote-3297668',
#  'https://www.investing.com/news/stock-market-news/meta-set-to-enter-bear-market-after-230-billion-value-wipeout-2699105',
#  'https://www.investing.com/news/stock-market-news/stock-market-today-sp-500-slumps-as-chinas-deepseek-ai-threat-rocks-big-tech-3831002',
#  'https://www.investing.com/news/cryptocurrency-news/rocketpads-last-round-for-rocket-public-sale-starts-before-listing-on-major-exchanges-2755797',
#  'https://www.investing.com/news/stock-market-news/tech-ceos-wax-poetic-on-ai-big-adds-to-sales-will-take-time-3064400',
#  'https://www.investing.com/news/pro/arista-networks-receives-investment-bank-analyst-rating-update-3348785',
#  'https://www.investing.com/news/stock-market-news/frances-afp-sues-musks-x-social-media-cites-refusal-to-discuss-payment-for-news-3142825',
#  'https://www.investing.com/news/stock-market-news/facebook-parent-meta-to-pay-725-million-to-settle-lawsuit-relating-to-cambridge-analytica-2969549',
#  'https://www.investing.com/news/company-news/meta-stock-soars-to-alltime-high-of-62984-amid-robust-growth-93CH-3766653',
#  'https://www.investing.com/news/technology-news/us-government-states-ask-judge-to-deny-facebooks-request-to-dismiss-lawsuits-2468790',
#  'https://www.investing.com/news/cryptocurrency-news/decentworld--there-are-many-benefits-of-buying-in-the-metaverse-2896112',
#  'https://www.investing.com/news/stock-market-news/keybanc-raises-estimates-on-alphabet-meta-ahead-of-earnings-3654713',
#  'https://www.investing.com/news/stock-market-news/amazon-looks-to-lure-corporate-customers-with-generative-ai-safety-measures-3245051',
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3548489',
#  'https://www.investing.com/news/stock-market-news/bond-yields-oil-majors-meme-stocks-3-things-to-watch-2553305',
#  'https://www.investing.com/news/stock-market-news/mexicos-new-airport-gets-boost-from-panamas-copa-airlines-2838485',
#  'https://www.investing.com/news/stock-market-news/doj-v-dei-trumps-justice-department-likely-to-target-diversity-programs-3763252',
#  'https://www.investing.com/news/stock-market-news/in-ai-we-trust-bofa-remains-bullish-on-these-5-chip-stocks-3400442',
#  'https://www.investing.com/news/stock-market-news/sp-500-closes-flat-as-fed-minutes-trigger-comeback-2765730',
#  'https://www.investing.com/news/stock-market-news/eu-top-court-sides-with-activist-schrems-in-privacy-dispute-with-meta-3648729',
#  'https://www.investing.com/news/stock-market-news/metas-business-messaging-opportunity-stands-at-3040b-3932131',
#  'https://www.investing.com/news/economy/take-five-over-to-the-fed-3283782',
#  'https://www.investing.com/news/stock-market-news/facebook-owner-meta-planning-lower-bonus-payouts-for-some-employees-wsj-3041780',
#  'https://www.investing.com/news/stock-market-news/how-trumps-tariff-move-impacts-big-tech-3846103',
#  'https://www.investing.com/news/stock-market-news/vietnam-to-require-social-media-users-to-verify-identity-3076001',
#  'https://www.investing.com/news/economy-news/googleparent-alphabet-hits-record-high-after-trump-taps-andrew-ferguson-as-ftc-chair-3767338',
#  'https://www.investing.com/news/stock-market-news/big-tech-anticipates-strong-q3-results-despite-teslas-stumble-93CH-3208260',
#  'https://www.investing.com/news/assorted/meta-platforms--building-ai-technology-for-the-uk-in-a-responsible-and-transparent-way-432SI-3615498',
#  'https://www.investing.com/news/stock-market-news/meta-oversight-board-tells-company-to-clean-up-rules-on-aigenerated-pornography-3535631',
#  'https://www.investing.com/news/cryptocurrency-news/jpex-staff-flee-event-as-scandal-hits-mt-gox-woes-diners-club-crypto-asia-express-3180097',
#  'https://www.investing.com/news/economy/japan-game-giant-nexon-plots-western-expansion-2836197',
#  'https://www.investing.com/news/stock-market-news/meta-to-contest-eu-antitrust-charges-at-july-13-hearing-3124581',
#  'https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3120247',
#  'https://www.investing.com/news/assorted/meta-quest-3-coming-this-fall--lower-prices-for-quest-2-432SI-3096340',
#  'https://www.investing.com/news/stock-market-news/jefferies-analysts-name-their-top-ai-winner-pick-432SI-3358959',
#  'https://www.investing.com/news/stock-market-news/asia-breathes-sigh-of-relief-as-us-jobs-fail-to-shock-2524542',
#  'https://www.investing.com/news/stock-market-news/apples-2-trillion-market-valuation-on-shaky-ground-2837331',
#  'https://www.investing.com/news/cryptocurrency-news/meta-goes-brazil-to-trademark-bitcoin-and-crypto-services-2752688',
#  'https://www.investing.com/news/stock-market-news/musks-x-aims-to-hire-100-content-moderators-in-austin-by-end-of-year-3284998',
#  'https://www.investing.com/news/stock-market-news/uaw-workers-may-vote-on-strike-at-detroit-three-automakers-next-week-3154760',
#  'https://www.investing.com/news/pro/new-street-research-starts-meta-platforms-inc-at-buy-432SI-2972542',
#  'https://www.investing.com/news/general/with-bulletproof-vests-socks-and-soap-us-jews-rush-to-aid-israel-3196387',
#  'https://www.investing.com/news/cryptocurrency-news/bitorbit-is-now-trading-at-155x-following-a-sub1-minute-ido-sellout-2669244',
#  'https://www.investing.com/news/cryptocurrency-news/latin-america-is-ready-for-crypto--just-integrate-it-with-their-payment-systems-2889693',
#  'https://www.investing.com/news/cryptocurrency-news/crypto-flipsider-news---cryptos-hit-2-trillion-market-cap-institutional-investors-prepare-for-reentry-crypto-firms-to-exit-uk-honduras-retracts-bitcoin-as-legal-tender-russia-to-accept-bitcoin-for-oil-and-gas-marc-andreessen-to-l',
#  'https://www.investing.com/news/world-news/air-strikes-heard-in-sudans-capital-after-more-truce-pledges-3071066',
#  'https://www.investing.com/news/stock-market-news/fewer-chickpeas-means-cheap-protein-and-hummus-could-be-harder-to-find-2844401',
#  'https://www.investing.com/news/stock-market-news/western-businesses-cut-some-russia-ties-over-ukraine-invasion-2772929',
#  ...]

# %%
with open('META_urls.txt', 'w') as f:
    for link in links:
        f.write("%s\n" % link)

# %%
# Apply nest_asyncio to allow running asyncio within Jupyter notebook
# This is necessary because Jupyter already uses an event loop
nest_asyncio.apply()

# Configuration parameters for parallel processing and network requests
# Calculate optimal number of workers for fetching HTML (limited to 32)
FETCH_WORKERS = min(32, os.cpu_count() * 4)  
# Use available CPU cores for processing articles 
PROCESS_WORKERS = os.cpu_count() or 4       
# Maximum retry attempts for failed network requests
MAX_FETCH_RETRIES = 3                      
# Delay between retry attempts (seconds)
RETRY_DELAY = 1                             
# Stock ticker symbol used for labeling data
TICKER = 'META'
# Create cloudscraper instance to bypass anti-bot measures
scraper = cloudscraper.create_scraper()

def is_placeholder(html: str) -> bool:
    """
    Check if the HTML content is a placeholder/error page instead of actual content.
    
    These placeholders are common when websites detect scraping or have technical issues.
    """
    lower = html.lower() if html else ""
    return (
        'temporarily down for maintenance' in lower
        or 'just a moment' in lower
        or "we're temporarily down" in lower
    )

def safe_find_datetime(url, html_content=None):
    """
    Extract publication date and time from the URL or HTML content.
    
    Uses multiple strategies with fallbacks:
    1. Try htmldate library on URL
    2. Look for American format dates (MM/DD/YYYY, HH:MM AM/PM) in content
    3. Try both European and American formats (DD/MM/YYYY or MM/DD/YYYY)
    4. Fallback to current date and time if all else fails
    
    Returns: tuple of (date_string, time_string)
    """
    try:
        # Strategy 1: Use htmldate library to extract date from URL
        dt = find_date(url)
        if dt:
            return dt, "00:00"  # Return with default time if date found
    except:
        pass
    
    if html_content:
        # Strategy 2: Look for American format with AM/PM
        m = re.search(r"(\d{1,2}/\d{1,2}/\d{4}),\s*(\d{1,2}:\d{2}\s*(?:AM|PM))", html_content)
        if m:
            ds, ts = m.groups()
            try:
                dt = datetime.strptime(f"{ds}, {ts}", "%m/%d/%Y, %I:%M %p")
                return dt.strftime("%Y-%m-%d"), dt.strftime("%H:%M")
            except:
                pass
        
        # Strategy 3: Look for numeric dates with 24-hour time format
        m = re.search(r"(\d{2}/\d{2}/\d{4}),\s*(\d{2}:\d{2})", html_content)
        if m:
            ds, ts = m.groups()
            # Try both European and American date formats
            for fmt in ("%d/%m/%Y, %H:%M", "%m/%d/%Y, %H:%M"):
                try:
                    dt = datetime.strptime(f"{ds}, {ts}", fmt)
                    return dt.strftime("%Y-%m-%d"), dt.strftime("%H:%M")
                except:
                    continue
    
    # Fallback: Use current date and time
    now = datetime.now()
    return now.strftime("%Y-%m-%d"), now.strftime("%H:%M")

# ——— Fetch HTML with minimal retry mechanism ———
def fetch_html(url, idx, total):
    """
    Fetch the HTML content for a given URL with retry logic.
    
    Args:
        url: The URL to fetch
        idx: Current index (for progress reporting)
        total: Total number of URLs (for progress reporting)
        
    Returns:
        tuple of (url, html_content) or (url, None) if failed
    """
    for attempt in range(1, MAX_FETCH_RETRIES + 1):
        try:
            # Make HTTP request with timeout
            resp = scraper.get(url, timeout=30)
            html = resp.text
            
            # Check if we got a placeholder page instead of content
            if is_placeholder(html):
                raise RuntimeError('Placeholder')
                
            # Report success
            print(f"[Fetch][{idx}/{total}][ok]")
            return url, html
            
        except Exception:
            # Report retry attempt
            print(f"[Fetch][{idx}/{total}][retry {attempt}]")
            if attempt < MAX_FETCH_RETRIES:
                # Wait before retrying
                time.sleep(RETRY_DELAY)
                
    # Report complete failure after all retries
    print(f"[Fetch error] {idx}/{total}: failed after {MAX_FETCH_RETRIES} retries")
    return url, None

# ——— Initialize sentiment analyzer from NLTK ———
SID = SentimentIntensityAnalyzer()

def process_article(arg):
    """
    Process an article's HTML to extract content and analyze sentiment.
    
    Uses newspaper3k library to parse article content and NLTK's VADER
    for sentiment analysis.
    
    Args:
        arg: tuple of (url, html_content)
        
    Returns:
        dictionary with extracted data and sentiment scores, or None if processing failed
    """
    url, html = arg
    if not html:
        return None
        
    # Initialize newspaper Article object
    art = Article(url)
    art.set_html(html)
    
    try:
        # Parse article content
        art.parse()
    except:
        return None
        
    # Extract text and title
    text = art.text or ""
    title = (art.title or "").strip() or "No title"
    
    # Calculate sentiment scores using VADER
    pol = SID.polarity_scores(text)
    
    # Extract publication date and time
    date, tm = safe_find_datetime(url, html)
    
    # Return combined data using dictionary unpacking
    return {**{'ticker': TICKER, 'publish_date': date, 'publish_time': tm,
             'title': title, 'body_text': text, 'url': url}, **pol}

async def scrape_all(urls):
    """
    Asynchronous pipeline to fetch and process multiple URLs in parallel.
    
    Implements a two-phase approach:
    1. Fetch all URLs concurrently using threads
    2. Process all fetched content concurrently using threads
    
    Args:
        urls: List of URLs to process
        
    Returns:
        pandas DataFrame containing all processed articles
    """
    total = len(urls)
    loop = asyncio.get_event_loop()
    
    # Phase 1: Fetch HTML content from all URLs in parallel
    with ThreadPoolExecutor(max_workers=FETCH_WORKERS) as fetch_pool:
        # Create fetch tasks and run them through the thread pool
        fetch_tasks = [loop.run_in_executor(fetch_pool, fetch_html, u, i+1, total)
                       for i, u in enumerate(urls)]
        # Wait for all fetch tasks to complete
        fetched = await asyncio.gather(*fetch_tasks)

    # Phase 2: Process all fetched HTML content in parallel
    records = []
    with ThreadPoolExecutor(max_workers=PROCESS_WORKERS) as proc_pool:
        # Submit processing tasks only for URLs with successful fetches
        futures = {
            proc_pool.submit(process_article, fr): fr[0]
            for fr in fetched if fr[1]  # Skip URLs where HTML is None
        }
        
        # Process results as they complete
        for i, fut in enumerate(as_completed(futures), 1):
            res = fut.result()
            print(f"[Process][{i}/{total}] {futures[fut]}")
            if res:
                records.append(res)
                
    # Convert results to DataFrame
    return pd.DataFrame(records)

# ——— Main entry point function ———
def main(links):
    """
    Main function that runs the entire scraping pipeline.
    
    Args:
        links: List of URLs to process
        
    Returns:
        pandas DataFrame with processed articles
    """
    df = asyncio.get_event_loop().run_until_complete(scrape_all(links))
    return df

# Execute the main function if this script is run directly
if __name__ == '__main__':
    df = main(links)
    print(df.shape)
    print(df.head())
# Out:
# [Fetch][20/9999][retry 1]
# [Fetch][23/9999][retry 1]
# [Fetch][25/9999][retry 1]
# [Fetch][22/9999][retry 1]
# [Fetch][31/9999][retry 1]
# [Fetch][32/9999][retry 1]
# [Fetch][12/9999][ok]
# [Fetch][19/9999][ok]
# [Fetch][17/9999][ok]
# [Fetch][14/9999][ok]
# [Fetch][7/9999][ok]
# [Fetch][9/9999][ok]
# [Fetch][2/9999][ok]
# [Fetch][21/9999][ok]
# [Fetch][13/9999][ok]
# [Fetch][16/9999][ok]
# [Fetch][8/9999][ok]
# [Fetch][11/9999][ok]
# [Fetch][4/9999][ok]
# [Fetch][1/9999][ok]
# [Fetch][6/9999][ok]
# [Fetch][10/9999][ok]
# [Fetch][5/9999][ok]
# [Fetch][18/9999][ok]
# [Fetch][3/9999][ok]
# [Fetch][15/9999][ok]
# [Fetch][29/9999][ok]
# [Fetch][24/9999][ok]
# [Fetch][30/9999][ok]
# [Fetch][26/9999][ok]
# [Fetch][28/9999][ok]
# [Fetch][27/9999][ok]
# [Fetch][33/9999][ok]
# [Fetch][34/9999][ok]
# [Fetch][47/9999][ok]
# [Fetch][40/9999][ok]
# [Fetch][50/9999][ok]
# [Fetch][36/9999][ok]
# [Fetch][49/9999][ok]
# [Fetch][39/9999][ok]
# [Fetch][23/9999][ok]
# [Fetch][38/9999][ok]
# [Fetch][52/9999][ok]
# [Fetch][55/9999][ok]
# [Fetch][53/9999][ok]
# [Fetch][46/9999][ok]
# [Fetch][41/9999][ok]
# [Fetch][37/9999][ok]
# [Fetch][48/9999][ok]
# [Fetch][35/9999][ok][Fetch][54/9999][ok]
#
# [Fetch][56/9999][ok]
# [Fetch][45/9999][ok]
# [Fetch][25/9999][ok]
# [Fetch][22/9999][ok]
# [Fetch][20/9999][ok]
# [Fetch][59/9999][ok]
# [Fetch][57/9999][ok]
# [Fetch][60/9999][ok]
# [Fetch][51/9999][ok]
# [Fetch][58/9999][ok]
# [Fetch][43/9999][ok]
# [Fetch][42/9999][ok]
# [Fetch][61/9999][ok]
# [Fetch][62/9999][ok]
# [Fetch][63/9999][ok]
# [Fetch][68/9999][ok]
# [Fetch][66/9999][ok]
# [Fetch][32/9999][ok]
# [Fetch][65/9999][ok]
# [Fetch][69/9999][ok]
# [Fetch][64/9999][ok]
# [Fetch][67/9999][ok]
# [Fetch][31/9999][ok]
# [Fetch][73/9999][ok]
# [Fetch][75/9999][ok]
# [Fetch][76/9999][ok]
# [Fetch][74/9999][ok]
# [Fetch][71/9999][ok]
# [Fetch][80/9999][ok]
# [Fetch][81/9999][ok]
# [Fetch][72/9999][ok]
# [Fetch][83/9999][ok]
# [Fetch][79/9999][ok]
# [Fetch][77/9999][ok]
# [Fetch][86/9999][ok]
# [Fetch][78/9999][ok]
# [Fetch][82/9999][ok]
# [Fetch][88/9999][ok]
# [Fetch][70/9999][ok]
# [Fetch][89/9999][ok]
# [Fetch][85/9999][ok]
# [Fetch][92/9999][ok][Fetch][44/9999][ok]
#
# [Fetch][94/9999][ok]
# [Fetch][95/9999][ok]
# [Fetch][91/9999][ok]
# [Fetch][90/9999][ok]
# [Fetch][98/9999][ok]
# [Fetch][97/9999][ok]
# [Fetch][93/9999][ok]
# [Fetch][100/9999][ok]
# [Fetch][102/9999][ok]
# [Fetch][99/9999][ok]
# [Fetch][101/9999][ok]
# [Fetch][105/9999][ok]
# [Fetch][109/9999][ok]
# [Fetch][108/9999][ok]
# [Fetch][110/9999][ok]
# [Fetch][104/9999][ok]
# [Fetch][103/9999][ok]
# [Fetch][111/9999][ok]
# [Fetch][106/9999][ok]
# [Fetch][112/9999][ok]
# [Fetch][117/9999][ok]
# [Fetch][118/9999][ok]
# [Fetch][107/9999][ok]
# [Fetch][116/9999][ok]
# [Fetch][114/9999][ok]
# [Fetch][120/9999][ok]
# [Fetch][115/9999][ok]
# [Fetch][122/9999][ok]
# [Fetch][128/9999][ok]
# [Fetch][125/9999][ok]
# [Fetch][124/9999][ok]
# [Fetch][119/9999][ok]
# [Fetch][113/9999][ok]
# [Fetch][127/9999][ok]
# [Fetch][121/9999][ok]
# [Fetch][84/9999][ok]
# [Fetch][137/9999][ok]
# [Fetch][133/9999][ok]
# [Fetch][134/9999][ok]
# [Fetch][131/9999][ok]
# [Fetch][129/9999][ok]
# [Fetch][139/9999][ok]
# [Fetch][136/9999][ok]
# [Fetch][126/9999][ok]
# [Fetch][141/9999][ok]
# [Fetch][130/9999][ok]
# [Fetch][138/9999][ok]
# [Fetch][87/9999][ok]
# [Fetch][143/9999][ok]
# [Fetch][144/9999][ok]
# [Fetch][149/9999][ok]
# [Fetch][145/9999][ok]
# [Fetch][96/9999][ok]
# [Fetch][142/9999][ok]
# [Fetch][148/9999][ok]
# [Fetch][146/9999][ok]
# [Fetch][123/9999][ok]
# [Fetch][150/9999][ok]
# [Fetch][152/9999][ok]
# [Fetch][151/9999][ok]
# [Fetch][147/9999][ok]
# [Fetch][155/9999][ok]
# [Fetch][153/9999][ok]
# [Fetch][157/9999][ok]
# [Fetch][161/9999][ok]
# [Fetch][160/9999][ok]
# [Fetch][162/9999][ok]
# [Fetch][163/9999][ok]
# [Fetch][165/9999][ok]
# [Fetch][156/9999][ok]
# [Fetch][164/9999][ok]
# [Fetch][132/9999][ok]
# [Fetch][159/9999][ok]
# [Fetch][167/9999][ok]
# [Fetch][140/9999][ok]
# [Fetch][154/9999][ok]
# [Fetch][166/9999][ok]
# [Fetch][135/9999][ok]
# [Fetch][168/9999][ok]
# [Fetch][170/9999][ok]
# [Fetch][169/9999][ok]
# [Fetch][158/9999][ok]
# [Fetch][172/9999][ok]
# [Fetch][175/9999][ok]
# [Fetch][176/9999][ok]
# [Fetch][181/9999][ok]
# [Fetch][178/9999][ok]
# [Fetch][174/9999][ok]
# [Fetch][177/9999][ok]
# [Fetch][171/9999][ok][Fetch][173/9999][ok]
#
# [Fetch][185/9999][ok]
# [Fetch][180/9999][ok]
# [Fetch][184/9999][ok]
# [Fetch][187/9999][ok]
# [Fetch][179/9999][ok]
# [Fetch][186/9999][ok]
# [Fetch][182/9999][ok]
# [Fetch][189/9999][ok]
# [Fetch][188/9999][ok]
# [Fetch][190/9999][ok]
# [Fetch][193/9999][ok]
# [Fetch][191/9999][ok]
# [Fetch][192/9999][ok]
# [Fetch][198/9999][ok]
# [Fetch][199/9999][ok]
# [Fetch][195/9999][ok]
# [Fetch][197/9999][ok]
# [Fetch][203/9999][ok]
# [Fetch][194/9999][ok]
# [Fetch][200/9999][ok]
# [Fetch][202/9999][ok]
# [Fetch][204/9999][ok]
# [Fetch][201/9999][ok]
# [Fetch][183/9999][ok]
# [Fetch][205/9999][ok]
# [Fetch][210/9999][ok]
# [Fetch][212/9999][ok]
# [Fetch][207/9999][ok]
# [Fetch][214/9999][ok]
# [Fetch][208/9999][ok]
# [Fetch][216/9999][ok]
# [Fetch][220/9999][ok]
# [Fetch][211/9999][ok]
# [Fetch][219/9999][ok]
# [Fetch][206/9999][ok][Fetch][215/9999][ok]
#
# [Fetch][213/9999][ok]
# [Fetch][218/9999][ok]
# [Fetch][209/9999][ok]
# [Fetch][196/9999][ok]
# [Fetch][221/9999][ok]
# [Fetch][226/9999][ok]
# [Fetch][225/9999][ok]
# [Fetch][223/9999][ok]
# [Fetch][217/9999][ok]
# [Fetch][222/9999][ok]
# [Fetch][231/9999][ok]
# [Fetch][224/9999][ok]
# [Fetch][228/9999][ok]
# [Fetch][230/9999][ok]
# [Fetch][227/9999][ok]
# [Fetch][232/9999][ok]
# [Fetch][229/9999][ok]
# [Fetch][233/9999][ok]
# [Fetch][234/9999][ok]
# [Fetch][235/9999][ok]
# [Fetch][236/9999][ok]
# [Fetch][240/9999][ok]
# [Fetch][237/9999][ok]
# [Fetch][238/9999][ok]
# [Fetch][241/9999][ok]
# [Fetch][239/9999][ok]
# [Fetch][247/9999][ok]
# [Fetch][246/9999][ok]
# [Fetch][248/9999][ok]
# [Fetch][250/9999][ok]
# [Fetch][251/9999][ok]
# [Fetch][245/9999][ok]
# [Fetch][243/9999][ok]
# [Fetch][255/9999][ok]
# [Fetch][252/9999][ok]
# [Fetch][260/9999][ok]
# [Fetch][253/9999][ok]
# [Fetch][244/9999][ok]
# [Fetch][242/9999][ok]
# [Fetch][249/9999][ok]
# [Fetch][254/9999][ok]
# [Fetch][262/9999][ok]
# [Fetch][258/9999][ok]
# [Fetch][257/9999][ok]
# [Fetch][261/9999][ok]
# [Fetch][267/9999][ok]
# [Fetch][264/9999][ok]
# [Fetch][259/9999][ok]
# [Fetch][256/9999][ok]
# [Fetch][265/9999][ok]
# [Fetch][273/9999][ok]
# [Fetch][266/9999][ok]
# [Fetch][268/9999][ok]
# [Fetch][269/9999][ok]
# [Fetch][270/9999][ok]
# [Fetch][271/9999][ok]
# [Fetch][272/9999][ok]
# [Fetch][274/9999][ok]
# [Fetch][263/9999][ok]
# [Fetch][277/9999][ok]
# [Fetch][275/9999][ok]
# [Fetch][278/9999][ok]
# [Fetch][276/9999][ok]
# [Fetch][279/9999][ok]
# [Fetch][284/9999][ok]
# [Fetch][280/9999][ok]
# [Fetch][285/9999][ok]
# [Fetch][288/9999][ok]
# [Fetch][287/9999][ok]
# [Fetch][282/9999][ok]
# [Fetch][286/9999][ok]
# [Fetch][290/9999][ok]
# [Fetch][281/9999][ok]
# [Fetch][295/9999][ok]
# [Fetch][292/9999][ok]
# [Fetch][291/9999][ok]
# [Fetch][293/9999][ok]
# [Fetch][283/9999][ok]
# [Fetch][296/9999][ok]
# [Fetch][294/9999][ok]
# [Fetch][297/9999][ok]
# [Fetch][289/9999][ok]
# [Fetch][302/9999][ok]
# [Fetch][306/9999][ok]
# [Fetch][301/9999][ok]
# [Fetch][305/9999][ok]
# [Fetch][304/9999][ok]
# [Fetch][299/9999][ok]
# [Fetch][309/9999][ok]
# [Fetch][311/9999][ok]
# [Fetch][312/9999][ok]
# [Fetch][314/9999][ok]
# [Fetch][315/9999][ok]
# [Fetch][298/9999][ok]
# [Fetch][321/9999][ok]
# [Fetch][319/9999][ok]
# [Fetch][313/9999][ok]
# [Fetch][324/9999][ok]
# [Fetch][318/9999][ok]
# [Fetch][322/9999][ok]
# [Fetch][320/9999][ok]
# [Fetch][307/9999][ok]
# [Fetch][317/9999][ok]
# [Fetch][300/9999][ok]
# [Fetch][316/9999][ok]
# [Fetch][327/9999][ok]
# [Fetch][308/9999][ok]
# [Fetch][323/9999][ok]
# [Fetch][310/9999][ok]
# [Fetch][325/9999][ok]
# [Fetch][330/9999][ok]
# [Fetch][334/9999][ok]
# [Fetch][303/9999][ok]
# [Fetch][336/9999][ok]
# [Fetch][328/9999][ok]
# [Fetch][329/9999][ok]
# [Fetch][331/9999][ok]
# [Fetch][338/9999][ok]
# [Fetch][337/9999][ok]
# [Fetch][341/9999][ok]
# [Fetch][344/9999][ok]
# [Fetch][339/9999][ok]
# [Fetch][343/9999][ok]
# [Fetch][349/9999][ok]
# [Fetch][342/9999][ok]
# [Fetch][345/9999][ok]
# [Fetch][346/9999][ok]
# [Fetch][340/9999][ok]
# [Fetch][351/9999][ok]
# [Fetch][326/9999][ok]
# [Fetch][350/9999][ok]
# [Fetch][354/9999][ok]
# [Fetch][353/9999][ok]
# [Fetch][347/9999][ok]
# [Fetch][355/9999][ok]
# [Fetch][360/9999][ok]
# [Fetch][358/9999][ok]
# [Fetch][348/9999][ok]
# [Fetch][352/9999][ok]
# [Fetch][357/9999][ok]
# [Fetch][333/9999][ok]
# [Fetch][356/9999][ok]
# [Fetch][359/9999][ok]
# [Fetch][364/9999][ok]
# [Fetch][361/9999][ok]
# [Fetch][362/9999][ok]
# [Fetch][332/9999][ok]
# [Fetch][367/9999][ok]
# [Fetch][363/9999][ok]
# [Fetch][368/9999][ok]
# [Fetch][366/9999][ok]
# [Fetch][370/9999][ok]
# [Fetch][365/9999][ok]
# [Fetch][372/9999][ok]
# [Fetch][373/9999][ok]
# [Fetch][374/9999][ok]
# [Fetch][371/9999][ok]
# [Fetch][375/9999][ok]
# [Fetch][377/9999][ok]
# [Fetch][380/9999][ok]
# [Fetch][381/9999][ok]
# [Fetch][384/9999][ok]
# [Fetch][386/9999][ok]
# [Fetch][379/9999][ok]
# [Fetch][382/9999][ok]
# [Fetch][378/9999][ok]
# [Fetch][387/9999][ok]
# [Fetch][389/9999][ok]
# [Fetch][393/9999][ok]
# [Fetch][390/9999][ok]
# [Fetch][335/9999][ok]
# [Fetch][388/9999][ok]
# [Fetch][391/9999][ok]
# [Fetch][394/9999][ok]
# [Fetch][395/9999][ok]
# [Fetch][396/9999][ok]
# [Fetch][399/9999][ok]
# [Fetch][369/9999][ok]
# [Fetch][401/9999][ok]
# [Fetch][397/9999][ok]
# [Fetch][400/9999][ok]
# [Fetch][392/9999][ok]
# [Fetch][376/9999][ok]
# [Fetch][402/9999][ok]
# [Fetch][406/9999][ok]
# [Fetch][403/9999][ok]
# [Fetch][383/9999][ok]
# [Fetch][407/9999][ok]
# [Fetch][404/9999][ok]
# [Fetch][405/9999][ok]
# [Fetch][408/9999][ok]
# [Fetch][409/9999][ok]
# [Fetch][410/9999][ok]
# [Fetch][416/9999][ok]
# [Fetch][385/9999][ok]
# [Fetch][417/9999][ok]
# [Fetch][415/9999][ok]
# [Fetch][413/9999][ok]
# [Fetch][411/9999][ok]
# [Fetch][414/9999][ok]
# [Fetch][418/9999][ok]
# [Fetch][422/9999][ok]
# [Fetch][419/9999][ok]
# [Fetch][424/9999][ok]
# [Fetch][421/9999][ok]
# [Fetch][412/9999][ok]
# [Fetch][425/9999][ok]
# [Fetch][431/9999][ok]
# [Fetch][426/9999][ok]
# [Fetch][428/9999][ok]
# [Fetch][420/9999][ok]
# [Fetch][432/9999][ok]
# [Fetch][429/9999][ok]
# [Fetch][430/9999][ok]
# [Fetch][433/9999][ok]
# [Fetch][427/9999][ok]
# [Fetch][438/9999][ok]
# [Fetch][440/9999][ok]
# [Fetch][435/9999][ok]
# [Fetch][441/9999][ok]
# [Fetch][423/9999][ok]
# [Fetch][434/9999][ok]
# [Fetch][436/9999][ok]
# [Fetch][439/9999][ok]
# [Fetch][437/9999][ok]
# [Fetch][444/9999][ok]
# [Fetch][443/9999][ok]
# [Fetch][442/9999][ok]
# [Fetch][398/9999][ok]
# [Fetch][450/9999][ok]
# [Fetch][452/9999][ok]
# [Fetch][446/9999][ok]
# [Fetch][447/9999][ok]
# [Fetch][451/9999][ok]
# [Fetch][448/9999][ok]
# [Fetch][445/9999][ok]
# [Fetch][449/9999][ok]
# [Fetch][453/9999][ok]
# [Fetch][458/9999][ok]
# [Fetch][456/9999][ok]
# [Fetch][459/9999][ok]
# [Fetch][457/9999][ok]
# [Fetch][454/9999][ok]
# [Fetch][462/9999][ok]
# [Fetch][464/9999][ok]
# [Fetch][460/9999][ok]
# [Fetch][472/9999][ok]
# [Fetch][463/9999][ok]
# [Fetch][468/9999][ok]
# [Fetch][465/9999][ok]
# [Fetch][461/9999][ok]
# [Fetch][473/9999][ok]
# [Fetch][470/9999][ok]
# [Fetch][469/9999][ok]
# [Fetch][475/9999][ok]
# [Fetch][467/9999][ok]
# [Fetch][477/9999][ok]
# [Fetch][478/9999][ok]
# [Fetch][474/9999][ok]
# [Fetch][481/9999][ok]
# [Fetch][480/9999][ok]
# [Fetch][482/9999][ok]
# [Fetch][487/9999][ok]
# [Fetch][492/9999][ok]
# [Fetch][479/9999][ok]
# [Fetch][489/9999][ok]
# [Fetch][471/9999][ok]
# [Fetch][483/9999][ok]
# [Fetch][485/9999][ok]
# [Fetch][488/9999][ok]
# [Fetch][491/9999][ok]
# [Fetch][496/9999][ok]
# [Fetch][490/9999][ok]
# [Fetch][501/9999][ok]
# [Fetch][497/9999][ok]
# [Fetch][502/9999][ok]
# [Fetch][466/9999][ok]
# [Fetch][494/9999][ok]
# [Fetch][455/9999][ok]
# [Fetch][498/9999][ok]
# [Fetch][505/9999][ok]
# [Fetch][495/9999][ok]
# [Fetch][504/9999][ok]
# [Fetch][500/9999][ok]
# [Fetch][486/9999][ok]
# [Fetch][484/9999][ok]
# [Fetch][476/9999][ok]
# [Fetch][503/9999][ok]
# [Fetch][506/9999][ok]
# [Fetch][499/9999][ok]
# [Fetch][509/9999][ok]
# [Fetch][507/9999][ok]
# [Fetch][510/9999][ok]
# [Fetch][515/9999][ok]
# [Fetch][517/9999][ok]
# [Fetch][516/9999][ok]
# [Fetch][508/9999][ok]
# [Fetch][511/9999][ok]
# [Fetch][514/9999][ok]
# [Fetch][512/9999][ok]
# [Fetch][518/9999][ok]
# [Fetch][521/9999][ok]
# [Fetch][519/9999][ok]
# [Fetch][520/9999][ok]
# [Fetch][522/9999][ok]
# [Fetch][526/9999][ok]
# [Fetch][525/9999][ok]
# [Fetch][523/9999][ok]
# [Fetch][527/9999][ok]
# [Fetch][531/9999][ok]
# [Fetch][532/9999][ok]
# [Fetch][530/9999][ok]
# [Fetch][524/9999][ok]
# [Fetch][533/9999][ok]
# [Fetch][538/9999][ok]
# [Fetch][544/9999][ok]
# [Fetch][541/9999][ok]
# [Fetch][529/9999][ok]
# [Fetch][535/9999][ok]
# [Fetch][513/9999][ok]
# [Fetch][540/9999][ok]
# [Fetch][543/9999][ok]
# [Fetch][542/9999][ok]
# [Fetch][539/9999][ok]
# [Fetch][537/9999][ok]
# [Fetch][534/9999][ok]
# [Fetch][546/9999][ok]
# [Fetch][545/9999][ok]
# [Fetch][550/9999][ok]
# [Fetch][536/9999][ok]
# [Fetch][547/9999][ok]
# [Fetch][548/9999][ok]
# [Fetch][493/9999][ok]
# [Fetch][551/9999][ok]
# [Fetch][555/9999][ok]
# [Fetch][552/9999][ok]
# [Fetch][564/9999][ok]
# [Fetch][556/9999][ok]
# [Fetch][561/9999][ok]
# [Fetch][554/9999][ok]
# [Fetch][553/9999][ok]
# [Fetch][528/9999][ok]
# [Fetch][558/9999][ok]
# [Fetch][560/9999][ok]
# [Fetch][549/9999][ok]
# [Fetch][562/9999][ok]
# [Fetch][563/9999][ok]
# [Fetch][557/9999][ok]
# [Fetch][559/9999][ok]
# [Fetch][570/9999][ok]
# [Fetch][575/9999][ok]
# [Fetch][565/9999][ok]
# [Fetch][572/9999][ok]
# [Fetch][576/9999][ok]
# [Fetch][571/9999][ok]
# [Fetch][578/9999][ok]
# [Fetch][580/9999][ok]
# [Fetch][566/9999][ok]
# [Fetch][573/9999][ok]
# [Fetch][574/9999][ok]
# [Fetch][568/9999][ok]
# [Fetch][581/9999][ok]
# [Fetch][579/9999][ok]
# [Fetch][582/9999][ok]
# [Fetch][577/9999][ok]
# [Fetch][567/9999][ok]
# [Fetch][587/9999][ok]
# [Fetch][588/9999][ok]
# [Fetch][583/9999][ok]
# [Fetch][593/9999][ok]
# [Fetch][584/9999][ok]
# [Fetch][591/9999][ok]
# [Fetch][595/9999][ok]
# [Fetch][589/9999][ok]
# [Fetch][585/9999][ok]
# [Fetch][594/9999][ok]
# [Fetch][569/9999][ok]
# [Fetch][598/9999][ok]
# [Fetch][597/9999][ok]
# [Fetch][590/9999][ok]
# [Fetch][592/9999][ok]
# [Fetch][596/9999][ok]
# [Fetch][605/9999][ok]
# [Fetch][602/9999][ok]
# [Fetch][600/9999][ok]
# [Fetch][608/9999][ok]
# [Fetch][599/9999][ok]
# [Fetch][606/9999][ok]
# [Fetch][610/9999][ok]
# [Fetch][603/9999][ok]
# [Fetch][609/9999][ok]
# [Fetch][604/9999][ok]
# [Fetch][601/9999][ok]
# [Fetch][607/9999][ok]
# [Fetch][611/9999][ok]
# [Fetch][615/9999][ok]
# [Fetch][613/9999][ok]
# [Fetch][618/9999][ok]
# [Fetch][612/9999][ok]
# [Fetch][616/9999][ok]
# [Fetch][617/9999][ok]
# [Fetch][621/9999][ok]
# [Fetch][614/9999][ok]
# [Fetch][586/9999][ok]
# [Fetch][625/9999][ok]
# [Fetch][624/9999][ok]
# [Fetch][620/9999][ok]
# [Fetch][626/9999][ok]
# [Fetch][622/9999][ok]
# [Fetch][619/9999][ok]
# [Fetch][633/9999][ok]
# [Fetch][631/9999][ok]
# [Fetch][630/9999][ok]
# [Fetch][634/9999][ok]
# [Fetch][629/9999][ok]
# [Fetch][635/9999][ok]
# [Fetch][623/9999][ok]
# [Fetch][636/9999][ok]
# [Fetch][639/9999][ok]
# [Fetch][640/9999][ok]
# [Fetch][643/9999][ok]
# [Fetch][627/9999][ok]
# [Fetch][637/9999][ok]
# [Fetch][632/9999][ok]
# [Fetch][628/9999][ok]
# [Fetch][641/9999][ok]
# [Fetch][642/9999][ok]
# [Fetch][638/9999][ok]
# [Fetch][648/9999][ok]
# [Fetch][646/9999][ok]
# [Fetch][647/9999][ok]
# [Fetch][651/9999][ok]
# [Fetch][649/9999][ok]
# [Fetch][644/9999][ok]
# [Fetch][653/9999][ok]
# [Fetch][657/9999][ok]
# [Fetch][650/9999][ok]
# [Fetch][654/9999][ok]
# [Fetch][656/9999][ok]
# [Fetch][661/9999][ok]
# [Fetch][659/9999][ok]
# [Fetch][652/9999][ok]
# [Fetch][645/9999][ok]
# [Fetch][655/9999][ok]
# [Fetch][660/9999][ok]
# [Fetch][664/9999][ok]
# [Fetch][658/9999][ok]
# [Fetch][665/9999][ok]
# [Fetch][669/9999][ok]
# [Fetch][663/9999][ok]
# [Fetch][668/9999][ok]
# [Fetch][667/9999][ok]
# [Fetch][676/9999][ok]
# [Fetch][673/9999][ok]
# [Fetch][675/9999][ok]
# [Fetch][671/9999][ok]
# [Fetch][674/9999][ok]
# [Fetch][677/9999][ok]
# [Fetch][670/9999][ok]
# [Fetch][672/9999][ok]
# [Fetch][681/9999][ok]
# [Fetch][678/9999][ok]
# [Fetch][684/9999][ok]
# [Fetch][679/9999][ok]
# [Fetch][683/9999][ok]
# [Fetch][680/9999][ok]
# [Fetch][682/9999][ok]
# [Fetch][685/9999][ok]
# [Fetch][688/9999][ok]
# [Fetch][689/9999][ok]
# [Fetch][690/9999][ok]
# [Fetch][687/9999][ok]
# [Fetch][691/9999][ok]
# [Fetch][693/9999][ok]
# [Fetch][692/9999][ok]
# [Fetch][694/9999][ok]
# [Fetch][666/9999][ok]
# [Fetch][662/9999][ok]
# [Fetch][696/9999][ok]
# [Fetch][703/9999][ok]
# [Fetch][700/9999][ok]
# [Fetch][697/9999][ok]
# [Fetch][702/9999][ok]
# [Fetch][699/9999][ok]
# [Fetch][701/9999][ok]
# [Fetch][708/9999][ok]
# [Fetch][704/9999][ok]
# [Fetch][706/9999][ok]
# [Fetch][716/9999][ok]
# [Fetch][709/9999][ok]
# [Fetch][710/9999][ok]
# [Fetch][686/9999][ok]
# [Fetch][705/9999][ok]
# [Fetch][713/9999][ok]
# [Fetch][711/9999][ok]
# [Fetch][718/9999][ok]
# [Fetch][714/9999][ok]
# [Fetch][715/9999][ok]
# [Fetch][712/9999][ok]
# [Fetch][707/9999][ok]
# [Fetch][724/9999][ok]
# [Fetch][720/9999][ok]
# [Fetch][695/9999][ok]
# [Fetch][728/9999][ok]
# [Fetch][729/9999][ok]
# [Fetch][698/9999][ok]
# [Fetch][727/9999][ok]
# [Fetch][723/9999][ok]
# [Fetch][730/9999][ok]
# [Fetch][725/9999][ok]
# [Fetch][722/9999][ok]
# [Fetch][717/9999][ok]
# [Fetch][721/9999][ok]
# [Fetch][731/9999][ok]
# [Fetch][732/9999][ok]
# [Fetch][719/9999][ok]
# [Fetch][735/9999][ok]
# [Fetch][733/9999][ok]
# [Fetch][741/9999][ok]
# [Fetch][736/9999][ok]
# [Fetch][737/9999][ok]
# [Fetch][747/9999][ok]
# [Fetch][740/9999][ok][Fetch][744/9999][ok]
#
# [Fetch][743/9999][ok]
# [Fetch][734/9999][ok]
# [Fetch][751/9999][ok]
# [Fetch][742/9999][ok]
# [Fetch][745/9999][ok]
# [Fetch][739/9999][ok]
# [Fetch][752/9999][ok]
# [Fetch][756/9999][ok]
# [Fetch][748/9999][ok]
# [Fetch][754/9999][ok]
# [Fetch][750/9999][ok]
# [Fetch][753/9999][ok]
# [Fetch][749/9999][ok]
# [Fetch][757/9999][ok]
# [Fetch][755/9999][ok]
# [Fetch][758/9999][ok]
# [Fetch][726/9999][ok]
# [Fetch][746/9999][ok]
# [Fetch][738/9999][ok]
# [Fetch][761/9999][ok]
# [Fetch][760/9999][ok]
# [Fetch][763/9999][ok]
# [Fetch][764/9999][ok]
# [Fetch][766/9999][ok]
# [Fetch][767/9999][ok]
# [Fetch][768/9999][ok]
# [Fetch][774/9999][ok]
# [Fetch][759/9999][ok]
# [Fetch][769/9999][ok]
# [Fetch][771/9999][ok]
# [Fetch][777/9999][ok]
# [Fetch][770/9999][ok]
# [Fetch][762/9999][ok]
# [Fetch][780/9999][ok]
# [Fetch][776/9999][ok]
# [Fetch][778/9999][ok]
# [Fetch][773/9999][ok]
# [Fetch][765/9999][ok]
# [Fetch][782/9999][ok]
# [Fetch][772/9999][ok]
# [Fetch][784/9999][ok]
# [Fetch][781/9999][ok]
# [Fetch][775/9999][ok]
# [Fetch][787/9999][ok]
# [Fetch][783/9999][ok]
# [Fetch][790/9999][ok]
# [Fetch][785/9999][ok]
# [Fetch][792/9999][ok]
# [Fetch][794/9999][ok]
# [Fetch][786/9999][ok]
# [Fetch][788/9999][ok]
# [Fetch][779/9999][ok]
# [Fetch][791/9999][ok]
# [Fetch][796/9999][ok]
# [Fetch][793/9999][ok]
# [Fetch][789/9999][ok]
# [Fetch][797/9999][ok]
# [Fetch][795/9999][ok]
# [Fetch][798/9999][ok]
# [Fetch][801/9999][ok]
# [Fetch][799/9999][ok]
# [Fetch][802/9999][ok]
# [Fetch][814/9999][ok]
# [Fetch][803/9999][ok]
# [Fetch][810/9999][ok]
# [Fetch][812/9999][ok]
# [Fetch][804/9999][ok]
# [Fetch][806/9999][ok]
# [Fetch][807/9999][ok]
# [Fetch][800/9999][ok]
# [Fetch][824/9999][ok]
# [Fetch][826/9999][ok]
# [Fetch][811/9999][ok]
# [Fetch][825/9999][ok]
# [Fetch][820/9999][ok]
# [Fetch][816/9999][ok]
# [Fetch][813/9999][ok]
# [Fetch][819/9999][ok]
# [Fetch][818/9999][ok]
# [Fetch][809/9999][ok]
# [Fetch][821/9999][ok]
# [Fetch][827/9999][ok]
# [Fetch][830/9999][ok]
# [Fetch][828/9999][ok]
# [Fetch][822/9999][ok]
# [Fetch][817/9999][ok]
# [Fetch][829/9999][ok]
# [Fetch][815/9999][ok]
# [Fetch][823/9999][ok]
# [Fetch][831/9999][ok]
# [Fetch][832/9999][ok]
# [Fetch][808/9999][ok]
# [Fetch][836/9999][ok]
# [Fetch][838/9999][ok]
# [Fetch][840/9999][ok]
# [Fetch][835/9999][ok]
# [Fetch][842/9999][ok]
# [Fetch][841/9999][ok]
# [Fetch][837/9999][ok]
# [Fetch][839/9999][ok]
# [Fetch][833/9999][ok]
# [Fetch][844/9999][ok]
# [Fetch][805/9999][ok]
# [Fetch][843/9999][ok]
# [Fetch][845/9999][ok]
# [Fetch][851/9999][ok]
# [Fetch][846/9999][ok]
# [Fetch][847/9999][ok]
# [Fetch][856/9999][ok]
# [Fetch][849/9999][ok]
# [Fetch][857/9999][ok]
# [Fetch][852/9999][ok]
# [Fetch][850/9999][ok]
# [Fetch][859/9999][ok]
# [Fetch][834/9999][ok]
# [Fetch][853/9999][ok]
# [Fetch][861/9999][ok]
# [Fetch][865/9999][ok]
# [Fetch][866/9999][ok]
# [Fetch][862/9999][ok]
# [Fetch][854/9999][ok]
# [Fetch][868/9999][ok]
# [Fetch][863/9999][ok]
# [Fetch][855/9999][ok]
# [Fetch][867/9999][ok]
# [Fetch][872/9999][ok]
# [Fetch][869/9999][ok]
# [Fetch][864/9999][ok]
# [Fetch][879/9999][ok]
# [Fetch][870/9999][ok]
# [Fetch][873/9999][ok]
# [Fetch][871/9999][ok]
# [Fetch][860/9999][ok]
# [Fetch][874/9999][ok]
# [Fetch][876/9999][ok]
# [Fetch][878/9999][ok]
# [Fetch][858/9999][ok]
# [Fetch][875/9999][ok]
# [Fetch][877/9999][ok]
# [Fetch][881/9999][ok]
# [Fetch][880/9999][ok]
# [Fetch][889/9999][ok]
# [Fetch][887/9999][ok]
# [Fetch][882/9999][ok]
# [Fetch][888/9999][ok]
# [Fetch][893/9999][ok]
# [Fetch][886/9999][ok]
# [Fetch][885/9999][ok]
# [Fetch][891/9999][ok]
# [Fetch][890/9999][ok]
# [Fetch][892/9999][ok]
# [Fetch][884/9999][ok]
# [Fetch][883/9999][ok]
# [Fetch][898/9999][ok]
# [Fetch][895/9999][ok]
# [Fetch][899/9999][ok]
# [Fetch][901/9999][ok]
# [Fetch][900/9999][ok]
# [Fetch][897/9999][ok]
# [Fetch][894/9999][ok]
# [Fetch][904/9999][ok]
# [Fetch][908/9999][ok]
# [Fetch][903/9999][ok]
# [Fetch][914/9999][ok]
# [Fetch][907/9999][ok]
# [Fetch][906/9999][ok]
# [Fetch][913/9999][ok]
# [Fetch][909/9999][ok]
# [Fetch][910/9999][ok]
# [Fetch][896/9999][ok]
# [Fetch][848/9999][ok]
# [Fetch][912/9999][ok]
# [Fetch][915/9999][ok]
# [Fetch][916/9999][ok]
# [Fetch][902/9999][ok]
# [Fetch][920/9999][ok]
# [Fetch][924/9999][ok]
# [Fetch][922/9999][ok]
# [Fetch][911/9999][ok]
# [Fetch][923/9999][ok]
# [Fetch][918/9999][ok]
# [Fetch][926/9999][ok]
# [Fetch][919/9999][ok]
# [Fetch][927/9999][ok]
# [Fetch][921/9999][ok]
# [Fetch][925/9999][ok]
# [Fetch][928/9999][ok]
# [Fetch][917/9999][ok]
# [Fetch][930/9999][ok]
# [Fetch][905/9999][ok]
# [Fetch][929/9999][ok]
# [Fetch][935/9999][ok]
# [Fetch][934/9999][ok]
# [Fetch][937/9999][ok]
# [Fetch][933/9999][ok]
# [Fetch][931/9999][ok]
# [Fetch][932/9999][ok]
# [Fetch][940/9999][ok]
# [Fetch][941/9999][ok]
# [Fetch][938/9999][ok]
# [Fetch][936/9999][ok]
# [Fetch][942/9999][ok]
# [Fetch][944/9999][ok]
# [Fetch][943/9999][ok]
# [Fetch][951/9999][ok]
# [Fetch][948/9999][ok]
# [Fetch][949/9999][ok]
# [Fetch][950/9999][ok]
# [Fetch][945/9999][ok]
# [Fetch][953/9999][ok]
# [Fetch][946/9999][ok]
# [Fetch][952/9999][ok]
# [Fetch][939/9999][ok]
# [Fetch][955/9999][ok]
# [Fetch][947/9999][ok]
# [Fetch][956/9999][ok]
# [Fetch][957/9999][ok]
# [Fetch][959/9999][ok]
# [Fetch][958/9999][ok]
# [Fetch][962/9999][ok]
# [Fetch][960/9999][ok]
# [Fetch][963/9999][ok]
# [Fetch][965/9999][ok]
# [Fetch][969/9999][ok]
# [Fetch][968/9999][ok]
# [Fetch][966/9999][ok]
# [Fetch][964/9999][ok]
# [Fetch][967/9999][ok]
# [Fetch][970/9999][ok]
# [Fetch][974/9999][ok]
# [Fetch][977/9999][ok]
# [Fetch][979/9999][ok]
# [Fetch][976/9999][ok]
# [Fetch][985/9999][ok]
# [Fetch][972/9999][ok]
# [Fetch][954/9999][ok]
# [Fetch][982/9999][ok]
# [Fetch][981/9999][ok]
# [Fetch][984/9999][ok]
# [Fetch][975/9999][ok]
# [Fetch][986/9999][ok]
# [Fetch][971/9999][ok]
# [Fetch][978/9999][ok]
# [Fetch][980/9999][ok]
# [Fetch][983/9999][ok]
# [Fetch][988/9999][ok]
# [Fetch][997/9999][ok]
# [Fetch][990/9999][ok]
# [Fetch][993/9999][ok]
# [Fetch][987/9999][ok]
# [Fetch][961/9999][ok]
# [Fetch][995/9999][ok]
# [Fetch][989/9999][ok]
# [Fetch][991/9999][ok]
# [Fetch][994/9999][ok]
# [Fetch][996/9999][ok]
# [Fetch][998/9999][ok]
# [Fetch][999/9999][ok]
# [Fetch][973/9999][ok]
# [Fetch][1002/9999][ok]
# [Fetch][1000/9999][ok]
# [Fetch][1004/9999][ok]
# [Fetch][1006/9999][ok]
# [Fetch][1001/9999][ok]
# [Fetch][1003/9999][ok]
# [Fetch][1015/9999][ok]
# [Fetch][1012/9999][ok]
# [Fetch][1008/9999][ok]
# [Fetch][1005/9999][ok]
# [Fetch][1011/9999][ok]
# [Fetch][1014/9999][ok]
# [Fetch][1013/9999][ok]
# [Fetch][1007/9999][ok]
# [Fetch][1009/9999][ok]
# [Fetch][1010/9999][ok]
# [Fetch][1019/9999][ok]
# [Fetch][1024/9999][ok]
# [Fetch][1022/9999][ok]
# [Fetch][1017/9999][ok]
# [Fetch][1016/9999][ok]
# [Fetch][992/9999][ok]
# [Fetch][1027/9999][ok]
# [Fetch][1020/9999][ok]
# [Fetch][1031/9999][ok]
# [Fetch][1033/9999][ok]
# [Fetch][1026/9999][ok]
# [Fetch][1023/9999][ok]
# [Fetch][1018/9999][ok]
# [Fetch][1035/9999][ok]
# [Fetch][1025/9999][ok]
# [Fetch][1021/9999][ok]
# [Fetch][1032/9999][ok]
# [Fetch][1028/9999][ok]
# [Fetch][1030/9999][ok]
# [Fetch][1034/9999][ok]
# [Fetch][1037/9999][ok]
# [Fetch][1029/9999][ok]
# [Fetch][1036/9999][ok]
# [Fetch][1040/9999][ok]
# [Fetch][1038/9999][ok]
# [Fetch][1048/9999][ok]
# [Fetch][1041/9999][ok]
# [Fetch][1039/9999][ok]
# [Fetch][1042/9999][ok]
# [Fetch][1050/9999][ok]
# [Fetch][1044/9999][ok]
# [Fetch][1047/9999][ok]
# [Fetch][1046/9999][ok]
# [Fetch][1049/9999][ok]
# [Fetch][1052/9999][ok]
# [Fetch][1057/9999][ok]
# [Fetch][1043/9999][ok]
# [Fetch][1054/9999][ok]
# [Fetch][1051/9999][ok]
# [Fetch][1055/9999][ok]
# [Fetch][1053/9999][ok]
# [Fetch][1059/9999][ok]
# [Fetch][1056/9999][ok]
# [Fetch][1058/9999][ok]
# [Fetch][1063/9999][ok]
# [Fetch][1060/9999][ok]
# [Fetch][1067/9999][ok]
# [Fetch][1064/9999][ok]
# [Fetch][1061/9999][ok]
# [Fetch][1078/9999][ok]
# [Fetch][1062/9999][ok]
# [Fetch][1080/9999][ok]
# [Fetch][1069/9999][ok]
# [Fetch][1072/9999][ok]
# [Fetch][1070/9999][ok][Fetch][1071/9999][ok]
#
# [Fetch][1076/9999][ok]
# [Fetch][1074/9999][ok]
# [Fetch][1066/9999][ok]
# [Fetch][1073/9999][ok]
# [Fetch][1045/9999][ok]
# [Fetch][1068/9999][ok]
# [Fetch][1077/9999][ok]
# [Fetch][1085/9999][ok]
# [Fetch][1082/9999][ok]
# [Fetch][1083/9999][ok]
# [Fetch][1089/9999][ok]
# [Fetch][1081/9999][ok]
# [Fetch][1087/9999][ok]
# [Fetch][1084/9999][ok]
# [Fetch][1088/9999][ok]
# [Fetch][1086/9999][ok]
# [Fetch][1091/9999][ok]
# [Fetch][1094/9999][ok]
# [Fetch][1092/9999][ok]
# [Fetch][1090/9999][ok]
# [Fetch][1095/9999][ok]
# [Fetch][1093/9999][ok]
# [Fetch][1100/9999][ok]
# [Fetch][1096/9999][ok]
# [Fetch][1075/9999][ok]
# [Fetch][1065/9999][ok]
# [Fetch][1098/9999][ok]
# [Fetch][1105/9999][ok]
# [Fetch][1106/9999][ok]
# [Fetch][1101/9999][ok]
# [Fetch][1111/9999][ok]
# [Fetch][1079/9999][ok]
# [Fetch][1113/9999][ok]
# [Fetch][1112/9999][ok]
# [Fetch][1103/9999][ok]
# [Fetch][1102/9999][ok]
# [Fetch][1108/9999][ok]
# [Fetch][1110/9999][ok]
# [Fetch][1109/9999][ok]
# [Fetch][1117/9999][ok]
# [Fetch][1115/9999][ok]
# [Fetch][1114/9999][ok]
# [Fetch][1104/9999][ok]
# [Fetch][1116/9999][ok]
# [Fetch][1097/9999][ok]
# [Fetch][1123/9999][ok]
# [Fetch][1099/9999][ok]
# [Fetch][1119/9999][ok]
# [Fetch][1120/9999][ok]
# [Fetch][1118/9999][ok]
# [Fetch][1121/9999][ok]
# [Fetch][1126/9999][ok]
# [Fetch][1124/9999][ok]
# [Fetch][1107/9999][ok]
# [Fetch][1128/9999][ok]
# [Fetch][1122/9999][ok]
# [Fetch][1125/9999][ok]
# [Fetch][1134/9999][ok]
# [Fetch][1130/9999][ok]
# [Fetch][1131/9999][ok]
# [Fetch][1129/9999][ok]
# [Fetch][1132/9999][ok]
# [Fetch][1137/9999][ok]
# [Fetch][1127/9999][ok]
# [Fetch][1139/9999][ok]
# [Fetch][1133/9999][ok]
# [Fetch][1140/9999][ok]
# [Fetch][1138/9999][ok]
# [Fetch][1136/9999][ok]
# [Fetch][1135/9999][ok]
# [Fetch][1141/9999][ok]
# [Fetch][1143/9999][ok]
# [Fetch][1142/9999][ok]
# [Fetch][1144/9999][ok]
# [Fetch][1145/9999][ok]
# [Fetch][1146/9999][ok]
# [Fetch][1148/9999][ok]
# [Fetch][1152/9999][ok]
# [Fetch][1151/9999][ok]
# [Fetch][1158/9999][ok]
# [Fetch][1157/9999][ok]
# [Fetch][1159/9999][ok]
# [Fetch][1147/9999][ok]
# [Fetch][1149/9999][ok]
# [Fetch][1161/9999][ok]
# [Fetch][1168/9999][ok]
# [Fetch][1166/9999][ok]
# [Fetch][1162/9999][ok]
# [Fetch][1169/9999][ok]
# [Fetch][1156/9999][ok][Fetch][1173/9999][ok]
#
# [Fetch][1165/9999][ok]
# [Fetch][1164/9999][ok]
# [Fetch][1167/9999][ok]
# [Fetch][1160/9999][ok]
# [Fetch][1150/9999][ok]
# [Fetch][1170/9999][ok]
# [Fetch][1154/9999][ok]
# [Fetch][1174/9999][ok]
# [Fetch][1163/9999][ok]
# [Fetch][1153/9999][ok]
# [Fetch][1155/9999][ok]
# [Fetch][1178/9999][ok]
# [Fetch][1175/9999][ok]
# [Fetch][1179/9999][ok]
# [Fetch][1176/9999][ok]
# [Fetch][1177/9999][ok]
# [Fetch][1183/9999][ok]
# [Fetch][1185/9999][ok]
# [Fetch][1171/9999][ok]
# [Fetch][1186/9999][ok]
# [Fetch][1172/9999][ok]
# [Fetch][1180/9999][ok]
# [Fetch][1184/9999][ok]
# [Fetch][1181/9999][ok]
# [Fetch][1191/9999][ok]
# [Fetch][1193/9999][ok]
# [Fetch][1188/9999][ok]
# [Fetch][1189/9999][ok]
# [Fetch][1199/9999][ok]
# [Fetch][1195/9999][ok]
# [Fetch][1194/9999][ok]
# [Fetch][1187/9999][ok]
# [Fetch][1190/9999][ok]
# [Fetch][1192/9999][ok]
# [Fetch][1204/9999][ok]
# [Fetch][1207/9999][ok]
# [Fetch][1202/9999][ok]
# [Fetch][1205/9999][ok]
# [Fetch][1208/9999][ok]
# [Fetch][1200/9999][ok]
# [Fetch][1196/9999][ok]
# [Fetch][1197/9999][ok]
# [Fetch][1198/9999][ok]
# [Fetch][1203/9999][ok]
# [Fetch][1206/9999][ok]
# [Fetch][1211/9999][ok]
# [Fetch][1216/9999][ok]
# [Fetch][1212/9999][ok]
# [Fetch][1209/9999][ok]
# [Fetch][1215/9999][ok]
# [Fetch][1210/9999][ok]
# [Fetch][1213/9999][ok]
# [Fetch][1219/9999][ok]
# [Fetch][1182/9999][ok]
# [Fetch][1201/9999][ok]
# [Fetch][1214/9999][ok]
# [Fetch][1222/9999][ok]
# [Fetch][1221/9999][ok]
# [Fetch][1220/9999][ok]
# [Fetch][1217/9999][ok]
# [Fetch][1223/9999][ok]
# [Fetch][1227/9999][ok]
# [Fetch][1218/9999][ok]
# [Fetch][1229/9999][ok]
# [Fetch][1228/9999][ok]
# [Fetch][1225/9999][ok]
# [Fetch][1232/9999][ok]
# [Fetch][1226/9999][ok]
# [Fetch][1230/9999][ok]
# [Fetch][1224/9999][ok]
# [Fetch][1234/9999][ok]
# [Fetch][1235/9999][ok]
# [Fetch][1236/9999][ok]
# [Fetch][1240/9999][ok]
# [Fetch][1237/9999][ok]
# [Fetch][1238/9999][ok]
# [Fetch][1245/9999][ok]
# [Fetch][1242/9999][ok]
# [Fetch][1239/9999][ok]
# [Fetch][1233/9999][ok]
# [Fetch][1246/9999][ok]
# [Fetch][1252/9999][ok]
# [Fetch][1251/9999][ok]
# [Fetch][1247/9999][ok]
# [Fetch][1248/9999][ok]
# [Fetch][1244/9999][ok]
# [Fetch][1253/9999][ok]
# [Fetch][1255/9999][ok]
# [Fetch][1249/9999][ok]
# [Fetch][1231/9999][ok]
# [Fetch][1259/9999][ok]
# [Fetch][1243/9999][ok]
# [Fetch][1254/9999][ok]
# [Fetch][1260/9999][ok]
# [Fetch][1257/9999][ok]
# [Fetch][1256/9999][ok]
# [Fetch][1264/9999][ok]
# [Fetch][1262/9999][ok]
# [Fetch][1261/9999][ok]
# [Fetch][1258/9999][ok]
# [Fetch][1267/9999][ok]
# [Fetch][1268/9999][ok]
# [Fetch][1265/9999][ok]
# [Fetch][1272/9999][ok]
# [Fetch][1241/9999][ok]
# [Fetch][1269/9999][ok]
# [Fetch][1276/9999][ok]
# [Fetch][1274/9999][ok]
# [Fetch][1250/9999][ok]
# [Fetch][1270/9999][ok]
# [Fetch][1280/9999][ok]
# [Fetch][1273/9999][ok]
# [Fetch][1283/9999][ok]
# [Fetch][1263/9999][ok]
# [Fetch][1282/9999][ok]
# [Fetch][1277/9999][ok]
# [Fetch][1281/9999][ok]
# [Fetch][1279/9999][ok]
# [Fetch][1288/9999][ok]
# [Fetch][1287/9999][ok]
# [Fetch][1301/9999][retry 1]
# [Fetch][1289/9999][ok]
# [Fetch][1278/9999][ok]
# [Fetch][1285/9999][ok]
# [Fetch][1290/9999][ok]
# [Fetch][1266/9999][ok]
# [Fetch][1291/9999][ok]
# [Fetch][1295/9999][ok]
# [Fetch][1298/9999][ok]
# [Fetch][1286/9999][ok]
# [Fetch][1304/9999][ok]
# [Fetch][1293/9999][ok]
# [Fetch][1308/9999][ok]
# [Fetch][1306/9999][ok]
# [Fetch][1312/9999][ok]
# [Fetch][1302/9999][ok]
# [Fetch][1300/9999][ok]
# [Fetch][1299/9999][ok]
# [Fetch][1294/9999][ok]
# [Fetch][1284/9999][ok]
# [Fetch][1292/9999][ok]
# [Fetch][1297/9999][ok]
# [Fetch][1309/9999][ok]
# [Fetch][1307/9999][ok]
# [Fetch][1303/9999][ok]
# [Fetch][1315/9999][ok]
# [Fetch][1296/9999][ok]
# [Fetch][1318/9999][ok]
# [Fetch][1311/9999][ok]
# [Fetch][1316/9999][ok]
# [Fetch][1313/9999][ok]
# [Fetch][1321/9999][ok]
# [Fetch][1323/9999][ok]
# [Fetch][1317/9999][ok]
# [Fetch][1322/9999][ok]
# [Fetch][1325/9999][ok]
# [Fetch][1319/9999][ok]
# [Fetch][1324/9999][ok]
# [Fetch][1271/9999][ok]
# [Fetch][1326/9999][ok]
# [Fetch][1328/9999][ok]
# [Fetch][1334/9999][ok]
# [Fetch][1327/9999][ok]
# [Fetch][1333/9999][ok]
# [Fetch][1329/9999][ok]
# [Fetch][1275/9999][ok]
# [Fetch][1335/9999][ok]
# [Fetch][1331/9999][ok]
# [Fetch][1339/9999][ok]
# [Fetch][1336/9999][ok]
# [Fetch][1332/9999][ok]
# [Fetch][1342/9999][ok]
# [Fetch][1341/9999][ok]
# [Fetch][1343/9999][ok]
# [Fetch][1338/9999][ok]
# [Fetch][1337/9999][ok]
# [Fetch][1314/9999][ok]
# [Fetch][1310/9999][ok]
# [Fetch][1344/9999][ok]
# [Fetch][1345/9999][ok]
# [Fetch][1330/9999][ok]
# [Fetch][1347/9999][ok]
# [Fetch][1340/9999][ok]
# [Fetch][1352/9999][ok]
# [Fetch][1301/9999][ok]
# [Fetch][1350/9999][ok]
# [Fetch][1351/9999][ok]
# [Fetch][1353/9999][ok]
# [Fetch][1349/9999][ok]
# [Fetch][1305/9999][ok]
# [Fetch][1346/9999][ok]
# [Fetch][1355/9999][ok]
# [Fetch][1357/9999][ok]
# [Fetch][1359/9999][ok]
# [Fetch][1356/9999][ok]
# [Fetch][1363/9999][ok]
# [Fetch][1360/9999][ok]
# [Fetch][1354/9999][ok]
# [Fetch][1362/9999][ok]
# [Fetch][1358/9999][ok]
# [Fetch][1364/9999][ok]
# [Fetch][1348/9999][ok]
# [Fetch][1369/9999][ok]
# [Fetch][1366/9999][ok]
# [Fetch][1361/9999][ok]
# [Fetch][1370/9999][ok]
# [Fetch][1371/9999][ok]
# [Fetch][1365/9999][ok]
# [Fetch][1368/9999][ok]
# [Fetch][1373/9999][ok]
# [Fetch][1367/9999][ok]
# [Fetch][1372/9999][ok]
# [Fetch][1376/9999][ok]
# [Fetch][1377/9999][ok]
# [Fetch][1378/9999][ok]
# [Fetch][1374/9999][ok]
# [Fetch][1320/9999][ok]
# [Fetch][1383/9999][ok]
# [Fetch][1381/9999][ok]
# [Fetch][1375/9999][ok]
# [Fetch][1380/9999][ok]
# [Fetch][1384/9999][ok]
# [Fetch][1385/9999][ok]
# [Fetch][1382/9999][ok]
# [Fetch][1388/9999][ok]
# [Fetch][1387/9999][ok]
# [Fetch][1379/9999][ok]
# [Fetch][1390/9999][ok]
# [Fetch][1397/9999][ok]
# [Fetch][1401/9999][ok]
# [Fetch][1405/9999][ok]
# [Fetch][1410/9999][ok]
# [Fetch][1391/9999][ok]
# [Fetch][1406/9999][ok]
# [Fetch][1394/9999][ok]
# [Fetch][1409/9999][ok]
# [Fetch][1386/9999][ok]
# [Fetch][1402/9999][ok]
# [Fetch][1396/9999][ok]
# [Fetch][1393/9999][ok]
# [Fetch][1403/9999][ok]
# [Fetch][1400/9999][ok]
# [Fetch][1412/9999][ok]
# [Fetch][1398/9999][ok]
# [Fetch][1404/9999][ok]
# [Fetch][1408/9999][ok]
# [Fetch][1413/9999][ok]
# [Fetch][1411/9999][ok]
# [Fetch][1392/9999][ok]
# [Fetch][1416/9999][ok]
# [Fetch][1389/9999][ok]
# [Fetch][1407/9999][ok]
# [Fetch][1415/9999][ok]
# [Fetch][1417/9999][ok]
# [Fetch][1395/9999][ok]
# [Fetch][1414/9999][ok]
# [Fetch][1399/9999][ok]
# [Fetch][1421/9999][ok]
# [Fetch][1419/9999][ok]
# [Fetch][1420/9999][ok]
# [Fetch][1428/9999][ok]
# [Fetch][1424/9999][ok]
# [Fetch][1423/9999][ok]
# [Fetch][1422/9999][ok]
# [Fetch][1430/9999][ok]
# [Fetch][1427/9999][ok]
# [Fetch][1433/9999][ok]
# [Fetch][1441/9999][ok]
# [Fetch][1431/9999][ok]
# [Fetch][1436/9999][ok]
# [Fetch][1418/9999][ok]
# [Fetch][1446/9999][ok]
# [Fetch][1447/9999][ok]
# [Fetch][1432/9999][ok]
# [Fetch][1434/9999][ok]
# [Fetch][1451/9999][ok]
# [Fetch][1450/9999][ok]
# [Fetch][1452/9999][ok]
# [Fetch][1453/9999][ok]
# [Fetch][1448/9999][ok]
# [Fetch][1443/9999][ok]
# [Fetch][1438/9999][ok]
# [Fetch][1455/9999][ok]
# [Fetch][1444/9999][ok]
# [Fetch][1442/9999][ok]
# [Fetch][1426/9999][ok]
# [Fetch][1445/9999][ok]
# [Fetch][1435/9999][ok]
# [Fetch][1439/9999][ok]
# [Fetch][1449/9999][ok]
# [Fetch][1456/9999][ok]
# [Fetch][1460/9999][ok]
# [Fetch][1437/9999][ok]
# [Fetch][1440/9999][ok]
# [Fetch][1464/9999][ok]
# [Fetch][1463/9999][ok]
# [Fetch][1462/9999][ok]
# [Fetch][1429/9999][ok]
# [Fetch][1461/9999][ok]
# [Fetch][1468/9999][ok]
# [Fetch][1457/9999][ok]
# [Fetch][1458/9999][ok]
# [Fetch][1469/9999][ok]
# [Fetch][1466/9999][ok]
# [Fetch][1467/9999][ok]
# [Fetch][1471/9999][ok]
# [Fetch][1474/9999][ok]
# [Fetch][1465/9999][ok]
# [Fetch][1473/9999][ok]
# [Fetch][1475/9999][ok]
# [Fetch][1470/9999][ok]
# [Fetch][1472/9999][ok]
# [Fetch][1478/9999][ok]
# [Fetch][1477/9999][ok]
# [Fetch][1425/9999][ok]
# [Fetch][1459/9999][ok]
# [Fetch][1476/9999][ok]
# [Fetch][1479/9999][ok]
# [Fetch][1482/9999][ok]
# [Fetch][1480/9999][ok]
# [Fetch][1487/9999][ok]
# [Fetch][1485/9999][ok]
# [Fetch][1484/9999][ok]
# [Fetch][1486/9999][ok]
# [Fetch][1483/9999][ok]
# [Fetch][1495/9999][ok]
# [Fetch][1488/9999][ok]
# [Fetch][1489/9999][ok]
# [Fetch][1491/9999][ok]
# [Fetch][1493/9999][ok]
# [Fetch][1497/9999][ok]
# [Fetch][1492/9999][ok]
# [Fetch][1494/9999][ok][Fetch][1496/9999][ok]
#
# [Fetch][1499/9999][ok]
# [Fetch][1498/9999][ok]
# [Fetch][1454/9999][ok]
# [Fetch][1500/9999][ok]
# [Fetch][1481/9999][ok]
# [Fetch][1507/9999][ok]
# [Fetch][1506/9999][ok]
# [Fetch][1510/9999][ok]
# [Fetch][1502/9999][ok]
# [Fetch][1509/9999][ok]
# [Fetch][1515/9999][ok]
# [Fetch][1505/9999][ok]
# [Fetch][1511/9999][ok]
# [Fetch][1512/9999][ok]
# [Fetch][1517/9999][ok]
# [Fetch][1514/9999][ok]
# [Fetch][1518/9999][ok]
# [Fetch][1504/9999][ok]
# [Fetch][1519/9999][ok]
# [Fetch][1513/9999][ok]
# [Fetch][1516/9999][ok]
# [Fetch][1508/9999][ok]
# [Fetch][1523/9999][ok]
# [Fetch][1522/9999][ok]
# [Fetch][1490/9999][ok]
# [Fetch][1524/9999][ok]
# [Fetch][1521/9999][ok]
# [Fetch][1526/9999][ok]
# [Fetch][1528/9999][ok]
# [Fetch][1520/9999][ok]
# [Fetch][1530/9999][ok]
# [Fetch][1527/9999][ok]
# [Fetch][1531/9999][ok]
# [Fetch][1529/9999][ok]
# [Fetch][1534/9999][ok]
# [Fetch][1525/9999][ok]
# [Fetch][1533/9999][ok]
# [Fetch][1536/9999][ok]
# [Fetch][1532/9999][ok]
# [Fetch][1538/9999][ok]
# [Fetch][1539/9999][ok]
# [Fetch][1540/9999][ok]
# [Fetch][1541/9999][ok]
# [Fetch][1535/9999][ok]
# [Fetch][1546/9999][ok]
# [Fetch][1537/9999][ok]
# [Fetch][1544/9999][ok]
# [Fetch][1548/9999][ok]
# [Fetch][1547/9999][ok]
# [Fetch][1552/9999][ok]
# [Fetch][1551/9999][ok]
# [Fetch][1503/9999][ok]
# [Fetch][1549/9999][ok][Fetch][1542/9999][ok]
#
# [Fetch][1550/9999][ok]
# [Fetch][1554/9999][ok]
# [Fetch][1556/9999][ok]
# [Fetch][1561/9999][ok]
# [Fetch][1559/9999][ok]
# [Fetch][1558/9999][ok]
# [Fetch][1545/9999][ok]
# [Fetch][1564/9999][ok]
# [Fetch][1560/9999][ok]
# [Fetch][1565/9999][ok]
# [Fetch][1501/9999][ok]
# [Fetch][1557/9999][ok]
# [Fetch][1563/9999][ok]
# [Fetch][1555/9999][ok]
# [Fetch][1566/9999][ok]
# [Fetch][1553/9999][ok]
# [Fetch][1567/9999][ok]
# [Fetch][1543/9999][ok]
# [Fetch][1569/9999][ok]
# [Fetch][1571/9999][ok]
# [Fetch][1574/9999][ok]
# [Fetch][1573/9999][ok]
# [Fetch][1572/9999][ok]
# [Fetch][1568/9999][ok]
# [Fetch][1570/9999][ok]
# [Fetch][1577/9999][ok]
# [Fetch][1580/9999][ok]
# [Fetch][1582/9999][ok]
# [Fetch][1576/9999][ok]
# [Fetch][1575/9999][ok]
# [Fetch][1581/9999][ok]
# [Fetch][1578/9999][ok]
# [Fetch][1590/9999][ok]
# [Fetch][1583/9999][ok]
# [Fetch][1584/9999][ok]
# [Fetch][1589/9999][ok]
# [Fetch][1586/9999][ok]
# [Fetch][1587/9999][ok]
# [Fetch][1588/9999][ok]
# [Fetch][1594/9999][ok]
# [Fetch][1585/9999][ok]
# [Fetch][1591/9999][ok]
# [Fetch][1596/9999][ok]
# [Fetch][1593/9999][ok]
# [Fetch][1562/9999][ok]
# [Fetch][1592/9999][ok]
# [Fetch][1595/9999][ok]
# [Fetch][1598/9999][ok]
# [Fetch][1600/9999][ok]
# [Fetch][1579/9999][ok]
# [Fetch][1603/9999][ok]
# [Fetch][1602/9999][ok]
# [Fetch][1604/9999][ok]
# [Fetch][1599/9999][ok]
# [Fetch][1601/9999][ok]
# [Fetch][1597/9999][ok]
# [Fetch][1606/9999][ok]
# [Fetch][1605/9999][ok]
# [Fetch][1613/9999][ok]
# [Fetch][1609/9999][ok]
# [Fetch][1611/9999][ok]
# [Fetch][1608/9999][ok]
# [Fetch][1612/9999][ok]
# [Fetch][1607/9999][ok]
# [Fetch][1610/9999][ok]
# [Fetch][1617/9999][ok]
# [Fetch][1615/9999][ok]
# [Fetch][1626/9999][ok]
# [Fetch][1622/9999][ok]
# [Fetch][1619/9999][ok]
# [Fetch][1625/9999][ok][Fetch][1620/9999][ok]
#
# [Fetch][1616/9999][ok]
# [Fetch][1618/9999][ok]
# [Fetch][1621/9999][ok]
# [Fetch][1627/9999][ok]
# [Fetch][1623/9999][ok]
# [Fetch][1614/9999][ok]
# [Fetch][1629/9999][ok]
# [Fetch][1628/9999][ok]
# [Fetch][1632/9999][ok]
# [Fetch][1624/9999][ok]
# [Fetch][1634/9999][ok]
# [Fetch][1633/9999][ok]
# [Fetch][1635/9999][ok]
# [Fetch][1636/9999][ok]
# [Fetch][1630/9999][ok]
# [Fetch][1643/9999][ok]
# [Fetch][1638/9999][ok]
# [Fetch][1640/9999][ok]
# [Fetch][1642/9999][ok]
# [Fetch][1639/9999][ok]
# [Fetch][1644/9999][ok]
# [Fetch][1652/9999][ok]
# [Fetch][1645/9999][ok]
# [Fetch][1631/9999][ok]
# [Fetch][1641/9999][ok]
# [Fetch][1646/9999][ok]
# [Fetch][1653/9999][ok]
# [Fetch][1649/9999][ok]
# [Fetch][1654/9999][ok]
# [Fetch][1647/9999][ok]
# [Fetch][1650/9999][ok]
# [Fetch][1660/9999][ok]
# [Fetch][1656/9999][ok]
# [Fetch][1659/9999][ok]
# [Fetch][1637/9999][ok]
# [Fetch][1661/9999][ok]
# [Fetch][1666/9999][ok]
# [Fetch][1670/9999][ok]
# [Fetch][1657/9999][ok]
# [Fetch][1658/9999][ok]
# [Fetch][1672/9999][ok]
# [Fetch][1665/9999][ok]
# [Fetch][1669/9999][ok]
# [Fetch][1668/9999][ok]
# [Fetch][1675/9999][ok]
# [Fetch][1655/9999][ok]
# [Fetch][1667/9999][ok]
# [Fetch][1651/9999][ok]
# [Fetch][1684/9999][ok]
# [Fetch][1677/9999][ok]
# [Fetch][1663/9999][ok]
# [Fetch][1676/9999][ok]
# [Fetch][1674/9999][ok]
# [Fetch][1662/9999][ok]
# [Fetch][1648/9999][ok]
# [Fetch][1692/9999][ok]
# [Fetch][1678/9999][ok]
# [Fetch][1687/9999][ok]
# [Fetch][1682/9999][ok]
# [Fetch][1681/9999][ok]
# [Fetch][1689/9999][ok]
# [Fetch][1683/9999][ok]
# [Fetch][1679/9999][ok]
# [Fetch][1698/9999][ok]
# [Fetch][1673/9999][ok]
# [Fetch][1685/9999][ok]
# [Fetch][1695/9999][ok]
# [Fetch][1693/9999][ok]
# [Fetch][1691/9999][ok]
# [Fetch][1699/9999][ok]
# [Fetch][1664/9999][ok]
# [Fetch][1706/9999][ok]
# [Fetch][1680/9999][ok]
# [Fetch][1696/9999][ok]
# [Fetch][1701/9999][ok]
# [Fetch][1707/9999][ok]
# [Fetch][1671/9999][ok]
# [Fetch][1713/9999][ok]
# [Fetch][1702/9999][ok]
# [Fetch][1703/9999][ok]
# [Fetch][1710/9999][ok]
# [Fetch][1688/9999][ok]
# [Fetch][1717/9999][ok]
# [Fetch][1697/9999][ok]
# [Fetch][1709/9999][ok]
# [Fetch][1714/9999][ok]
# [Fetch][1704/9999][ok]
# [Fetch][1705/9999][ok]
# [Fetch][1712/9999][ok]
# [Fetch][1725/9999][ok]
# [Fetch][1711/9999][ok]
# [Fetch][1723/9999][ok]
# [Fetch][1722/9999][ok]
# [Fetch][1690/9999][ok]
# [Fetch][1716/9999][ok]
# [Fetch][1686/9999][ok]
# [Fetch][1726/9999][ok]
# [Fetch][1720/9999][ok]
# [Fetch][1727/9999][ok]
# [Fetch][1715/9999][ok]
# [Fetch][1694/9999][ok]
# [Fetch][1730/9999][ok]
# [Fetch][1745/9999][ok]
# [Fetch][1742/9999][ok]
# [Fetch][1728/9999][ok][Fetch][1700/9999][ok]
#
# [Fetch][1741/9999][ok]
# [Fetch][1708/9999][ok]
# [Fetch][1731/9999][ok]
# [Fetch][1733/9999][ok]
# [Fetch][1752/9999][ok]
# [Fetch][1729/9999][ok]
# [Fetch][1751/9999][ok]
# [Fetch][1744/9999][ok]
# [Fetch][1738/9999][ok]
# [Fetch][1757/9999][ok]
# [Fetch][1758/9999][ok]
# [Fetch][1719/9999][ok]
# [Fetch][1732/9999][ok]
# [Fetch][1743/9999][ok]
# [Fetch][1756/9999][ok]
# [Fetch][1760/9999][ok]
# [Fetch][1762/9999][ok]
# [Fetch][1755/9999][ok]
# [Fetch][1759/9999][ok]
# [Fetch][1739/9999][ok]
# [Fetch][1765/9999][ok]
# [Fetch][1766/9999][ok]
# [Fetch][1721/9999][ok]
# [Fetch][1767/9999][ok]
# [Fetch][1737/9999][ok]
# [Fetch][1761/9999][ok]
# [Fetch][1746/9999][ok]
# [Fetch][1768/9999][ok]
# [Fetch][1772/9999][ok]
# [Fetch][1771/9999][ok]
# [Fetch][1747/9999][ok]
# [Fetch][1763/9999][ok]
# [Fetch][1775/9999][ok]
# [Fetch][1740/9999][ok]
# [Fetch][1764/9999][ok]
# [Fetch][1770/9999][ok]
# [Fetch][1777/9999][ok]
# [Fetch][1774/9999][ok]
# [Fetch][1748/9999][ok]
# [Fetch][1734/9999][ok]
# [Fetch][1736/9999][ok]
# [Fetch][1724/9999][ok]
# [Fetch][1779/9999][ok]
# [Fetch][1781/9999][ok]
# [Fetch][1778/9999][ok]
# [Fetch][1780/9999][ok]
# [Fetch][1789/9999][ok]
# [Fetch][1776/9999][ok]
# [Fetch][1786/9999][ok]
# [Fetch][1749/9999][ok]
# [Fetch][1782/9999][ok]
# [Fetch][1795/9999][ok]
# [Fetch][1718/9999][ok]
# [Fetch][1785/9999][ok]
# [Fetch][1787/9999][ok]
# [Fetch][1790/9999][ok]
# [Fetch][1791/9999][ok]
# [Fetch][1796/9999][ok]
# [Fetch][1788/9999][ok]
# [Fetch][1735/9999][ok]
# [Fetch][1798/9999][ok]
# [Fetch][1799/9999][ok]
# [Fetch][1794/9999][ok]
# [Fetch][1792/9999][ok]
# [Fetch][1783/9999][ok]
# [Fetch][1801/9999][ok]
# [Fetch][1806/9999][ok]
# [Fetch][1753/9999][ok]
# [Fetch][1803/9999][ok]
# [Fetch][1769/9999][ok]
# [Fetch][1805/9999][ok]
# [Fetch][1802/9999][ok]
# [Fetch][1809/9999][ok]
# [Fetch][1807/9999][ok]
# [Fetch][1784/9999][ok]
# [Fetch][1811/9999][ok]
# [Fetch][1812/9999][ok]
# [Fetch][1800/9999][ok]
# [Fetch][1813/9999][ok]
# [Fetch][1815/9999][ok]
# [Fetch][1820/9999][ok]
# [Fetch][1823/9999][ok]
# [Fetch][1821/9999][ok]
# [Fetch][1824/9999][ok]
# [Fetch][1818/9999][ok]
# [Fetch][1754/9999][ok]
# [Fetch][1773/9999][ok]
# [Fetch][1822/9999][ok]
# [Fetch][1814/9999][ok]
# [Fetch][1825/9999][ok]
# [Fetch][1819/9999][ok]
# [Fetch][1826/9999][ok]
# [Fetch][1797/9999][ok]
# [Fetch][1817/9999][ok]
# [Fetch][1793/9999][ok]
# [Fetch][1832/9999][ok]
# [Fetch][1830/9999][ok]
# [Fetch][1750/9999][ok]
# [Fetch][1836/9999][ok]
# [Fetch][1833/9999][ok]
# [Fetch][1831/9999][ok]
# [Fetch][1839/9999][ok]
# [Fetch][1835/9999][ok]
# [Fetch][1837/9999][ok]
# [Fetch][1843/9999][ok]
# [Fetch][1829/9999][ok]
# [Fetch][1828/9999][ok]
# [Fetch][1840/9999][ok]
# [Fetch][1804/9999][ok]
# [Fetch][1808/9999][ok]
# [Fetch][1810/9999][ok]
# [Fetch][1842/9999][ok]
# [Fetch][1846/9999][ok]
# [Fetch][1849/9999][ok]
# [Fetch][1845/9999][ok]
# [Fetch][1838/9999][ok]
# [Fetch][1816/9999][ok]
# [Fetch][1853/9999][ok]
# [Fetch][1850/9999][ok]
# [Fetch][1827/9999][ok]
# [Fetch][1852/9999][ok]
# [Fetch][1856/9999][ok]
# [Fetch][1841/9999][ok]
# [Fetch][1854/9999][ok]
# [Fetch][1848/9999][ok]
# [Fetch][1851/9999][ok]
# [Fetch][1858/9999][ok]
# [Fetch][1834/9999][ok]
# [Fetch][1859/9999][ok]
# [Fetch][1844/9999][ok]
# [Fetch][1857/9999][ok]
# [Fetch][1862/9999][ok]
# [Fetch][1855/9999][ok]
# [Fetch][1860/9999][ok]
# [Fetch][1863/9999][ok]
# [Fetch][1867/9999][ok]
# [Fetch][1847/9999][ok]
# [Fetch][1864/9999][ok]
# [Fetch][1866/9999][ok]
# [Fetch][1871/9999][ok]
# [Fetch][1868/9999][ok]
# [Fetch][1869/9999][ok]
# [Fetch][1878/9999][ok]
# [Fetch][1879/9999][ok]
# [Fetch][1875/9999][ok]
# [Fetch][1880/9999][ok]
# [Fetch][1874/9999][ok]
# [Fetch][1870/9999][ok]
# [Fetch][1876/9999][ok][Fetch][1865/9999][ok]
#
# [Fetch][1873/9999][ok]
# [Fetch][1881/9999][ok]
# [Fetch][1882/9999][ok]
# [Fetch][1886/9999][ok]
# [Fetch][1883/9999][ok]
# [Fetch][1885/9999][ok]
# [Fetch][1889/9999][ok]
# [Fetch][1890/9999][ok]
# [Fetch][1892/9999][ok]
# [Fetch][1872/9999][ok]
# [Fetch][1894/9999][ok]
# [Fetch][1896/9999][ok]
# [Fetch][1893/9999][ok]
# [Fetch][1899/9999][ok]
# [Fetch][1877/9999][ok]
# [Fetch][1903/9999][ok]
# [Fetch][1900/9999][ok]
# [Fetch][1884/9999][ok]
# [Fetch][1895/9999][ok]
# [Fetch][1891/9999][ok]
# [Fetch][1887/9999][ok]
# [Fetch][1898/9999][ok]
# [Fetch][1904/9999][ok]
# [Fetch][1888/9999][ok]
# [Fetch][1861/9999][ok]
# [Fetch][1908/9999][ok]
# [Fetch][1901/9999][ok]
# [Fetch][1902/9999][ok]
# [Fetch][1910/9999][ok]
# [Fetch][1906/9999][ok]
# [Fetch][1911/9999][ok]
# [Fetch][1909/9999][ok]
# [Fetch][1912/9999][ok]
# [Fetch][1907/9999][ok]
# [Fetch][1897/9999][ok]
# [Fetch][1913/9999][ok]
# [Fetch][1916/9999][ok]
# [Fetch][1915/9999][ok]
# [Fetch][1914/9999][ok]
# [Fetch][1920/9999][ok]
# [Fetch][1918/9999][ok]
# [Fetch][1923/9999][ok]
# [Fetch][1905/9999][ok]
# [Fetch][1922/9999][ok]
# [Fetch][1919/9999][ok]
# [Fetch][1928/9999][ok]
# [Fetch][1917/9999][ok]
# [Fetch][1924/9999][ok]
# [Fetch][1925/9999][ok]
# [Fetch][1921/9999][ok]
# [Fetch][1934/9999][ok]
# [Fetch][1933/9999][ok]
# [Fetch][1931/9999][ok]
# [Fetch][1929/9999][ok]
# [Fetch][1938/9999][ok]
# [Fetch][1927/9999][ok]
# [Fetch][1926/9999][ok]
# [Fetch][1932/9999][ok]
# [Fetch][1937/9999][ok]
# [Fetch][1936/9999][ok]
# [Fetch][1943/9999][ok]
# [Fetch][1935/9999][ok]
# [Fetch][1939/9999][ok]
# [Fetch][1944/9999][ok]
# [Fetch][1942/9999][ok]
# [Fetch][1941/9999][ok]
# [Fetch][1946/9999][ok]
# [Fetch][1930/9999][ok]
# [Fetch][1945/9999][ok]
# [Fetch][1948/9999][ok]
# [Fetch][1940/9999][ok]
# [Fetch][1947/9999][ok]
# [Fetch][1954/9999][ok]
# [Fetch][1950/9999][ok]
# [Fetch][1952/9999][ok]
# [Fetch][1949/9999][ok]
# [Fetch][1959/9999][ok]
# [Fetch][1956/9999][ok]
# [Fetch][1960/9999][ok]
# [Fetch][1958/9999][ok]
# [Fetch][1957/9999][ok]
# [Fetch][1964/9999][ok]
# [Fetch][1961/9999][ok]
# [Fetch][1965/9999][ok]
# [Fetch][1973/9999][ok]
# [Fetch][1967/9999][ok]
# [Fetch][1970/9999][ok]
# [Fetch][1972/9999][ok]
# [Fetch][1968/9999][ok]
# [Fetch][1962/9999][ok]
# [Fetch][1974/9999][ok]
# [Fetch][1969/9999][ok]
# [Fetch][1975/9999][ok]
# [Fetch][1979/9999][ok]
# [Fetch][1966/9999][ok]
# [Fetch][1980/9999][ok]
# [Fetch][1978/9999][ok]
# [Fetch][1982/9999][ok]
# [Fetch][1953/9999][ok]
# [Fetch][1983/9999][ok]
# [Fetch][1981/9999][ok]
# [Fetch][1987/9999][ok]
# [Fetch][1955/9999][ok]
# [Fetch][1986/9999][ok]
# [Fetch][1951/9999][ok]
# [Fetch][1976/9999][ok]
# [Fetch][1993/9999][ok]
# [Fetch][1992/9999][ok]
# [Fetch][1995/9999][ok]
# [Fetch][1988/9999][ok]
# [Fetch][1997/9999][ok]
# [Fetch][1994/9999][ok]
# [Fetch][1996/9999][ok]
# [Fetch][1998/9999][ok]
# [Fetch][1971/9999][ok]
# [Fetch][1963/9999][ok]
# [Fetch][1999/9999][ok]
# [Fetch][2006/9999][ok]
# [Fetch][2002/9999][ok]
# [Fetch][2000/9999][ok]
# [Fetch][2007/9999][ok]
# [Fetch][2001/9999][ok]
# [Fetch][2003/9999][ok]
# [Fetch][2008/9999][ok]
# [Fetch][2004/9999][ok]
# [Fetch][2010/9999][ok]
# [Fetch][2009/9999][ok]
# [Fetch][1989/9999][ok]
# [Fetch][2013/9999][ok]
# [Fetch][2005/9999][ok]
# [Fetch][1990/9999][ok]
# [Fetch][1977/9999][ok]
# [Fetch][1985/9999][ok]
# [Fetch][1991/9999][ok]
# [Fetch][2015/9999][ok]
# [Fetch][2018/9999][ok]
# [Fetch][2019/9999][ok]
# [Fetch][2014/9999][ok]
# [Fetch][1984/9999][ok]
# [Fetch][2021/9999][ok]
# [Fetch][2024/9999][ok]
# [Fetch][2017/9999][ok]
# [Fetch][2011/9999][ok]
# [Fetch][2020/9999][ok]
# [Fetch][2027/9999][ok]
# [Fetch][2016/9999][ok]
# [Fetch][2029/9999][ok]
# [Fetch][2012/9999][ok]
# [Fetch][2022/9999][ok]
# [Fetch][2026/9999][ok]
# [Fetch][2030/9999][ok]
# [Fetch][2055/9999][retry 1]
# [Fetch][2031/9999][ok]
# [Fetch][2032/9999][ok]
# [Fetch][2033/9999][ok]
# [Fetch][2028/9999][ok]
# [Fetch][2037/9999][ok]
# [Fetch][2040/9999][ok]
# [Fetch][2036/9999][ok]
# [Fetch][2044/9999][ok][Fetch][2042/9999][ok]
#
# [Fetch][2034/9999][ok]
# [Fetch][2043/9999][ok]
# [Fetch][2046/9999][ok]
# [Fetch][2051/9999][ok]
# [Fetch][2035/9999][ok]
# [Fetch][2041/9999][ok]
# [Fetch][2025/9999][ok]
# [Fetch][2038/9999][ok]
# [Fetch][2045/9999][ok]
# [Fetch][2049/9999][ok]
# [Fetch][2052/9999][ok]
# [Fetch][2056/9999][ok]
# [Fetch][2057/9999][ok]
# [Fetch][2047/9999][ok]
# [Fetch][2053/9999][ok]
# [Fetch][2050/9999][ok]
# [Fetch][2059/9999][ok]
# [Fetch][2060/9999][ok]
# [Fetch][2054/9999][ok]
# [Fetch][2062/9999][ok]
# [Fetch][2064/9999][ok]
# [Fetch][2063/9999][ok]
# [Fetch][2070/9999][ok]
# [Fetch][2023/9999][ok]
# [Fetch][2073/9999][ok]
# [Fetch][2066/9999][ok]
# [Fetch][2068/9999][ok]
# [Fetch][2067/9999][ok]
# [Fetch][2061/9999][ok]
# [Fetch][2048/9999][ok]
# [Fetch][2065/9999][ok]
# [Fetch][2069/9999][ok][Fetch][2075/9999][ok]
#
# [Fetch][2071/9999][ok]
# [Fetch][2081/9999][ok]
# [Fetch][2039/9999][ok]
# [Fetch][2083/9999][ok]
# [Fetch][2079/9999][ok]
# [Fetch][2078/9999][ok]
# [Fetch][2080/9999][ok]
# [Fetch][2074/9999][ok]
# [Fetch][2072/9999][ok]
# [Fetch][2084/9999][ok]
# [Fetch][2089/9999][ok]
# [Fetch][2082/9999][ok]
# [Fetch][2055/9999][ok]
# [Fetch][2058/9999][ok]
# [Fetch][2096/9999][ok]
# [Fetch][2101/9999][ok]
# [Fetch][2086/9999][ok]
# [Fetch][2090/9999][ok]
# [Fetch][2085/9999][ok]
# [Fetch][2103/9999][ok]
# [Fetch][2088/9999][ok]
# [Fetch][2097/9999][ok]
# [Fetch][2102/9999][ok]
# [Fetch][2107/9999][ok]
# [Fetch][2092/9999][ok]
# [Fetch][2111/9999][ok]
# [Fetch][2106/9999][ok]
# [Fetch][2076/9999][ok]
# [Fetch][2108/9999][ok]
# [Fetch][2104/9999][ok]
# [Fetch][2112/9999][ok]
# [Fetch][2099/9999][ok]
# [Fetch][2100/9999][ok]
# [Fetch][2113/9999][ok]
# [Fetch][2116/9999][ok]
# [Fetch][2077/9999][ok]
# [Fetch][2120/9999][ok]
# [Fetch][2087/9999][ok]
# [Fetch][2110/9999][ok]
# [Fetch][2114/9999][ok]
# [Fetch][2094/9999][ok]
# [Fetch][2123/9999][ok]
# [Fetch][2124/9999][ok]
# [Fetch][2122/9999][ok]
# [Fetch][2117/9999][ok]
# [Fetch][2098/9999][ok]
# [Fetch][2127/9999][ok]
# [Fetch][2119/9999][ok]
# [Fetch][2128/9999][ok]
# [Fetch][2118/9999][ok]
# [Fetch][2133/9999][ok]
# [Fetch][2091/9999][ok]
# [Fetch][2129/9999][ok]
# [Fetch][2136/9999][ok]
# [Fetch][2137/9999][ok]
# [Fetch][2139/9999][ok]
# ...
# [Process][5016/9999] https://www.investing.com/news/economy-news/musk-stirs-uk-divisions-sparks-calls-for-faster-rollout-of-online-safety-laws-3559967
# [Process][5017/9999] https://www.investing.com/news/stock-market-news/us-supreme-court-bars-suit-against-facebook-under-antirobocall-law-2463910
# [Process][5018/9999] https://www.investing.com/news/stock-market-news/stock-market-today-dow-ends-higher-after-rebounding-amid-goldilocks-jobs-report-3192802
# [Process][5019/9999] https://www.investing.com/news/pro/reddit-receives-investment-bank-analyst-rating-update-3377581
# [Process][5020/9999] https://www.investing.com/news/stock-market-news/meta-platforms-should-reduce-headcount-expense-by-20--altimeter-capital-432SI-2919920
# [Process][5021/9999] https://www.investing.com/news/general/actor-armie-hammer-accused-of-rape-attorney-calls-claim-outrageous-2451285
# [Process][5022/9999] https://www.investing.com/news/stock-market-news/sp-500-slumps-as-powell-triggers-ugly-tech-selloff-2881128
# [Process][5023/9999] https://www.investing.com/news/stock-market-news/afterhours-movers-snap-sinks-following-weak-results-drags-meta-and-pinterest-lower-432SI-2917787
# [Process][5024/9999] https://www.investing.com/news/pro/meta-platforms-july-weekly-160-straddle-priced-into-quarter-432SI-2854866
# [Process][5025/9999] https://www.investing.com/news/stock-market-news/meta-platforms-delivers-upbeat-guidance-as-q1-results-top-estimates-shares-soar-3065484
# [Process][5026/9999] https://www.investing.com/news/stock-market-news/us-house-panel-subpoenas-tech-giants-over-foreign-communications-3896765
# [Process][5027/9999] https://www.investing.com/news/stock-market-news/tesla-apple-hostess-brands-boeing-rise-premarket-alibaba-falls-3171625
# [Process][5028/9999] https://www.investing.com/news/pro/tiktok-sues-us-government-over-law-forcing-sale-or-ban--nyt-432SI-3424941
# [Process][5029/9999] https://www.investing.com/news/stock-market-news/moderna-att-rise-premarket-united-airlines-tesla-exxon-mobil-fall-2717688
# [Process][5030/9999] https://www.investing.com/news/stock-market-news/metas-whatsapp-launches-new-ai-tools-for-businesses-3474311
# [Process][5031/9999] https://www.investing.com/news/commodities-news/morning-bid-tech-bounces-as-eyes-turn-to-mag7-fed-meet-and-canada-cut-3836417
# [Process][5032/9999] https://www.investing.com/news/stock-market-news/analysisdetroits-strikes-become-an-industrial-survivor-game-3188940
# [Process][5033/9999] https://www.investing.com/news/commodities-news/bus-crash-in-bolivia-leaves-at-least-15-dead-3902768
# [Process][5034/9999] https://www.investing.com/news/stock-market-news/earnings-wave-credit-suisse-outflows-bbby-bankruptcy--whats-moving-markets-3062449
# [Process][5035/9999] https://www.investing.com/news/cryptocurrency-news/zunanauts--a-new-nft-collection-set-to-reward-smart-investors-2877261
# [Process][5036/9999] https://www.investing.com/news/stock-market-news/smaller-stocks-are-poised-to-shine-dotcom-veteran-jacob-says-2662534
# [Process][5037/9999] https://www.investing.com/news/stock-market-news/sp-500-stumbles-shrugs-off-easing-government-shutdown-fears-2631470
# [Process][5038/9999] https://www.investing.com/news/stock-market-news/midday-movers-meta-boeing-fall-coinbase-equitrans-midstream-rise-3332280
# [Process][5039/9999] https://www.investing.com/news/stock-market-news/amazon-orders-employees-to-wear-masks-regardless-of-vaccination-status--bloomberg-news-2582994
# [Process][5040/9999] https://www.investing.com/news/stock-market-news/amazon-announces-new-slate-of-ai-models-3752123
# [Process][5041/9999] https://www.investing.com/news/stock-market-news/peter-thiel-to-step-down-from-meta-platforms-board-2758807
# [Process][5042/9999] https://www.investing.com/news/pro/meta-platforms-informed-staff-of-job-cuts-to-be-announced-monday--the-information-432SI-3857282
# [Process][5043/9999] https://www.investing.com/news/world-news/at-least-three-killed-in-russian-missile-strikes-on-ukraine-2966480
# [Process][5044/9999] https://www.investing.com/news/company-news/marjorie-taylor-greene-makes-multiple-stock-purchases-including-us-treasury-bill-93CH-3658110
# [Process][5045/9999] https://www.investing.com/news/world-news/new-normal-kremlin-says-tough-approach-to-navalny-allies-here-to-stay-2623151
# [Process][5046/9999] https://www.investing.com/news/world-news/wagner-boss-yevgeny-prigozhin-biden-says-report-of-his-death-not-surprising-3160151
# [Process][5047/9999] https://www.investing.com/news/stock-market-news/stock-market-today-dow-in-big-move-as-meta-leads-tech-rally-ahead-of-midterms-2935169
# [Process][5048/9999] https://www.investing.com/news/cryptocurrency-news/lbank-exchange-will-list-nevada-nvd-on-november-26-2021-2690763
# [Process][5049/9999] https://www.investing.com/news/stock-market-news/canadian-union-unifor-says-ford-offers-wage-increases-of-10-for-first-year-3181052
# [Process][5050/9999] https://www.investing.com/news/stock-market-news/broadening-us-market-rally-gets-boost-from-dovish-fed-3350473
# [Process][5051/9999] https://www.investing.com/news/stock-market-news/snap-ea-tumble-in-premarket-meta-tmobile-fall-amd-rises-2993260
# [Process][5052/9999] https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3839886
# [Process][5053/9999] https://www.investing.com/news/world-news/zelenskiy-calls-for-us-pragmatism-after-trump-calls-him-a-dictator-3879982
# [Process][5054/9999] https://www.investing.com/news/world-news/zelenskiy-mocks-russia-claims-over-soledar-says-fighting-goes-on-2978455
# [Process][5055/9999] https://www.investing.com/news/stock-market-news/amazon-surges-eyes-wall-street-record-gain-in-value-2757412
# [Process][5056/9999] https://www.investing.com/news/stock-market-news/riskreward-on-google-stock-favorable-says-wolfe-432SI-3603183
# [Process][5057/9999] https://www.investing.com/news/stock-market-news/wall-street-opens-mixed-hurt-by-bond-yield-rise-dow-up-190-pts-nasdaq-down-2627366
# [Process][5058/9999] https://www.investing.com/news/cryptocurrency-news/digital-dollar-advocate-will-retire-as-dallas-fed-president-2627952
# [Process][5059/9999] https://www.investing.com/news/cryptocurrency-news/innovation-funding-democratized-an-interview-with-the-ceo-of-dacxi-2629394
# [Process][5060/9999] https://www.investing.com/news/stock-market-news/facebook-enters-correction-stock-looks-cheap-2624940
# [Process][5061/9999] https://www.investing.com/news/stock-market-news/analysts-weigh-in-as-meta-unveils-ar-glasses-prototype-new-vr-headset-3633409
# [Process][5062/9999] https://www.investing.com/news/insider-trading-news/mark-zuckerberg-sells-145-million-in-meta-stock-93CH-3838528
# [Process][5063/9999] https://www.investing.com/news/economy/microsoft-meta-report-samsungs-chip-unit-disappoints--whats-moving-markets-3693488
# [Process][5064/9999] https://www.investing.com/news/stock-market-news/us-futures-mixed-federal-reserve-big-tech-stocks-in-focus-2570460
# [Process][5065/9999] https://www.investing.com/news/stock-market-news/lvmh-considers-widening-us-footprint-as-ceo-arnault-expresses-france-fatigue-3835661
# [Process][5066/9999] https://www.investing.com/news/stock-market-news/morgan-stanley-sees-longterm-upside-in-alphabets-ai-push-3690462
# [Process][5067/9999] https://www.investing.com/news/world-news/hardship-deepens-amidst-syrias-frozen-conflict-2762922
# [Process][5068/9999] https://www.investing.com/news/pro/goldman-sachs-says-these-are-the-4-best-internet-stocks-to-own-432SI-3338293
# [Process][5069/9999] https://www.investing.com/news/stock-market-news/amazon-comcast-more-earnings-3-things-to-watch-2571343
# [Process][5070/9999] https://www.investing.com/news/stock-market-news/meta-preparing-for-fresh-round-of-job-cuts--washington-post-3010785
# [Process][5071/9999] https://www.investing.com/news/stock-market-news/meta-platforms-hits-record-high-as-analysts-raise-target-432SI-3366088
# [Process][5072/9999] https://www.investing.com/news/world-news/hamas-unable-to-pay-salaries-in-gaza-after-qatari-aid-delay-officials-say-3126466
# [Process][5073/9999] https://www.investing.com/news/stock-market-news/german-envoy-urges-hungarians-to-safeguard-relations-with-eu-and-nato-3646624
# [Process][5074/9999] https://www.investing.com/news/stock-market-news/reddit-unveils-new-content-moderation-and-analytics-tools-to-boost-user-engagement-3912805
# [Process][5075/9999] https://www.investing.com/news/economy/asian-stocks-track-wall-st-tech-rally-us-yields-cling-to-highs-2759949
# [Process][5076/9999] https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3209924
# [Process][5077/9999] https://www.investing.com/news/stock-market-news/meta-platforms-earnings-beat-revenue-misses-in-q1-2812240
# [Process][5078/9999] https://www.investing.com/news/economy-news/morning-bid-decision-day-for-far-rights-rivals-3504743
# [Process][5079/9999] https://www.investing.com/news/stock-market-news/google-unveils-enterprise-ai-tools-new-ai-chip-3163380
# [Process][5080/9999] https://www.investing.com/news/economy-news/futures-mixed-as-inflation-data-presidential-debate-in-focus-3493380
# [Process][5081/9999] https://www.investing.com/news/stock-market-news/sp-500-slips-in-volatile-trade-as-surging-yields-bite-3188333
# [Process][5082/9999] https://www.investing.com/news/cryptocurrency-news/israeli-crypto-exchange-gets-license-from-capital-markets-authority-2897708
# [Process][5083/9999] https://www.investing.com/news/stock-market-news/big-banks-consumer-confidence-oil-stocks-3-things-to-watch-2544395
# [Process][5084/9999] https://www.investing.com/news/world-news/myanmar-protester-urge-guerrilla-strikes-as-internet-blackout-widens-2464483
# [Process][5085/9999] https://www.investing.com/news/stock-market-news/x-bytedance-bookingcom-could-face-tough-eu-rules-3322473
# [Process][5086/9999] https://www.investing.com/news/pro/meta-platforms-inc-pt-lowered-to-260-at-truist-securities-432SI-2856649
# [Process][5087/9999] https://www.investing.com/news/stock-market-news/chipmaker-amd-beats-estimates-for-thirdquarter-revenue-3689362
# [Process][5088/9999] https://www.investing.com/news/stock-market-news/magnificent-seven-to-add-more-than-1-trillion-in-value-after-trump-pauses-some-tariffs-3977591
# [Process][5089/9999] https://www.investing.com/news/stock-market-news/stock-market-today-dow-ends-year-nursing-biggest-annual-slump-since-2008-2971500
# [Process][5090/9999] https://www.investing.com/news/stock-market-news/us-q2-earnings-set-highest-bar-since-2021--goldman-3505493
# [Process][5091/9999] https://www.investing.com/news/stock-market-news/usdoj-tells-court-to-reject-tiktok-challenge-to-crackdown-law-3540238
# [Process][5092/9999] https://www.investing.com/news/pro/ftcs-khan-overruled-staff-to-sue-meta-platforms-over-vr-app-deal--bloomberg-432SI-2858205
# [Process][5093/9999] https://www.investing.com/news/world-news/myanmar-junta-opposition-set-to-extend-ceasefire-malaysia-pm-says-3992196
# [Process][5094/9999] https://www.investing.com/news/stock-market-news/meta-to-introduce-watermarking-feature-for-some-ai-products-3250932
# [Process][5095/9999] https://www.investing.com/news/world-news/trumps-blog-page-shuts-down-a-month-after-launch-2521460
# [Process][5096/9999] https://www.investing.com/news/stock-market-news/stock-market-today-dow-closes-lower-as-tech-wreck-continues-amid-meta-slump-3210792
# [Process][5097/9999] https://www.investing.com/news/cryptocurrency-news/top-ai-dataset-features-cryptocurrency-websites-in-its-datafeed-3062067
# [Process][5098/9999] https://www.investing.com/news/world-news/italys-right-to-try-to-elect-senate-speaker-as-president-snubbing-left-2751539
# [Process][5099/9999] https://www.investing.com/news/stock-market-news/a-stock-traders-guide-to-navigating-the-chip-industry-2844875
# [Process][5100/9999] https://www.investing.com/news/stock-market-news/instagram-will-allow-users-to-shop-directly-in-chats-2849044
# [Process][5101/9999] https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3209516
# [Process][5102/9999] https://www.investing.com/news/stock-market-news/investingcoms-stocks-of-the-week-3981827
# [Process][5103/9999] https://www.investing.com/news/pro/metas-voluntary-child-protection-seems-not-to-work-eus-breton-to-tell-company-eu-official-says--reuters-432SI-3100847
# [Process][5104/9999] https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3291030
# [Process][5105/9999] https://www.investing.com/news/stock-market-news/broadcom-rallies-on-forecast-for-booming-ai-chip-demand-3771047
# [Process][5106/9999] https://www.investing.com/news/pro/facebook-inc-receives-investment-bank-analyst-rating-update-3548370
# [Process][5107/9999] https://www.investing.com/news/stock-market-news/avoid-these-3-overvalued-metaverse-stocks-in-december-2698038
# [Process][5108/9999] https://www.investing.com/news/cryptocurrency-news/lazybear-secures-4-million-usdt-in-strategic-financing-to-revolutionize-crypto-trading-3403914
# [Process][5109/9999] https://www.investing.com/news/stock-market-news/stock-market-today-dow-shows-fight-but-weekly-losing-streak-continues-2824695
# [Process][5110/9999] https://www.investing.com/news/stock-market-news/instagram-reinstates-robert-f-kennedy-jr-amid-presidential-bid-launch--wapo-3097677
# [Process][5111/9999] https://www.investing.com/news/stock-market-news/dow-turns-positive-as-cyclicals-shine-to-offset-churn-in-tech-2522871
# [Process][5112/9999] https://www.investing.com/news/earnings/meta-platforms-earnings-beat-by-119-revenue-topped-estimates-4014472
# [Process][5113/9999] https://www.investing.com/news/stock-market-news/sp-500-advances-but-on-track-to-extend-losing-streak-as-wild-swings-continue-2969845
# [Process][5114/9999] https://www.investing.com/news/stock-market-news/nvidia-micron-uber-and-walt-disney-rise-premarket-tesla-falls-3800140
# [Process][5115/9999] https://www.investing.com/news/world-news/at-what-cost-ukraine-strains-to-bolster-its-army-as-war-fatigue-weighs-3244373
# [Process][5116/9999] https://www.investing.com/news/stock-market-news/sp-500-gives-up-gains-as-tech-healthcare-stumble-offsets-energy-rally-2520469
# [Process][5117/9999] https://www.investing.com/news/stock-market-news/market-leadership-is-becoming-increasingly-unhealthy--jpmorgan-432SI-3287371
# [Process][5118/9999] https://www.investing.com/news/stock-market-news/keybanc-flags-ad-spending-slowdown-cuts-target-on-major-digital-names-3977501
# [Process][5119/9999] https://www.investing.com/news/world-news/us-capitol-police-officer-charged-with-telling-rioter-to-destroy-evidence-2645437
# [Process][5120/9999] https://www.investing.com/news/cryptocurrency-news/ftx-under-active-civil-and-criminal-investigation-bahamas-ag-2952549
# [Process][5121/9999] https://www.investing.com/news/world-news/myanmar-forces-kill-25-in-raid-on-town-resident-and-media-say-2549493
# [Process][5122/9999] https://www.investing.com/news/stock-market-news/facebook-stock-still-attractive-after-whistleblower-testimony-2639136
# [Process][5123/9999] https://www.investing.com/news/analyst-ratings/jmp-maintains-meta-stock-750-target-on-ad-business-strength-93CH-3953849
# [Process][5124/9999] https://www.investing.com/news/stock-market-news/facebook-falls-as-public-outcry-forces-it-to-pause-instagram-kids-2627300
# [Process][5125/9999] https://www.investing.com/news/cryptocurrency-news/why-is-strategy-up-while-tech-is-down-michael-saylor-explains-4005567
# [Process][5126/9999] https://www.investing.com/news/stock-market-news/top-us-antitrust-lawmaker-targets-big-tech-with-new-bills--sources-2528126
# [Process][5127/9999] https://www.investing.com/news/stock-market-news/goldman-sachs-adjusts-ratings-on-digital-advertisers-ahead-of-earnings-3661971
# [Process][5128/9999] https://www.investing.com/news/stock-market-news/sp-500-off-lows-but-remains-under-pressure-as-ratehike-fears-dent-tech-3007413
# [Process][5129/9999] https://www.investing.com/news/stock-market-news/oracle-rallies-nvidia-microsoft-up-on-openai-partnership-3823506

# %%
df
# Out:
#      ticker publish_date publish_time  \
# 0     GOOGL   2023-06-26        05:38
# 1     GOOGL   2024-03-12        09:30
# 2     GOOGL   2021-09-20        10:12
# 3     GOOGL   2025-02-05        09:17
# 4     GOOGL   2023-06-29        13:07
# ...     ...          ...          ...
# 9988  GOOGL   2023-07-05        07:41
# 9989  GOOGL   2025-04-01        01:14
# 9990  GOOGL   2025-02-20        08:19
# 9991  GOOGL   2025-02-21        11:32
# 9992  GOOGL   2025-03-03        19:18
#
#                                                   title  \
# 0     UBS downgrades Alphabet stock, sees better ris...
# 1     Alphabet Inc Class A receives Investment Bank ...
# 2     President of Turkey declares war against crypt...
# 3     Flare Hosts AI Hackathon at UC Berkeley with G...
# 4     Google to block news in Canada over law on pay...
# ...                                                 ...
# 9988  Canada's Quebecor to pull its ads from Faceboo...
# 9989  Google’s DeepMind slows research publications ...
# 9990  Jefferies: 'Better days ahead' for Roku By Inv...
# 9991  5 big analyst AI moves: Bullish on Marvell, me...
# 9992  Stock market today: S&P 500 ends lower as rebo...
#
#                                               body_text  \
# 0     UBS analysts downgraded Alphabet (NASDAQ: ) sh...
# 1     Risk Disclosure: Trading in financial instrume...
# 2     In a Sept 18 meeting that took place in the ci...
# 3     Dubai, United Arab Emirates, February 5th, 202...
# 4     By Ismail Shakil\n\nOTTAWA (Reuters) -Google s...
# ...                                                 ...
# 9988  (Reuters) -Quebecor said on Wednesday it will ...
# 9989  Investing.com-- Google’s (NASDAQ: ) artificial...
# 9990  Investing.com -- In a note Thursday, Jefferies...
# 9991  Investing.com -- Here are the biggest analyst ...
# 9992  Investing.com-- The S&P 500 closed sharply los...
#
#                                                     url    neg    neu    pos  \
# 0     https://www.investing.com/news/stock-market-ne...  0.075  0.793  0.132
# 1     https://www.investing.com/news/pro/tiktok-ban-...  0.076  0.893  0.032
# 2     https://www.investing.com/news/cryptocurrency-...  0.106  0.835  0.059
# 3     https://www.investing.com/news/cryptocurrency-...  0.016  0.867  0.118
# 4     https://www.investing.com/news/stock-market-ne...  0.064  0.899  0.038
# ...                                                 ...    ...    ...    ...
# 9988  https://www.investing.com/news/stock-market-ne...  0.060  0.895  0.045
# 9989  https://www.investing.com/news/stock-market-ne...  0.053  0.768  0.179
# 9990  https://www.investing.com/news/stock-market-ne...  0.014  0.829  0.157
# 9991  https://www.investing.com/news/stock-market-ne...  0.026  0.836  0.138
# 9992  https://www.investing.com/news/stock-market-ne...  0.043  0.899  0.058
#
#       compound
# 0       0.8236
# 1      -0.8437
# 2      -0.9398
# 3       0.9961
# 4      -0.9273
# ...        ...
# 9988   -0.4939
# 9989    0.9716
# 9990    0.9886
# 9991    0.9993
# 9992    0.8832
#
# [9993 rows x 10 columns]

# %%
#sort by publish_date and publish_time
df = df.sort_values(by=['publish_date', 'publish_time'], ascending=[False,False]).reset_index(drop=True)

# %%
pd.set_option('display.max_columns', None)

# %%
# Count empty body_text entries
empty_body_count = df[df['body_text'] == ''].shape[0]
print(f"Number of articles with empty body_text: {empty_body_count}")
# Out:
# Number of articles with empty body_text: 0

# %%
df
# Out:
#      ticker publish_date publish_time  \
# 0     GOOGL   2025-05-04        00:20
# 1     GOOGL   2025-05-03        23:25
# 2     GOOGL   2025-05-03        04:30
# 3     GOOGL   2025-05-03        03:02
# 4     GOOGL   2025-05-02        11:27
# ...     ...          ...          ...
# 9988  GOOGL   2021-05-04        15:57
# 9989  GOOGL   2021-05-04        15:54
# 9990  GOOGL   2021-05-04        14:03
# 9991  GOOGL   2021-05-04        07:13
# 9992  GOOGL   2021-05-04        07:10
#
#                                                   title  \
# 0                             Error 404: Page Not Found
# 1                             Error 404: Page Not Found
# 2     Here’s how Goldman Sachs expects companies to ...
# 3     Strategy’s Saylor Reveals Asset That Leaves Bi...
# 4     Google faces September trial on ad tech antitr...
# ...                                                 ...
# 9988  S&P 500 Falls After Yellen Triggers Rate Hike ...
# 9989  Apple vs. Google: Which FAANG Stock is a Bette...
# 9990  S&P 500 Slips on Tech Wreck as Yellen Stokes I...
# 9991  Nasdaq ends sharply lower in tech sell-off By ...
# 9992  Explainer-Ahead of Trump Facebook ruling, here...
#
#                                               body_text  \
# 0     404\n\nPage Not Found\n\nSeems like the page y...
# 1     404\n\nPage Not Found\n\nSeems like the page y...
# 2     Investing.com - Investors have been focused du...
# 3     U.Today - Michael Saylor, a bull and co-founde...
# 4     By David Shepardson and Jody Godoy\n\nALEXANDR...
# ...                                                 ...
# 9988  By Yasin Ebrahim\n\nInvesting.com – The S&P 50...
# 9989  The COVID-19 pandemic has treated the FAANG st...
# 9990  By Yasin Ebrahim\n\nInvesting.com – The S&P 50...
# 9991  By Krystal Hu and Shreyashi Sanyal\n\n(Reuters...
# 9992  By Elizabeth Culliford\n\n(Reuters) - Facebook...
#
#                                                     url    neg    neu    pos  \
# 0     https://www.investing.com/news/cryptocurrency-...  0.140  0.860  0.000
# 1     https://www.investing.com/news/cryptocurrency-...  0.140  0.860  0.000
# 2     https://www.investing.com/news/stock-market-ne...  0.070  0.821  0.108
# 3     https://www.investing.com/news/cryptocurrency-...  0.000  0.911  0.089
# 4     https://www.investing.com/news/stock-market-ne...  0.062  0.878  0.060
# ...                                                 ...    ...    ...    ...
# 9988  https://www.investing.com/news/stock-market-ne...  0.054  0.845  0.101
# 9989  https://www.investing.com/news/stock-market-ne...  0.019  0.878  0.104
# 9990  https://www.investing.com/news/stock-market-ne...  0.047  0.865  0.088
# 9991  https://www.investing.com/news/stock-market-ne...  0.046  0.849  0.104
# 9992  https://www.investing.com/news/stock-market-ne...  0.092  0.847  0.062
#
#       compound
# 0      -0.2755
# 1      -0.2755
# 2       0.9672
# 3       0.9806
# 4      -0.3907
# ...        ...
# 9988    0.9750
# 9989    0.9813
# 9990    0.9480
# 9991    0.9820
# 9992   -0.9788
#
# [9993 rows x 10 columns]

# %%
article_sentiments = df.copy()

# %%
article_sentiments
# Out:
#      ticker publish_date publish_time  \
# 0     GOOGL   2025-05-04        00:20
# 1     GOOGL   2025-05-03        23:25
# 2     GOOGL   2025-05-03        04:30
# 3     GOOGL   2025-05-03        03:02
# 4     GOOGL   2025-05-02        11:27
# ...     ...          ...          ...
# 9988  GOOGL   2021-05-04        15:57
# 9989  GOOGL   2021-05-04        15:54
# 9990  GOOGL   2021-05-04        14:03
# 9991  GOOGL   2021-05-04        07:13
# 9992  GOOGL   2021-05-04        07:10
#
#                                                   title  \
# 0                             Error 404: Page Not Found
# 1                             Error 404: Page Not Found
# 2     Here’s how Goldman Sachs expects companies to ...
# 3     Strategy’s Saylor Reveals Asset That Leaves Bi...
# 4     Google faces September trial on ad tech antitr...
# ...                                                 ...
# 9988  S&P 500 Falls After Yellen Triggers Rate Hike ...
# 9989  Apple vs. Google: Which FAANG Stock is a Bette...
# 9990  S&P 500 Slips on Tech Wreck as Yellen Stokes I...
# 9991  Nasdaq ends sharply lower in tech sell-off By ...
# 9992  Explainer-Ahead of Trump Facebook ruling, here...
#
#                                               body_text  \
# 0     404\n\nPage Not Found\n\nSeems like the page y...
# 1     404\n\nPage Not Found\n\nSeems like the page y...
# 2     Investing.com - Investors have been focused du...
# 3     U.Today - Michael Saylor, a bull and co-founde...
# 4     By David Shepardson and Jody Godoy\n\nALEXANDR...
# ...                                                 ...
# 9988  By Yasin Ebrahim\n\nInvesting.com – The S&P 50...
# 9989  The COVID-19 pandemic has treated the FAANG st...
# 9990  By Yasin Ebrahim\n\nInvesting.com – The S&P 50...
# 9991  By Krystal Hu and Shreyashi Sanyal\n\n(Reuters...
# 9992  By Elizabeth Culliford\n\n(Reuters) - Facebook...
#
#                                                     url    neg    neu    pos  \
# 0     https://www.investing.com/news/cryptocurrency-...  0.140  0.860  0.000
# 1     https://www.investing.com/news/cryptocurrency-...  0.140  0.860  0.000
# 2     https://www.investing.com/news/stock-market-ne...  0.070  0.821  0.108
# 3     https://www.investing.com/news/cryptocurrency-...  0.000  0.911  0.089
# 4     https://www.investing.com/news/stock-market-ne...  0.062  0.878  0.060
# ...                                                 ...    ...    ...    ...
# 9988  https://www.investing.com/news/stock-market-ne...  0.054  0.845  0.101
# 9989  https://www.investing.com/news/stock-market-ne...  0.019  0.878  0.104
# 9990  https://www.investing.com/news/stock-market-ne...  0.047  0.865  0.088
# 9991  https://www.investing.com/news/stock-market-ne...  0.046  0.849  0.104
# 9992  https://www.investing.com/news/stock-market-ne...  0.092  0.847  0.062
#
#       compound
# 0      -0.2755
# 1      -0.2755
# 2       0.9672
# 3       0.9806
# 4      -0.3907
# ...        ...
# 9988    0.9750
# 9989    0.9813
# 9990    0.9480
# 9991    0.9820
# 9992   -0.9788
#
# [9993 rows x 10 columns]

# %%
# 1. แปลงคอลัมน์ publish_date เป็น datetime
article_sentiments['publish_date'] = pd.to_datetime(article_sentiments['publish_date'], errors='coerce')

# 2. แปลงคอลัมน์ publish_time เป็นเวลา (datetime.time)
article_sentiments['publish_time'] = pd.to_datetime(article_sentiments['publish_time'], format='%H:%M', errors='coerce').dt.time

article_sentiments['publish_datetime'] = pd.to_datetime(
    article_sentiments['publish_date'].astype(str) + ' ' + article_sentiments['publish_time'].astype(str),
    errors='coerce'
)

# %%
# สมมติว่า df คือ DataFrame ที่ได้จากการ scrape
# ตัวอย่างการโหลดไฟล์ pickle (ปรับ path ให้ตรงกับไฟล์ของคุณ)
# df = pd.read_pickle('/mnt/data/your_file.pkl')


def remove_html(text):
    if isinstance(text, str):
        return BeautifulSoup(text, "html.parser").get_text()
    return text

def remove_ads(text):
    if isinstance(text, str):
        # ลบข้อความที่มีรูปแบบโฆษณาที่พบได้บ่อย (สามารถปรับ regex ได้ตามความเหมาะสม)
        text = re.sub(r"here or remove ads.*?disclosureor", "", text, flags=re.IGNORECASE|re.DOTALL)
    return text

def clean_text(text):
    text = remove_html(text)      # ลบ HTML tags
    text = remove_ads(text)       # ลบข้อความโฆษณา
    text = text.strip()           # ตัดช่องว่างหัวและท้าย
    text = re.sub(r'[\r\n]+', ' ', text)
    text = re.sub(r'\s+', ' ', text)  # แทนที่ช่องว่างหลายตัวด้วยช่องว่างเดียว
    return text

for col in ['title', 'body_text']:
    article_sentiments[col] = article_sentiments[col].apply(clean_text)

article_sentiments = article_sentiments.drop_duplicates()

article_sentiments = article_sentiments.drop(columns=['publish_date', 'publish_time'])

# %%
article_sentiments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9993 entries, 0 to 9992
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ticker            9993 non-null   object
#  1   title             9993 non-null   object
#  2   body_text         9993 non-null   object
#  3   url               9993 non-null   object
#  4   neg               9993 non-null   float64
#  5   neu               9993 non-null   float64
#  6   pos               9993 non-null   float64
#  7   compound          9993 non-null   float64
#  8   publish_datetime  9993 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 702.8+ KB

# %%
article_sentiments
# Out:
#      ticker                                              title  \
# 0     GOOGL                          Error 404: Page Not Found
# 1     GOOGL                          Error 404: Page Not Found
# 2     GOOGL  Here’s how Goldman Sachs expects companies to ...
# 3     GOOGL  Strategy’s Saylor Reveals Asset That Leaves Bi...
# 4     GOOGL  Google faces September trial on ad tech antitr...
# ...     ...                                                ...
# 9988  GOOGL  S&P 500 Falls After Yellen Triggers Rate Hike ...
# 9989  GOOGL  Apple vs. Google: Which FAANG Stock is a Bette...
# 9990  GOOGL  S&P 500 Slips on Tech Wreck as Yellen Stokes I...
# 9991  GOOGL  Nasdaq ends sharply lower in tech sell-off By ...
# 9992  GOOGL  Explainer-Ahead of Trump Facebook ruling, here...
#
#                                               body_text  \
# 0     404 Page Not Found Seems like the page you wer...
# 1     404 Page Not Found Seems like the page you wer...
# 2     Investing.com - Investors have been focused du...
# 3     U.Today - Michael Saylor, a bull and co-founde...
# 4     By David Shepardson and Jody Godoy ALEXANDRIA,...
# ...                                                 ...
# 9988  By Yasin Ebrahim Investing.com – The S&P 500 f...
# 9989  The COVID-19 pandemic has treated the FAANG st...
# 9990  By Yasin Ebrahim Investing.com – The S&P 500 t...
# 9991  By Krystal Hu and Shreyashi Sanyal (Reuters) -...
# 9992  By Elizabeth Culliford (Reuters) - Facebook's ...
#
#                                                     url    neg    neu    pos  \
# 0     https://www.investing.com/news/cryptocurrency-...  0.140  0.860  0.000
# 1     https://www.investing.com/news/cryptocurrency-...  0.140  0.860  0.000
# 2     https://www.investing.com/news/stock-market-ne...  0.070  0.821  0.108
# 3     https://www.investing.com/news/cryptocurrency-...  0.000  0.911  0.089
# 4     https://www.investing.com/news/stock-market-ne...  0.062  0.878  0.060
# ...                                                 ...    ...    ...    ...
# 9988  https://www.investing.com/news/stock-market-ne...  0.054  0.845  0.101
# 9989  https://www.investing.com/news/stock-market-ne...  0.019  0.878  0.104
# 9990  https://www.investing.com/news/stock-market-ne...  0.047  0.865  0.088
# 9991  https://www.investing.com/news/stock-market-ne...  0.046  0.849  0.104
# 9992  https://www.investing.com/news/stock-market-ne...  0.092  0.847  0.062
#
#       compound    publish_datetime
# 0      -0.2755 2025-05-04 00:20:00
# 1      -0.2755 2025-05-03 23:25:00
# 2       0.9672 2025-05-03 04:30:00
# 3       0.9806 2025-05-03 03:02:00
# 4      -0.3907 2025-05-02 11:27:00
# ...        ...                 ...
# 9988    0.9750 2021-05-04 15:57:00
# 9989    0.9813 2021-05-04 15:54:00
# 9990    0.9480 2021-05-04 14:03:00
# 9991    0.9820 2021-05-04 07:13:00
# 9992   -0.9788 2021-05-04 07:10:00
#
# [9993 rows x 9 columns]

# %%
article_sentiments = article_sentiments.sort_values(
    by='publish_datetime', 
    ascending=False
).reset_index(drop=True)

# %%
article_sentiments
# Out:
#      ticker                                              title  \
# 0     GOOGL                          Error 404: Page Not Found
# 1     GOOGL                          Error 404: Page Not Found
# 2     GOOGL  Here’s how Goldman Sachs expects companies to ...
# 3     GOOGL  Strategy’s Saylor Reveals Asset That Leaves Bi...
# 4     GOOGL  Google faces September trial on ad tech antitr...
# ...     ...                                                ...
# 9988  GOOGL  S&P 500 Falls After Yellen Triggers Rate Hike ...
# 9989  GOOGL  Apple vs. Google: Which FAANG Stock is a Bette...
# 9990  GOOGL  S&P 500 Slips on Tech Wreck as Yellen Stokes I...
# 9991  GOOGL  Nasdaq ends sharply lower in tech sell-off By ...
# 9992  GOOGL  Explainer-Ahead of Trump Facebook ruling, here...
#
#                                               body_text  \
# 0     404 Page Not Found Seems like the page you wer...
# 1     404 Page Not Found Seems like the page you wer...
# 2     Investing.com - Investors have been focused du...
# 3     U.Today - Michael Saylor, a bull and co-founde...
# 4     By David Shepardson and Jody Godoy ALEXANDRIA,...
# ...                                                 ...
# 9988  By Yasin Ebrahim Investing.com – The S&P 500 f...
# 9989  The COVID-19 pandemic has treated the FAANG st...
# 9990  By Yasin Ebrahim Investing.com – The S&P 500 t...
# 9991  By Krystal Hu and Shreyashi Sanyal (Reuters) -...
# 9992  By Elizabeth Culliford (Reuters) - Facebook's ...
#
#                                                     url    neg    neu    pos  \
# 0     https://www.investing.com/news/cryptocurrency-...  0.140  0.860  0.000
# 1     https://www.investing.com/news/cryptocurrency-...  0.140  0.860  0.000
# 2     https://www.investing.com/news/stock-market-ne...  0.070  0.821  0.108
# 3     https://www.investing.com/news/cryptocurrency-...  0.000  0.911  0.089
# 4     https://www.investing.com/news/stock-market-ne...  0.062  0.878  0.060
# ...                                                 ...    ...    ...    ...
# 9988  https://www.investing.com/news/stock-market-ne...  0.054  0.845  0.101
# 9989  https://www.investing.com/news/stock-market-ne...  0.019  0.878  0.104
# 9990  https://www.investing.com/news/stock-market-ne...  0.047  0.865  0.088
# 9991  https://www.investing.com/news/stock-market-ne...  0.046  0.849  0.104
# 9992  https://www.investing.com/news/stock-market-ne...  0.092  0.847  0.062
#
#       compound    publish_datetime
# 0      -0.2755 2025-05-04 00:20:00
# 1      -0.2755 2025-05-03 23:25:00
# 2       0.9672 2025-05-03 04:30:00
# 3       0.9806 2025-05-03 03:02:00
# 4      -0.3907 2025-05-02 11:27:00
# ...        ...                 ...
# 9988    0.9750 2021-05-04 15:57:00
# 9989    0.9813 2021-05-04 15:54:00
# 9990    0.9480 2021-05-04 14:03:00
# 9991    0.9820 2021-05-04 07:13:00
# 9992   -0.9788 2021-05-04 07:10:00
#
# [9993 rows x 9 columns]

# %%
article_sentiments = article_sentiments[
    ~article_sentiments['title']
        .str.strip()
        .str.match(r'^(Cryptocurrency News|By Investing\.com|Error 404: Page Not Found)$')
].reset_index(drop=True)

# %%
article_sentiments
# Out:
#      ticker                                              title  \
# 0     GOOGL  Here’s how Goldman Sachs expects companies to ...
# 1     GOOGL  Strategy’s Saylor Reveals Asset That Leaves Bi...
# 2     GOOGL  Google faces September trial on ad tech antitr...
# 3     GOOGL  Bernstein upgrades Reddit, says it’s ’executin...
# 4     GOOGL  Analyst lowers Apple rating on lack of ‘AI-dri...
# ...     ...                                                ...
# 9986  GOOGL  S&P 500 Falls After Yellen Triggers Rate Hike ...
# 9987  GOOGL  Apple vs. Google: Which FAANG Stock is a Bette...
# 9988  GOOGL  S&P 500 Slips on Tech Wreck as Yellen Stokes I...
# 9989  GOOGL  Nasdaq ends sharply lower in tech sell-off By ...
# 9990  GOOGL  Explainer-Ahead of Trump Facebook ruling, here...
#
#                                               body_text  \
# 0     Investing.com - Investors have been focused du...
# 1     U.Today - Michael Saylor, a bull and co-founde...
# 2     By David Shepardson and Jody Godoy ALEXANDRIA,...
# 3     Investing.com -- Bernstein upgraded Reddit to ...
# 4     Investing.com -- Rosenblatt Securities downgra...
# ...                                                 ...
# 9986  By Yasin Ebrahim Investing.com – The S&P 500 f...
# 9987  The COVID-19 pandemic has treated the FAANG st...
# 9988  By Yasin Ebrahim Investing.com – The S&P 500 t...
# 9989  By Krystal Hu and Shreyashi Sanyal (Reuters) -...
# 9990  By Elizabeth Culliford (Reuters) - Facebook's ...
#
#                                                     url    neg    neu    pos  \
# 0     https://www.investing.com/news/stock-market-ne...  0.070  0.821  0.108
# 1     https://www.investing.com/news/cryptocurrency-...  0.000  0.911  0.089
# 2     https://www.investing.com/news/stock-market-ne...  0.062  0.878  0.060
# 3     https://www.investing.com/news/stock-market-ne...  0.037  0.835  0.128
# 4     https://www.investing.com/news/stock-market-ne...  0.066  0.841  0.093
# ...                                                 ...    ...    ...    ...
# 9986  https://www.investing.com/news/stock-market-ne...  0.054  0.845  0.101
# 9987  https://www.investing.com/news/stock-market-ne...  0.019  0.878  0.104
# 9988  https://www.investing.com/news/stock-market-ne...  0.047  0.865  0.088
# 9989  https://www.investing.com/news/stock-market-ne...  0.046  0.849  0.104
# 9990  https://www.investing.com/news/stock-market-ne...  0.092  0.847  0.062
#
#       compound    publish_datetime
# 0       0.9672 2025-05-03 04:30:00
# 1       0.9806 2025-05-03 03:02:00
# 2      -0.3907 2025-05-02 11:27:00
# 3       0.9772 2025-05-02 09:57:00
# 4       0.9185 2025-05-02 09:05:00
# ...        ...                 ...
# 9986    0.9750 2021-05-04 15:57:00
# 9987    0.9813 2021-05-04 15:54:00
# 9988    0.9480 2021-05-04 14:03:00
# 9989    0.9820 2021-05-04 07:13:00
# 9990   -0.9788 2021-05-04 07:10:00
#
# [9991 rows x 9 columns]

# %%
article_sentiments.to_pickle("META_article_sentiments.pkl")

article_sentiments.to_csv("META_article_sentiments.csv", index=False)
