# %%
import pandas as pd
from transformers import pipeline
from datetime import datetime

df = pd.read_pickle('/content/test_label.pkl')
df['date'] = pd.to_datetime(df['date'])

# %%
df
# Out:
#            date                                               text  label
# 0    2025-04-30  deepseek releases new math ai model risk discl...      0
# 1    2025-04-30  adv micro device receives investment bank anal...      0
# 2    2025-04-30  nvidia corp receives investment bank analyst r...      0
# 3    2025-04-30  taiwans ase evaluating how it will support nvi...      0
# 4    2025-04-30  super micro slumps on forecast cut analysts do...      0
# ...         ...                                                ...    ...
# 5118 2023-11-01  stock market today dow ends higher as treasury...      0
# 5119 2023-11-01  fed decision looms futures slip amd reports in...      0
# 5120 2023-11-01  megacap firm valuations fall amid rising rates...      0
# 5121 2023-11-01  us stocks rally as fed holds rates prompts hop...      0
# 5122 2023-11-01  apple unveils m3 chip series intensifying comp...      0
#
# [5123 rows x 3 columns]

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TextClassificationPipeline

# Load model 1
tokenizer1 = AutoTokenizer.from_pretrained("Photchara/stock_sentiment_Finbert_label")
model1_raw = AutoModelForSequenceClassification.from_pretrained("Photchara/stock_sentiment_Finbert_label")
model1 = TextClassificationPipeline(model=model1_raw, tokenizer=tokenizer1, truncation=True)

# Load model 2
tokenizer2 = AutoTokenizer.from_pretrained("Photchara/stock_sentiment_pct_change_v1")
model2_raw = AutoModelForSequenceClassification.from_pretrained("Photchara/stock_sentiment_pct_change_v1")
model2 = TextClassificationPipeline(model=model2_raw, tokenizer=tokenizer2, truncation=True)

# Load model 3
tokenizer3 = AutoTokenizer.from_pretrained("ProsusAI/finbert")
model3_raw = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")
model3 = TextClassificationPipeline(model=model3_raw, tokenizer=tokenizer3, truncation=True)
# Out:
# Device set to use cuda:0
# Device set to use cuda:0
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Device set to use cuda:0

# %%
def predict_sentiment(text):
    try:
        result1 = model1(text)[0]
        label1 = result1['label'].lower()

        result2 = model2(text)[0]
        label2 = result2['label'].lower()

        result3 = model3(text)[0]
        label3 = result3['label'].lower()
        return label1, label2, label3
    except:
        return None, None, None

# %%
df[['label1', 'label2', 'label3']] = df['text'].apply(
    lambda x: pd.Series(predict_sentiment(x))
)

# %%
label_mapping = {
    'negative': -1,
    'positive': 1,
    'neutral': 0
}

# %%
df['label1_num'] = df['label1'].map(label_mapping)
df['label2_num'] = df['label2'].map(label_mapping)
df['label3_num'] = df['label3'].map(label_mapping)

# %%
df
# Out:
#            date                                               text  label  \
# 0    2025-04-30  deepseek releases new math ai model risk discl...      0
# 1    2025-04-30  adv micro device receives investment bank anal...      0
# 2    2025-04-30  nvidia corp receives investment bank analyst r...      0
# 3    2025-04-30  taiwans ase evaluating how it will support nvi...      0
# 4    2025-04-30  super micro slumps on forecast cut analysts do...      0
# ...         ...                                                ...    ...
# 5118 2023-11-01  stock market today dow ends higher as treasury...      0
# 5119 2023-11-01  fed decision looms futures slip amd reports in...      0
# 5120 2023-11-01  megacap firm valuations fall amid rising rates...      0
# 5121 2023-11-01  us stocks rally as fed holds rates prompts hop...      0
# 5122 2023-11-01  apple unveils m3 chip series intensifying comp...      0
#
#         label1    label2  label1_num  label2_num    label3  label3_num
# 0      neutral  positive           0           1   neutral           0
# 1      neutral  positive           0           1   neutral           0
# 2      neutral  negative           0          -1   neutral           0
# 3      neutral  positive           0           1   neutral           0
# 4     negative  negative          -1          -1  negative          -1
# ...        ...       ...         ...         ...       ...         ...
# 5118  positive  positive           1           1  positive           1
# 5119  negative  negative          -1          -1  negative          -1
# 5120  negative  positive          -1           1  negative          -1
# 5121  negative  positive          -1           1  negative          -1
# 5122   neutral   neutral           0           0   neutral           0
#
# [5123 rows x 9 columns]

# %%
df[df['date'] == '2024-11-11']
# Out:
#            date                                               text  label  \
# 2008 2024-11-11  monolithic power systems receives investment b...      0
# 2009 2024-11-11  marvell receives investment bank analyst ratin...      0
# 2010 2024-11-11  nvidia price target raised to 165 by mizuho by...      0
# 2011 2024-11-11  monolithic power systems receives investment b...      0
# 2012 2024-11-11  nvidia pt receives investment bank analyst rat...      0
# 2013 2024-11-11  ubs raises nvidia target to 185 maintains buy ...      0
# 2014 2024-11-11  morgan stanley bumps nvidia shares target on m...      0
# 2015 2024-11-11  nvidia pt receives investment bank analyst rat...      0
# 2016 2024-11-11  nvidia falls to low down 27 by investingcom ri...      0
# 2017 2024-11-11  morgan stanley lifts nvidia price target estim...      0
# 2018 2024-11-11  nvidia corporation receives investment bank an...      0
# 2019 2024-11-11  nvidia corporation receives investment bank an...      0
# 2020 2024-11-11  melius lifts nvidia shares pt pointing to stro...      0
# 2021 2024-11-11  nvidia stock target upgraded rating held on ai...      0
# 2022 2024-11-11  tesla shares surge extending postelection rall...      0
# 2023 2024-11-11  piper sandler is calling nvidia their top pick...      0
# 2024 2024-11-11  sp 500 posts record high close trumplinked sto...      0
# 2025 2024-11-11  nvidia pt receives investment bank analyst rat...      0
# 2026 2024-11-11  nvidia pt receives investment bank analyst rat...      0
# 2027 2024-11-11  openai and rivals seek new path to smarter ai ...      0
# 2028 2024-11-11  earnings growth to continue goldman says but u...      0
# 2029 2024-11-11  nvidia pt receives investment bank analyst rat...      0
# 2030 2024-11-11  china chip index nears 3year high as tsmc orde...      0
# 2031 2024-11-11  softbank expected to book 187 billion profit o...      0
#
#         label1    label2  label1_num  label2_num    label3  label3_num
# 2008   neutral  positive           0           1   neutral           0
# 2009   neutral  negative           0          -1   neutral           0
# 2010  positive   neutral           1           0  positive           1
# 2011   neutral  positive           0           1   neutral           0
# 2012   neutral  negative           0          -1   neutral           0
# 2013  positive  positive           1           1  positive           1
# 2014  positive  negative           1          -1  positive           1
# 2015   neutral  negative           0          -1   neutral           0
# 2016   neutral  negative           0          -1   neutral           0
# 2017  positive  positive           1           1  positive           1
# 2018   neutral  negative           0          -1   neutral           0
# 2019   neutral  negative           0          -1   neutral           0
# 2020  positive  positive           1           1  positive           1
# 2021  positive  negative           1          -1  positive           1
# 2022  positive  positive           1           1  positive           1
# 2023  positive  positive           1           1  positive           1
# 2024  positive  positive           1           1  positive           1
# 2025   neutral  negative           0          -1   neutral           0
# 2026   neutral  negative           0          -1   neutral           0
# 2027   neutral  positive           0           1   neutral           0
# 2028  positive  negative           1          -1  positive           1
# 2029   neutral  negative           0          -1   neutral           0
# 2030  positive  positive           1           1  positive           1
# 2031  positive  positive           1           1  positive           1

# %%
avg_df = df.groupby('date', as_index=False)[['label1_num', 'label2_num','label3_num']].mean()
# avg_df = df.groupby('date', as_index=False)[['label1_num', 'label2_num','label3_num']].agg(lambda x: x.mode()[0])

# %%
avg_df
# Out:
#           date  label1_num  label2_num  label3_num
# 0   2023-11-01   -0.555556    0.222222   -0.555556
# 1   2023-11-02    0.400000    0.200000    0.400000
# 2   2023-11-03   -0.500000    0.500000   -0.500000
# 3   2023-11-06   -0.166667    0.000000   -0.166667
# 4   2023-11-07    0.375000    0.500000    0.250000
# ..         ...         ...         ...         ...
# 367 2025-04-24   -0.066667    0.333333    0.000000
# 368 2025-04-25   -0.333333    0.666667   -0.333333
# 369 2025-04-28   -0.461538    0.538462   -0.461538
# 370 2025-04-29   -0.157895    0.157895   -0.105263
# 371 2025-04-30   -0.111111    0.111111   -0.111111
#
# [372 rows x 4 columns]

# %%
def score_to_sentiment(score):
    if score > 0.1:
        return 'positive'
    elif score < -0.1:
        return 'negative'
    else:
        return 'neutral'

# %%
avg_df['sentiment1'] = avg_df['label1_num'].apply(score_to_sentiment)
avg_df['sentiment2'] = avg_df['label2_num'].apply(score_to_sentiment)
avg_df['sentiment3'] = avg_df['label3_num'].apply(score_to_sentiment)

# %%
# sentiment_map = {1:'positive', 0:'neutral', -1:'negative'}
# avg_df['label1_num'] = avg_df['label1_num'].map(sentiment_map)
# avg_df['label2_num'] = avg_df['label2_num'].map(sentiment_map)

# %%
avg_df
# Out:
#           date  label1_num  label2_num  label3_num sentiment1 sentiment2  \
# 0   2023-11-01   -0.555556    0.222222   -0.555556   negative   positive
# 1   2023-11-02    0.400000    0.200000    0.400000   positive   positive
# 2   2023-11-03   -0.500000    0.500000   -0.500000   negative   positive
# 3   2023-11-06   -0.166667    0.000000   -0.166667   negative    neutral
# 4   2023-11-07    0.375000    0.500000    0.250000   positive   positive
# ..         ...         ...         ...         ...        ...        ...
# 367 2025-04-24   -0.066667    0.333333    0.000000    neutral   positive
# 368 2025-04-25   -0.333333    0.666667   -0.333333   negative   positive
# 369 2025-04-28   -0.461538    0.538462   -0.461538   negative   positive
# 370 2025-04-29   -0.157895    0.157895   -0.105263   negative   positive
# 371 2025-04-30   -0.111111    0.111111   -0.111111   negative   positive
#
#     sentiment3
# 0     negative
# 1     positive
# 2     negative
# 3     negative
# 4     positive
# ..         ...
# 367    neutral
# 368   negative
# 369   negative
# 370   negative
# 371   negative
#
# [372 rows x 7 columns]

# %%
# นับแต่ละ combination ของ sentiment1 และ sentiment2
sentiment_combo_counts = avg_df.groupby(['sentiment1', 'sentiment2','sentiment3']).size().reset_index(name='count')

# หรือใช้ value_counts แบบ tuple
# sentiment_combo_counts = df[['sentiment1', 'sentiment2']].value_counts().reset_index(name='count')

print(sentiment_combo_counts)
# Out:
#    sentiment1 sentiment2 sentiment3  count
# 0    negative   negative   negative     41
# 1    negative   negative    neutral      1
# 2    negative    neutral   negative     30
# 3    negative    neutral    neutral      4
# 4    negative   positive   negative     61
# 5    negative   positive    neutral      8
# 6    negative   positive   positive      2
# 7     neutral   negative    neutral      5
# 8     neutral   negative   positive      2
# 9     neutral    neutral   negative      1
# 10    neutral    neutral    neutral     11
# 11    neutral    neutral   positive      3
# 12    neutral   positive   negative      4
# 13    neutral   positive    neutral     49
# 14    neutral   positive   positive      5
# 15   positive   negative   negative      1
# 16   positive   negative    neutral      1
# 17   positive   negative   positive     11
# 18   positive    neutral    neutral      1
# 19   positive    neutral   positive     21
# 20   positive   positive    neutral      8
# 21   positive   positive   positive    102

# %%
avg_df[['date', 'sentiment1', 'sentiment2' ,'sentiment3']].to_csv('date_sentiments.csv', index=False)

# %%
test_ans = df.groupby('date', as_index=False)['label'].mean()

# %%
test_ans['label'] = test_ans['label'].map({0:'positive',1:'negative',2:'neutral'})

# %%
test_ans
# Out:
#           date     label
# 0   2023-11-01  positive
# 1   2023-11-02  positive
# 2   2023-11-03  positive
# 3   2023-11-06   neutral
# 4   2023-11-07  positive
# ..         ...       ...
# 367 2025-04-24  positive
# 368 2025-04-25  negative
# 369 2025-04-28   neutral
# 370 2025-04-29   neutral
# 371 2025-04-30  positive
#
# [372 rows x 2 columns]

# %%
df_merged = pd.merge(avg_df, test_ans, on='date')
from sklearn.metrics import accuracy_score

# วัด accuracy ของแต่ละโมเดล
acc1 = accuracy_score(df_merged['label'], df_merged['sentiment1'])
acc2 = accuracy_score(df_merged['label'], df_merged['sentiment2'])
acc3 = accuracy_score(df_merged['label'], df_merged['sentiment3'])
print(f"Accuracy ของ model 1: {acc1:.6f}")
print(f"Accuracy ของ model 2: {acc2:.6f}")
print(f"Accuracy ของ model 3: {acc3:.6f}")
# Out:
# Accuracy ของ model 1: 0.362903
# Accuracy ของ model 2: 0.419355
# Accuracy ของ model 3: 0.362903

# %%
df_merged[df_merged['sentiment1'] != df_merged['sentiment3']]
# Out:
#           date  label1_num  label2_num  label3_num sentiment1 sentiment2  \
# 5   2023-11-08    0.000000    0.000000   -0.500000    neutral    neutral
# 7   2023-11-10    0.166667    0.333333    0.000000   positive   positive
# 13  2023-11-20   -0.105263    0.263158    0.000000   negative   positive
# 60  2024-02-01    0.125000    0.500000    0.000000   positive   positive
# 66  2024-02-09    0.111111    0.111111    0.000000   positive   positive
# 76  2024-02-26    0.120000    0.360000    0.080000   positive   positive
# 77  2024-02-27    0.250000   -0.500000    0.000000   positive   negative
# 86  2024-03-11   -0.300000    0.500000   -0.100000   negative   positive
# 96  2024-03-25    0.200000    0.600000    0.100000   positive   positive
# 109 2024-04-12   -0.166667    0.333333    0.000000   negative   positive
# 132 2024-05-15    0.000000   -0.500000    0.250000    neutral   negative
# 137 2024-05-22   -0.103448    0.103448   -0.068966   negative   positive
# 138 2024-05-23    0.088235   -0.323529    0.117647    neutral   negative
# 139 2024-05-24   -0.055556    0.444444   -0.277778    neutral   positive
# 154 2024-06-17    0.000000    0.230769    0.153846    neutral   positive
# 157 2024-06-21   -0.208333    0.458333   -0.083333   negative   positive
# 172 2024-07-15    0.142857    0.071429    0.071429   positive    neutral
# 175 2024-07-18    0.000000    0.272727   -0.181818    neutral   positive
# 176 2024-07-19    0.200000    0.200000    0.000000   positive   positive
# 192 2024-08-12   -0.285714    0.428571    0.000000   negative   positive
# 193 2024-08-13   -0.833333    0.333333    0.166667   negative   positive
# 202 2024-08-26   -0.181818    0.000000   -0.045455   negative    neutral
# 220 2024-09-20    0.125000    0.750000    0.000000   positive   positive
# 222 2024-09-24    0.200000   -0.200000   -0.200000   positive   negative
# 223 2024-09-25    0.083333    0.166667    0.166667    neutral   positive
# 229 2024-10-03   -0.166667    0.000000    0.000000   negative    neutral
# 231 2024-10-07    0.000000   -0.076923    0.153846    neutral    neutral
# 232 2024-10-08    0.222222    0.333333    0.000000   positive   positive
# 234 2024-10-10    0.000000    0.500000   -0.125000    neutral   positive
# 245 2024-10-25   -0.250000    0.500000    0.250000   negative   positive
# 263 2024-11-20   -0.157895   -0.421053   -0.078947   negative   negative
# 265 2024-11-22   -0.111111    0.222222    0.000000   negative   positive
# 267 2024-11-26    0.000000    0.666667    0.166667    neutral   positive
# 270 2024-12-02   -0.153846   -0.076923    0.000000   negative    neutral
# 271 2024-12-03   -0.062500    0.000000    0.125000    neutral    neutral
# 282 2024-12-18   -0.071429    0.142857    0.142857    neutral   positive
# 283 2024-12-19   -0.250000    0.000000    0.000000   negative    neutral
# 292 2025-01-03    0.000000    0.454545   -0.181818    neutral   positive
# 296 2025-01-10    0.055556    0.333333    0.111111    neutral   positive
# 312 2025-02-04    0.083333   -0.041667    0.125000    neutral    neutral
# 313 2025-02-05   -0.105263    0.263158    0.000000   negative   positive
#
#     sentiment3     label
# 5     negative  positive
# 7      neutral  positive
# 13     neutral  negative
# 60     neutral  positive
# 66     neutral   neutral
# 76     neutral   neutral
# 77     neutral  negative
# 86     neutral  positive
# 96     neutral  negative
# 109    neutral  negative
# 132   positive   neutral
# 137    neutral  positive
# 138   positive  positive
# 139   negative  positive
# 154   positive  positive
# 157    neutral  negative
# 172    neutral  negative
# 175   negative  negative
# 176    neutral  positive
# 192    neutral  positive
# 193   positive  positive
# 202    neutral  positive
# 220    neutral   neutral
# 222   negative  positive
# 223   positive   neutral
# 229    neutral  positive
# 231   positive  positive
# 232    neutral   neutral
# 234   negative   neutral
# 245   positive  negative
# 263    neutral  positive
# 265    neutral  negative
# 267   positive  negative
# 270    neutral  positive
# 271   positive  positive
# 282   positive  positive
# 283    neutral  positive
# 292   negative  positive
# 296   positive  negative
# 312   positive  positive
# 313    neutral  positive
